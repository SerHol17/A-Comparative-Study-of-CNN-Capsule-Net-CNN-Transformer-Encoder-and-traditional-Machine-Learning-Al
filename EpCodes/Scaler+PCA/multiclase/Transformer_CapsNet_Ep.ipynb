# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

import math

# %%
data_path6 ='https://raw.githubusercontent.com/sowiroar/capsnet/main/Epileptic%20Seizure%20Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  Labels[i] = Labels[i]-1

# %%
Labels
# Out:
# array([3, 0, 4, ..., 4, 2, 3])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 3    2300
# 0    2300
# 4    2300
# 1    2300
# 2    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, Labels, test_size=0.2, stratify=Labels, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (9200, 178)
# Train labels shape: (9200,)
# Test data shape: (2300, 178)
# Test labels shape: (2300,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test=pca.transform(X_test)

# %%
X_train.shape
# Out:
# (9200, 41)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (9200, 41, 1)

# %%
#classes
classes = [0, 1, 2, 3, 4]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %% [markdown]
# ## Transformer

# %%
# OPTIMIZER
LEARNING_RATE_2 = 1e-3
WEIGHT_DECAY_2 = 1e-4
LAYER_NORM_EPS_2 = 1e-6
PROJECTION_DIM_2 = 512 # no se puede modificar
NUM_HEADS_2 = 8
NUM_LAYERS_2 = 1
MLP_UNITS_2 = [
    PROJECTION_DIM_2 * 2,
    PROJECTION_DIM_2
]
def mlp(x, dropout_rate, hidden_units):
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
def transformer_2(encoded_patches):

    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS_2, key_dim=PROJECTION_DIM_2, dropout=0.1
    )(x1, x1)

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS_2, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x4, x2])
    return encoded_patches

def Transform_sh_2(inputs):
      # Iterate over the number of layers and stack up blocks of
      # Transformer.
    for i in range(NUM_LAYERS_2):
          # Add a Transformer block.
        encoded_patches = transformer_2(inputs)

    return encoded_patches

# %% [markdown]
# ## CapsNet

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=5
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,1,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 1, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %% [markdown]
# ## Transformer_Caps_Net

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  #Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  CVT1=Transform_sh_2(Layer_1)
  representation = tf.keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(CVT1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(representation)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7ed0518df880>)
# Epoch 1/500
# 72/72 - 33s - loss: 1.5714 - accuracy: 0.2584 - 33s/epoch - 460ms/step
# Epoch 2/500
# 72/72 - 1s - loss: 1.5663 - accuracy: 0.2352 - 1s/epoch - 17ms/step
# Epoch 3/500
# 72/72 - 1s - loss: 1.5557 - accuracy: 0.2343 - 1s/epoch - 17ms/step
# Epoch 4/500
# 72/72 - 1s - loss: 1.3333 - accuracy: 0.3659 - 1s/epoch - 17ms/step
# Epoch 5/500
# 72/72 - 1s - loss: 1.3944 - accuracy: 0.3404 - 1s/epoch - 20ms/step
# Epoch 6/500
# 72/72 - 1s - loss: 1.3765 - accuracy: 0.3404 - 1s/epoch - 20ms/step
# Epoch 7/500
# 72/72 - 1s - loss: 1.5915 - accuracy: 0.2223 - 1s/epoch - 17ms/step
# Epoch 8/500
# 72/72 - 1s - loss: 1.3956 - accuracy: 0.3193 - 1s/epoch - 17ms/step
# Epoch 9/500
# 72/72 - 1s - loss: 1.3379 - accuracy: 0.3486 - 1s/epoch - 17ms/step
# Epoch 10/500
# 72/72 - 1s - loss: 1.3176 - accuracy: 0.3500 - 1s/epoch - 17ms/step
# Epoch 11/500
# 72/72 - 1s - loss: 1.2881 - accuracy: 0.3697 - 1s/epoch - 17ms/step
# Epoch 12/500
# 72/72 - 1s - loss: 1.2492 - accuracy: 0.3987 - 1s/epoch - 17ms/step
# Epoch 13/500
# 72/72 - 1s - loss: 1.2310 - accuracy: 0.3990 - 1s/epoch - 17ms/step
# Epoch 14/500
# 72/72 - 1s - loss: 1.3186 - accuracy: 0.3678 - 1s/epoch - 18ms/step
# Epoch 15/500
# 72/72 - 2s - loss: 1.5726 - accuracy: 0.2505 - 2s/epoch - 21ms/step
# Epoch 16/500
# 72/72 - 1s - loss: 1.3543 - accuracy: 0.3585 - 1s/epoch - 18ms/step
# Epoch 17/500
# 72/72 - 1s - loss: 1.2919 - accuracy: 0.3853 - 1s/epoch - 17ms/step
# Epoch 18/500
# 72/72 - 1s - loss: 1.2617 - accuracy: 0.4108 - 1s/epoch - 17ms/step
# Epoch 19/500
# 72/72 - 1s - loss: 1.2552 - accuracy: 0.4103 - 1s/epoch - 17ms/step
# Epoch 20/500
# 72/72 - 1s - loss: 1.2469 - accuracy: 0.4041 - 1s/epoch - 17ms/step
# Epoch 21/500
# 72/72 - 1s - loss: 1.2312 - accuracy: 0.4159 - 1s/epoch - 17ms/step
# Epoch 22/500
# 72/72 - 1s - loss: 1.2084 - accuracy: 0.4387 - 1s/epoch - 17ms/step
# Epoch 23/500
# 72/72 - 1s - loss: 1.1983 - accuracy: 0.4539 - 1s/epoch - 17ms/step
# Epoch 24/500
# 72/72 - 1s - loss: 1.1832 - accuracy: 0.4713 - 1s/epoch - 20ms/step
# Epoch 25/500
# 72/72 - 1s - loss: 1.1536 - accuracy: 0.4879 - 1s/epoch - 20ms/step
# Epoch 26/500
# 72/72 - 1s - loss: 1.1435 - accuracy: 0.5004 - 1s/epoch - 17ms/step
# Epoch 27/500
# 72/72 - 1s - loss: 1.1373 - accuracy: 0.4970 - 1s/epoch - 17ms/step
# Epoch 28/500
# 72/72 - 1s - loss: 1.1085 - accuracy: 0.5153 - 1s/epoch - 18ms/step
# Epoch 29/500
# 72/72 - 1s - loss: 1.0906 - accuracy: 0.5212 - 1s/epoch - 17ms/step
# Epoch 30/500
# 72/72 - 1s - loss: 1.0521 - accuracy: 0.5398 - 1s/epoch - 17ms/step
# Epoch 31/500
# 72/72 - 1s - loss: 1.0363 - accuracy: 0.5442 - 1s/epoch - 17ms/step
# Epoch 32/500
# 72/72 - 1s - loss: 1.0272 - accuracy: 0.5480 - 1s/epoch - 17ms/step
# Epoch 33/500
# 72/72 - 1s - loss: 1.0079 - accuracy: 0.5547 - 1s/epoch - 19ms/step
# Epoch 34/500
# 72/72 - 1s - loss: 0.9997 - accuracy: 0.5632 - 1s/epoch - 21ms/step
# Epoch 35/500
# 72/72 - 1s - loss: 0.9916 - accuracy: 0.5590 - 1s/epoch - 18ms/step
# Epoch 36/500
# 72/72 - 1s - loss: 0.9681 - accuracy: 0.5713 - 1s/epoch - 17ms/step
# Epoch 37/500
# 72/72 - 1s - loss: 0.9533 - accuracy: 0.5767 - 1s/epoch - 17ms/step
# Epoch 38/500
# 72/72 - 1s - loss: 0.9471 - accuracy: 0.5846 - 1s/epoch - 17ms/step
# Epoch 39/500
# 72/72 - 1s - loss: 0.9357 - accuracy: 0.5842 - 1s/epoch - 17ms/step
# Epoch 40/500
# 72/72 - 1s - loss: 0.9214 - accuracy: 0.5868 - 1s/epoch - 17ms/step
# Epoch 41/500
# 72/72 - 1s - loss: 0.9199 - accuracy: 0.5907 - 1s/epoch - 17ms/step
# Epoch 42/500
# 72/72 - 1s - loss: 0.9179 - accuracy: 0.5967 - 1s/epoch - 18ms/step
# Epoch 43/500
# 72/72 - 1s - loss: 0.9047 - accuracy: 0.5977 - 1s/epoch - 21ms/step
# Epoch 44/500
# 72/72 - 1s - loss: 0.9002 - accuracy: 0.6003 - 1s/epoch - 19ms/step
# Epoch 45/500
# 72/72 - 1s - loss: 0.8899 - accuracy: 0.6025 - 1s/epoch - 18ms/step
# Epoch 46/500
# 72/72 - 1s - loss: 0.8877 - accuracy: 0.5990 - 1s/epoch - 17ms/step
# Epoch 47/500
# 72/72 - 1s - loss: 0.8815 - accuracy: 0.6048 - 1s/epoch - 18ms/step
# Epoch 48/500
# 72/72 - 1s - loss: 0.8689 - accuracy: 0.6095 - 1s/epoch - 18ms/step
# Epoch 49/500
# 72/72 - 1s - loss: 0.8680 - accuracy: 0.6074 - 1s/epoch - 17ms/step
# Epoch 50/500
# 72/72 - 1s - loss: 0.8610 - accuracy: 0.6140 - 1s/epoch - 17ms/step
# Epoch 51/500
# 72/72 - 1s - loss: 0.8589 - accuracy: 0.6176 - 1s/epoch - 18ms/step
# Epoch 52/500
# 72/72 - 1s - loss: 0.8633 - accuracy: 0.6127 - 1s/epoch - 20ms/step
# Epoch 53/500
# 72/72 - 1s - loss: 0.8558 - accuracy: 0.6177 - 1s/epoch - 21ms/step
# Epoch 54/500
# 72/72 - 1s - loss: 0.8453 - accuracy: 0.6227 - 1s/epoch - 18ms/step
# Epoch 55/500
# 72/72 - 1s - loss: 0.8380 - accuracy: 0.6200 - 1s/epoch - 18ms/step
# Epoch 56/500
# 72/72 - 1s - loss: 0.8526 - accuracy: 0.6226 - 1s/epoch - 17ms/step
# Epoch 57/500
# 72/72 - 1s - loss: 0.8335 - accuracy: 0.6250 - 1s/epoch - 17ms/step
# Epoch 58/500
# 72/72 - 1s - loss: 0.8265 - accuracy: 0.6299 - 1s/epoch - 18ms/step
# Epoch 59/500
# 72/72 - 1s - loss: 0.8303 - accuracy: 0.6257 - 1s/epoch - 17ms/step
# Epoch 60/500
# 72/72 - 1s - loss: 0.8178 - accuracy: 0.6316 - 1s/epoch - 17ms/step
# Epoch 61/500
# 72/72 - 1s - loss: 0.8172 - accuracy: 0.6366 - 1s/epoch - 19ms/step
# Epoch 62/500
# 72/72 - 2s - loss: 0.8100 - accuracy: 0.6329 - 2s/epoch - 21ms/step
# Epoch 63/500
# 72/72 - 1s - loss: 0.7972 - accuracy: 0.6379 - 1s/epoch - 17ms/step
# Epoch 64/500
# 72/72 - 1s - loss: 0.8086 - accuracy: 0.6317 - 1s/epoch - 17ms/step
# Epoch 65/500
# 72/72 - 1s - loss: 0.7989 - accuracy: 0.6416 - 1s/epoch - 18ms/step
# Epoch 66/500
# 72/72 - 1s - loss: 0.7996 - accuracy: 0.6409 - 1s/epoch - 17ms/step
# Epoch 67/500
# 72/72 - 1s - loss: 0.7875 - accuracy: 0.6437 - 1s/epoch - 17ms/step
# Epoch 68/500
# 72/72 - 1s - loss: 0.7826 - accuracy: 0.6504 - 1s/epoch - 17ms/step
# Epoch 69/500
# 72/72 - 1s - loss: 0.7700 - accuracy: 0.6521 - 1s/epoch - 17ms/step
# Epoch 70/500
# 72/72 - 1s - loss: 0.7701 - accuracy: 0.6518 - 1s/epoch - 18ms/step
# Epoch 71/500
# 72/72 - 2s - loss: 0.7729 - accuracy: 0.6465 - 2s/epoch - 21ms/step
# Epoch 72/500
# 72/72 - 1s - loss: 0.7734 - accuracy: 0.6537 - 1s/epoch - 20ms/step
# Epoch 73/500
# 72/72 - 2s - loss: 0.7617 - accuracy: 0.6579 - 2s/epoch - 32ms/step
# Epoch 74/500
# 72/72 - 2s - loss: 0.7650 - accuracy: 0.6564 - 2s/epoch - 24ms/step
# Epoch 75/500
# 72/72 - 1s - loss: 0.7572 - accuracy: 0.6654 - 1s/epoch - 17ms/step
# Epoch 76/500
# 72/72 - 1s - loss: 0.7555 - accuracy: 0.6576 - 1s/epoch - 17ms/step
# Epoch 77/500
# 72/72 - 1s - loss: 0.7529 - accuracy: 0.6625 - 1s/epoch - 17ms/step
# Epoch 78/500
# 72/72 - 1s - loss: 0.7520 - accuracy: 0.6623 - 1s/epoch - 17ms/step
# Epoch 79/500
# 72/72 - 1s - loss: 0.7531 - accuracy: 0.6591 - 1s/epoch - 20ms/step
# Epoch 80/500
# 72/72 - 1s - loss: 0.7496 - accuracy: 0.6640 - 1s/epoch - 20ms/step
# Epoch 81/500
# 72/72 - 1s - loss: 0.7509 - accuracy: 0.6641 - 1s/epoch - 18ms/step
# Epoch 82/500
# 72/72 - 1s - loss: 0.7454 - accuracy: 0.6657 - 1s/epoch - 17ms/step
# Epoch 83/500
# 72/72 - 1s - loss: 0.7466 - accuracy: 0.6693 - 1s/epoch - 17ms/step
# Epoch 84/500
# 72/72 - 1s - loss: 0.7397 - accuracy: 0.6662 - 1s/epoch - 17ms/step
# Epoch 85/500
# 72/72 - 1s - loss: 0.7410 - accuracy: 0.6653 - 1s/epoch - 17ms/step
# Epoch 86/500
# 72/72 - 1s - loss: 0.7427 - accuracy: 0.6640 - 1s/epoch - 17ms/step
# Epoch 87/500
# 72/72 - 1s - loss: 0.7389 - accuracy: 0.6655 - 1s/epoch - 17ms/step
# Epoch 88/500
# 72/72 - 1s - loss: 0.7451 - accuracy: 0.6618 - 1s/epoch - 19ms/step
# Epoch 89/500
# 72/72 - 2s - loss: 0.7356 - accuracy: 0.6701 - 2s/epoch - 21ms/step
# Epoch 90/500
# 72/72 - 1s - loss: 0.7294 - accuracy: 0.6727 - 1s/epoch - 17ms/step
# Epoch 91/500
# 72/72 - 1s - loss: 0.7219 - accuracy: 0.6716 - 1s/epoch - 17ms/step
# Epoch 92/500
# 72/72 - 1s - loss: 0.7168 - accuracy: 0.6743 - 1s/epoch - 17ms/step
# Epoch 93/500
# 72/72 - 1s - loss: 0.7251 - accuracy: 0.6737 - 1s/epoch - 17ms/step
# Epoch 94/500
# 72/72 - 1s - loss: 0.7233 - accuracy: 0.6755 - 1s/epoch - 17ms/step
# Epoch 95/500
# 72/72 - 1s - loss: 0.7291 - accuracy: 0.6707 - 1s/epoch - 17ms/step
# Epoch 96/500
# 72/72 - 1s - loss: 0.7265 - accuracy: 0.6707 - 1s/epoch - 18ms/step
# Epoch 97/500
# 72/72 - 1s - loss: 0.7278 - accuracy: 0.6691 - 1s/epoch - 18ms/step
# Epoch 98/500
# 72/72 - 1s - loss: 0.7227 - accuracy: 0.6752 - 1s/epoch - 21ms/step
# Epoch 99/500
# 72/72 - 1s - loss: 0.7099 - accuracy: 0.6805 - 1s/epoch - 19ms/step
# Epoch 100/500
# 72/72 - 1s - loss: 0.7193 - accuracy: 0.6748 - 1s/epoch - 17ms/step
# Epoch 101/500
# 72/72 - 1s - loss: 0.7165 - accuracy: 0.6812 - 1s/epoch - 17ms/step
# Epoch 102/500
# 72/72 - 1s - loss: 0.7148 - accuracy: 0.6763 - 1s/epoch - 17ms/step
# Epoch 103/500
# 72/72 - 1s - loss: 0.7132 - accuracy: 0.6783 - 1s/epoch - 18ms/step
# Epoch 104/500
# 72/72 - 1s - loss: 0.7229 - accuracy: 0.6732 - 1s/epoch - 17ms/step
# Epoch 105/500
# 72/72 - 1s - loss: 0.7110 - accuracy: 0.6757 - 1s/epoch - 17ms/step
# Epoch 106/500
# 72/72 - 1s - loss: 0.7076 - accuracy: 0.6758 - 1s/epoch - 17ms/step
# Epoch 107/500
# 72/72 - 1s - loss: 0.7076 - accuracy: 0.6837 - 1s/epoch - 20ms/step
# Epoch 108/500
# 72/72 - 1s - loss: 0.7077 - accuracy: 0.6811 - 1s/epoch - 20ms/step
# Epoch 109/500
# 72/72 - 1s - loss: 0.7003 - accuracy: 0.6883 - 1s/epoch - 17ms/step
# Epoch 110/500
# 72/72 - 1s - loss: 0.7110 - accuracy: 0.6812 - 1s/epoch - 17ms/step
# Epoch 111/500
# 72/72 - 1s - loss: 0.7034 - accuracy: 0.6849 - 1s/epoch - 17ms/step
# Epoch 112/500
# 72/72 - 1s - loss: 0.6992 - accuracy: 0.6851 - 1s/epoch - 18ms/step
# Epoch 113/500
# 72/72 - 1s - loss: 0.6950 - accuracy: 0.6882 - 1s/epoch - 17ms/step
# Epoch 114/500
# 72/72 - 1s - loss: 0.7019 - accuracy: 0.6803 - 1s/epoch - 17ms/step
# Epoch 115/500
# 72/72 - 1s - loss: 0.7008 - accuracy: 0.6892 - 1s/epoch - 17ms/step
# Epoch 116/500
# 72/72 - 1s - loss: 0.7005 - accuracy: 0.6858 - 1s/epoch - 19ms/step
# Epoch 117/500
# 72/72 - 1s - loss: 0.7006 - accuracy: 0.6918 - 1s/epoch - 21ms/step
# Epoch 118/500
# 72/72 - 1s - loss: 0.6815 - accuracy: 0.6920 - 1s/epoch - 18ms/step
# Epoch 119/500
# 72/72 - 1s - loss: 0.6840 - accuracy: 0.6949 - 1s/epoch - 18ms/step
# Epoch 120/500
# 72/72 - 1s - loss: 0.6878 - accuracy: 0.6899 - 1s/epoch - 18ms/step
# Epoch 121/500
# 72/72 - 1s - loss: 0.6913 - accuracy: 0.6817 - 1s/epoch - 18ms/step
# Epoch 122/500
# 72/72 - 1s - loss: 0.6851 - accuracy: 0.6905 - 1s/epoch - 18ms/step
# Epoch 123/500
# 72/72 - 1s - loss: 0.6790 - accuracy: 0.6986 - 1s/epoch - 17ms/step
# Epoch 124/500
# 72/72 - 1s - loss: 0.6828 - accuracy: 0.6923 - 1s/epoch - 17ms/step
# Epoch 125/500
# 72/72 - 1s - loss: 0.6747 - accuracy: 0.7022 - 1s/epoch - 18ms/step
# Epoch 126/500
# 72/72 - 2s - loss: 0.6835 - accuracy: 0.6912 - 2s/epoch - 21ms/step
# Epoch 127/500
# 72/72 - 1s - loss: 0.6798 - accuracy: 0.6933 - 1s/epoch - 19ms/step
# Epoch 128/500
# 72/72 - 1s - loss: 0.6751 - accuracy: 0.6941 - 1s/epoch - 17ms/step
# Epoch 129/500
# 72/72 - 1s - loss: 0.6655 - accuracy: 0.6872 - 1s/epoch - 17ms/step
# Epoch 130/500
# 72/72 - 1s - loss: 0.6839 - accuracy: 0.6895 - 1s/epoch - 17ms/step
# Epoch 131/500
# 72/72 - 1s - loss: 0.6683 - accuracy: 0.6995 - 1s/epoch - 17ms/step
# Epoch 132/500
# 72/72 - 1s - loss: 0.6723 - accuracy: 0.7036 - 1s/epoch - 17ms/step
# Epoch 133/500
# 72/72 - 1s - loss: 0.6714 - accuracy: 0.6939 - 1s/epoch - 18ms/step
# Epoch 134/500
# 72/72 - 1s - loss: 0.6579 - accuracy: 0.7040 - 1s/epoch - 17ms/step
# Epoch 135/500
# 72/72 - 1s - loss: 0.6681 - accuracy: 0.6973 - 1s/epoch - 20ms/step
# Epoch 136/500
# 72/72 - 1s - loss: 0.6749 - accuracy: 0.6957 - 1s/epoch - 20ms/step
# Epoch 137/500
# 72/72 - 1s - loss: 0.6619 - accuracy: 0.6986 - 1s/epoch - 17ms/step
# Epoch 138/500
# 72/72 - 1s - loss: 0.6628 - accuracy: 0.7025 - 1s/epoch - 17ms/step
# Epoch 139/500
# 72/72 - 1s - loss: 0.6579 - accuracy: 0.7011 - 1s/epoch - 17ms/step
# Epoch 140/500
# 72/72 - 1s - loss: 0.6574 - accuracy: 0.7011 - 1s/epoch - 17ms/step
# Epoch 141/500
# 72/72 - 1s - loss: 0.6559 - accuracy: 0.7050 - 1s/epoch - 17ms/step
# Epoch 142/500
# 72/72 - 1s - loss: 0.6583 - accuracy: 0.7007 - 1s/epoch - 17ms/step
# Epoch 143/500
# 72/72 - 1s - loss: 0.6510 - accuracy: 0.7047 - 1s/epoch - 18ms/step
# Epoch 144/500
# 72/72 - 1s - loss: 0.6450 - accuracy: 0.7149 - 1s/epoch - 19ms/step
# Epoch 145/500
# 72/72 - 1s - loss: 0.6574 - accuracy: 0.7057 - 1s/epoch - 21ms/step
# Epoch 146/500
# 72/72 - 1s - loss: 0.6522 - accuracy: 0.7085 - 1s/epoch - 18ms/step
# Epoch 147/500
# 72/72 - 1s - loss: 0.6381 - accuracy: 0.7141 - 1s/epoch - 17ms/step
# Epoch 148/500
# 72/72 - 1s - loss: 0.6539 - accuracy: 0.7060 - 1s/epoch - 17ms/step
# Epoch 149/500
# 72/72 - 1s - loss: 0.6480 - accuracy: 0.7108 - 1s/epoch - 18ms/step
# Epoch 150/500
# 72/72 - 1s - loss: 0.6432 - accuracy: 0.7139 - 1s/epoch - 17ms/step
# Epoch 151/500
# 72/72 - 1s - loss: 0.6396 - accuracy: 0.7108 - 1s/epoch - 17ms/step
# Epoch 152/500
# 72/72 - 1s - loss: 0.6406 - accuracy: 0.7164 - 1s/epoch - 18ms/step
# Epoch 153/500
# 72/72 - 1s - loss: 0.6361 - accuracy: 0.7088 - 1s/epoch - 17ms/step
# Epoch 154/500
# 72/72 - 1s - loss: 0.6312 - accuracy: 0.7150 - 1s/epoch - 20ms/step
# Epoch 155/500
# 72/72 - 1s - loss: 0.6352 - accuracy: 0.7108 - 1s/epoch - 20ms/step
# Epoch 156/500
# 72/72 - 1s - loss: 0.6226 - accuracy: 0.7168 - 1s/epoch - 17ms/step
# Epoch 157/500
# 72/72 - 1s - loss: 0.6259 - accuracy: 0.7207 - 1s/epoch - 17ms/step
# Epoch 158/500
# 72/72 - 1s - loss: 0.6226 - accuracy: 0.7250 - 1s/epoch - 17ms/step
# Epoch 159/500
# 72/72 - 1s - loss: 0.6419 - accuracy: 0.7129 - 1s/epoch - 18ms/step
# Epoch 160/500
# 72/72 - 1s - loss: 0.6290 - accuracy: 0.7209 - 1s/epoch - 17ms/step
# Epoch 161/500
# 72/72 - 1s - loss: 0.6219 - accuracy: 0.7179 - 1s/epoch - 17ms/step
# Epoch 162/500
# 72/72 - 1s - loss: 0.6239 - accuracy: 0.7180 - 1s/epoch - 17ms/step
# Epoch 163/500
# 72/72 - 1s - loss: 0.6170 - accuracy: 0.7245 - 1s/epoch - 20ms/step
# Epoch 164/500
# 72/72 - 1s - loss: 0.6242 - accuracy: 0.7173 - 1s/epoch - 21ms/step
# Epoch 165/500
# 72/72 - 1s - loss: 0.6254 - accuracy: 0.7186 - 1s/epoch - 17ms/step
# Epoch 166/500
# 72/72 - 1s - loss: 0.6249 - accuracy: 0.7229 - 1s/epoch - 17ms/step
# Epoch 167/500
# 72/72 - 1s - loss: 0.6145 - accuracy: 0.7242 - 1s/epoch - 17ms/step
# Epoch 168/500
# 72/72 - 1s - loss: 0.6143 - accuracy: 0.7259 - 1s/epoch - 17ms/step
# Epoch 169/500
# 72/72 - 1s - loss: 0.6150 - accuracy: 0.7255 - 1s/epoch - 17ms/step
# Epoch 170/500
# 72/72 - 1s - loss: 0.6115 - accuracy: 0.7250 - 1s/epoch - 17ms/step
# Epoch 171/500
# 72/72 - 1s - loss: 0.6019 - accuracy: 0.7297 - 1s/epoch - 17ms/step
# Epoch 172/500
# 72/72 - 1s - loss: 0.6132 - accuracy: 0.7291 - 1s/epoch - 18ms/step
# Epoch 173/500
# 72/72 - 1s - loss: 0.6080 - accuracy: 0.7289 - 1s/epoch - 21ms/step
# Epoch 174/500
# 72/72 - 1s - loss: 0.6003 - accuracy: 0.7316 - 1s/epoch - 19ms/step
# Epoch 175/500
# 72/72 - 1s - loss: 0.6061 - accuracy: 0.7302 - 1s/epoch - 17ms/step
# Epoch 176/500
# 72/72 - 1s - loss: 0.5960 - accuracy: 0.7282 - 1s/epoch - 17ms/step
# Epoch 177/500
# 72/72 - 1s - loss: 0.5951 - accuracy: 0.7335 - 1s/epoch - 17ms/step
# Epoch 178/500
# 72/72 - 1s - loss: 0.5958 - accuracy: 0.7353 - 1s/epoch - 17ms/step
# Epoch 179/500
# 72/72 - 1s - loss: 0.5922 - accuracy: 0.7310 - 1s/epoch - 17ms/step
# Epoch 180/500
# 72/72 - 1s - loss: 0.5986 - accuracy: 0.7287 - 1s/epoch - 17ms/step
# Epoch 181/500
# 72/72 - 1s - loss: 0.5835 - accuracy: 0.7371 - 1s/epoch - 17ms/step
# Epoch 182/500
# 72/72 - 1s - loss: 0.6000 - accuracy: 0.7232 - 1s/epoch - 20ms/step
# Epoch 183/500
# 72/72 - 1s - loss: 0.6007 - accuracy: 0.7325 - 1s/epoch - 20ms/step
# Epoch 184/500
# 72/72 - 1s - loss: 0.5935 - accuracy: 0.7336 - 1s/epoch - 17ms/step
# Epoch 185/500
# 72/72 - 1s - loss: 0.5966 - accuracy: 0.7368 - 1s/epoch - 17ms/step
# Epoch 186/500
# 72/72 - 1s - loss: 0.5830 - accuracy: 0.7418 - 1s/epoch - 17ms/step
# Epoch 187/500
# 72/72 - 1s - loss: 0.5900 - accuracy: 0.7340 - 1s/epoch - 17ms/step
# Epoch 188/500
# 72/72 - 1s - loss: 0.5812 - accuracy: 0.7418 - 1s/epoch - 18ms/step
# Epoch 189/500
# 72/72 - 1s - loss: 0.5783 - accuracy: 0.7421 - 1s/epoch - 17ms/step
# Epoch 190/500
# 72/72 - 1s - loss: 0.5699 - accuracy: 0.7465 - 1s/epoch - 18ms/step
# Epoch 191/500
# 72/72 - 1s - loss: 0.5879 - accuracy: 0.7401 - 1s/epoch - 18ms/step
# Epoch 192/500
# 72/72 - 2s - loss: 0.5826 - accuracy: 0.7422 - 2s/epoch - 21ms/step
# Epoch 193/500
# 72/72 - 1s - loss: 0.5902 - accuracy: 0.7368 - 1s/epoch - 18ms/step
# Epoch 194/500
# 72/72 - 1s - loss: 0.5780 - accuracy: 0.7458 - 1s/epoch - 17ms/step
# Epoch 195/500
# 72/72 - 1s - loss: 0.5656 - accuracy: 0.7459 - 1s/epoch - 17ms/step
# Epoch 196/500
# 72/72 - 1s - loss: 0.5726 - accuracy: 0.7486 - 1s/epoch - 18ms/step
# Epoch 197/500
# 72/72 - 1s - loss: 0.5756 - accuracy: 0.7458 - 1s/epoch - 17ms/step
# Epoch 198/500
# 72/72 - 1s - loss: 0.5720 - accuracy: 0.7472 - 1s/epoch - 18ms/step
# Epoch 199/500
# 72/72 - 1s - loss: 0.5639 - accuracy: 0.7490 - 1s/epoch - 18ms/step
# Epoch 200/500
# 72/72 - 1s - loss: 0.5709 - accuracy: 0.7507 - 1s/epoch - 18ms/step
# Epoch 201/500
# 72/72 - 1s - loss: 0.5703 - accuracy: 0.7449 - 1s/epoch - 20ms/step
# Epoch 202/500
# 72/72 - 1s - loss: 0.5639 - accuracy: 0.7520 - 1s/epoch - 19ms/step
# Epoch 203/500
# 72/72 - 1s - loss: 0.5646 - accuracy: 0.7540 - 1s/epoch - 18ms/step
# Epoch 204/500
# 72/72 - 1s - loss: 0.5620 - accuracy: 0.7542 - 1s/epoch - 18ms/step
# Epoch 205/500
# 72/72 - 1s - loss: 0.5593 - accuracy: 0.7510 - 1s/epoch - 17ms/step
# Epoch 206/500
# 72/72 - 1s - loss: 0.5576 - accuracy: 0.7511 - 1s/epoch - 17ms/step
# Epoch 207/500
# 72/72 - 1s - loss: 0.5531 - accuracy: 0.7540 - 1s/epoch - 18ms/step
# Epoch 208/500
# 72/72 - 1s - loss: 0.5524 - accuracy: 0.7568 - 1s/epoch - 17ms/step
# Epoch 209/500
# 72/72 - 1s - loss: 0.5446 - accuracy: 0.7587 - 1s/epoch - 17ms/step
# Epoch 210/500
# 72/72 - 1s - loss: 0.5490 - accuracy: 0.7614 - 1s/epoch - 19ms/step
# Epoch 211/500
# 72/72 - 1s - loss: 0.5472 - accuracy: 0.7637 - 1s/epoch - 21ms/step
# Epoch 212/500
# 72/72 - 1s - loss: 0.5392 - accuracy: 0.7610 - 1s/epoch - 17ms/step
# Epoch 213/500
# 72/72 - 1s - loss: 0.5314 - accuracy: 0.7687 - 1s/epoch - 18ms/step
# Epoch 214/500
# 72/72 - 1s - loss: 0.5383 - accuracy: 0.7664 - 1s/epoch - 18ms/step
# Epoch 215/500
# 72/72 - 1s - loss: 0.5400 - accuracy: 0.7645 - 1s/epoch - 17ms/step
# Epoch 216/500
# 72/72 - 1s - loss: 0.5312 - accuracy: 0.7678 - 1s/epoch - 17ms/step
# Epoch 217/500
# 72/72 - 1s - loss: 0.5475 - accuracy: 0.7600 - 1s/epoch - 17ms/step
# Epoch 218/500
# 72/72 - 1s - loss: 0.5354 - accuracy: 0.7655 - 1s/epoch - 18ms/step
# Epoch 219/500
# 72/72 - 1s - loss: 0.5315 - accuracy: 0.7733 - 1s/epoch - 18ms/step
# Epoch 220/500
# 72/72 - 1s - loss: 0.5302 - accuracy: 0.7667 - 1s/epoch - 20ms/step
# Epoch 221/500
# 72/72 - 1s - loss: 0.5380 - accuracy: 0.7654 - 1s/epoch - 19ms/step
# Epoch 222/500
# 72/72 - 1s - loss: 0.5262 - accuracy: 0.7685 - 1s/epoch - 17ms/step
# Epoch 223/500
# 72/72 - 1s - loss: 0.5274 - accuracy: 0.7637 - 1s/epoch - 17ms/step
# Epoch 224/500
# 72/72 - 1s - loss: 0.5242 - accuracy: 0.7683 - 1s/epoch - 17ms/step
# Epoch 225/500
# 72/72 - 1s - loss: 0.5248 - accuracy: 0.7692 - 1s/epoch - 17ms/step
# Epoch 226/500
# 72/72 - 1s - loss: 0.5282 - accuracy: 0.7716 - 1s/epoch - 18ms/step
# Epoch 227/500
# 72/72 - 1s - loss: 0.5305 - accuracy: 0.7673 - 1s/epoch - 17ms/step
# Epoch 228/500
# 72/72 - 1s - loss: 0.5322 - accuracy: 0.7666 - 1s/epoch - 17ms/step
# Epoch 229/500
# 72/72 - 1s - loss: 0.5188 - accuracy: 0.7689 - 1s/epoch - 20ms/step
# Epoch 230/500
# 72/72 - 1s - loss: 0.5112 - accuracy: 0.7763 - 1s/epoch - 20ms/step
# Epoch 231/500
# 72/72 - 1s - loss: 0.5095 - accuracy: 0.7785 - 1s/epoch - 17ms/step
# Epoch 232/500
# 72/72 - 1s - loss: 0.5174 - accuracy: 0.7783 - 1s/epoch - 17ms/step
# Epoch 233/500
# 72/72 - 1s - loss: 0.5178 - accuracy: 0.7739 - 1s/epoch - 17ms/step
# Epoch 234/500
# 72/72 - 1s - loss: 0.5145 - accuracy: 0.7735 - 1s/epoch - 17ms/step
# Epoch 235/500
# 72/72 - 1s - loss: 0.5049 - accuracy: 0.7754 - 1s/epoch - 17ms/step
# Epoch 236/500
# 72/72 - 1s - loss: 0.5054 - accuracy: 0.7782 - 1s/epoch - 17ms/step
# Epoch 237/500
# 72/72 - 1s - loss: 0.5586 - accuracy: 0.7559 - 1s/epoch - 18ms/step
# Epoch 238/500
# 72/72 - 1s - loss: 0.5327 - accuracy: 0.7636 - 1s/epoch - 19ms/step
# Epoch 239/500
# 72/72 - 2s - loss: 0.5175 - accuracy: 0.7782 - 2s/epoch - 21ms/step
# Epoch 240/500
# 72/72 - 1s - loss: 0.4983 - accuracy: 0.7853 - 1s/epoch - 18ms/step
# Epoch 241/500
# 72/72 - 1s - loss: 0.5119 - accuracy: 0.7820 - 1s/epoch - 17ms/step
# Epoch 242/500
# 72/72 - 1s - loss: 0.4990 - accuracy: 0.7809 - 1s/epoch - 18ms/step
# Epoch 243/500
# 72/72 - 1s - loss: 0.4943 - accuracy: 0.7824 - 1s/epoch - 18ms/step
# Epoch 244/500
# 72/72 - 1s - loss: 0.5030 - accuracy: 0.7838 - 1s/epoch - 18ms/step
# Epoch 245/500
# 72/72 - 1s - loss: 0.4998 - accuracy: 0.7812 - 1s/epoch - 18ms/step
# Epoch 246/500
# 72/72 - 1s - loss: 0.5063 - accuracy: 0.7834 - 1s/epoch - 17ms/step
# Epoch 247/500
# 72/72 - 1s - loss: 0.4913 - accuracy: 0.7866 - 1s/epoch - 17ms/step
# Epoch 248/500
# 72/72 - 1s - loss: 0.4937 - accuracy: 0.7901 - 1s/epoch - 21ms/step
# Epoch 249/500
# 72/72 - 1s - loss: 0.4944 - accuracy: 0.7876 - 1s/epoch - 19ms/step
# Epoch 250/500
# 72/72 - 1s - loss: 0.4964 - accuracy: 0.7879 - 1s/epoch - 17ms/step
# Epoch 251/500
# 72/72 - 1s - loss: 0.4947 - accuracy: 0.7839 - 1s/epoch - 17ms/step
# Epoch 252/500
# 72/72 - 1s - loss: 0.4917 - accuracy: 0.7893 - 1s/epoch - 17ms/step
# Epoch 253/500
# 72/72 - 1s - loss: 0.4786 - accuracy: 0.7959 - 1s/epoch - 17ms/step
# Epoch 254/500
# 72/72 - 1s - loss: 0.4909 - accuracy: 0.7861 - 1s/epoch - 17ms/step
# Epoch 255/500
# 72/72 - 1s - loss: 0.4867 - accuracy: 0.7932 - 1s/epoch - 17ms/step
# Epoch 256/500
# 72/72 - 1s - loss: 0.4806 - accuracy: 0.7949 - 1s/epoch - 17ms/step
# Epoch 257/500
# 72/72 - 1s - loss: 0.4845 - accuracy: 0.7916 - 1s/epoch - 19ms/step
# Epoch 258/500
# 72/72 - 2s - loss: 0.4745 - accuracy: 0.7925 - 2s/epoch - 23ms/step
# Epoch 259/500
# 72/72 - 1s - loss: 0.4687 - accuracy: 0.7976 - 1s/epoch - 18ms/step
# Epoch 260/500
# 72/72 - 1s - loss: 0.4860 - accuracy: 0.7902 - 1s/epoch - 18ms/step
# Epoch 261/500
# 72/72 - 1s - loss: 0.4718 - accuracy: 0.7979 - 1s/epoch - 17ms/step
# Epoch 262/500
# 72/72 - 1s - loss: 0.4653 - accuracy: 0.8014 - 1s/epoch - 17ms/step
# Epoch 263/500
# 72/72 - 1s - loss: 0.4671 - accuracy: 0.8061 - 1s/epoch - 18ms/step
# Epoch 264/500
# 72/72 - 1s - loss: 0.4656 - accuracy: 0.7986 - 1s/epoch - 17ms/step
# Epoch 265/500
# 72/72 - 1s - loss: 0.4487 - accuracy: 0.8070 - 1s/epoch - 18ms/step
# Epoch 266/500
# 72/72 - 1s - loss: 0.4655 - accuracy: 0.8016 - 1s/epoch - 18ms/step
# Epoch 267/500
# 72/72 - 2s - loss: 0.4609 - accuracy: 0.8037 - 2s/epoch - 21ms/step
# Epoch 268/500
# 72/72 - 1s - loss: 0.4683 - accuracy: 0.8024 - 1s/epoch - 19ms/step
# Epoch 269/500
# 72/72 - 1s - loss: 0.4649 - accuracy: 0.8028 - 1s/epoch - 17ms/step
# Epoch 270/500
# 72/72 - 1s - loss: 0.4628 - accuracy: 0.8049 - 1s/epoch - 17ms/step
# Epoch 271/500
# 72/72 - 1s - loss: 0.4723 - accuracy: 0.8027 - 1s/epoch - 17ms/step
# Epoch 272/500
# 72/72 - 1s - loss: 0.5569 - accuracy: 0.7661 - 1s/epoch - 18ms/step
# Epoch 273/500
# 72/72 - 1s - loss: 0.5087 - accuracy: 0.7878 - 1s/epoch - 17ms/step
# Epoch 274/500
# 72/72 - 1s - loss: 0.4830 - accuracy: 0.7910 - 1s/epoch - 17ms/step
# Epoch 275/500
# 72/72 - 1s - loss: 0.4724 - accuracy: 0.7982 - 1s/epoch - 17ms/step
# Epoch 276/500
# 72/72 - 1s - loss: 0.4628 - accuracy: 0.8060 - 1s/epoch - 20ms/step
# Epoch 277/500
# 72/72 - 1s - loss: 0.4680 - accuracy: 0.7963 - 1s/epoch - 20ms/step
# Epoch 278/500
# 72/72 - 1s - loss: 0.4633 - accuracy: 0.8047 - 1s/epoch - 18ms/step
# Epoch 279/500
# 72/72 - 1s - loss: 0.4616 - accuracy: 0.8046 - 1s/epoch - 18ms/step
# Epoch 280/500
# 72/72 - 1s - loss: 0.4652 - accuracy: 0.8018 - 1s/epoch - 17ms/step
# Epoch 281/500
# 72/72 - 1s - loss: 0.4450 - accuracy: 0.8167 - 1s/epoch - 17ms/step
# Epoch 282/500
# 72/72 - 1s - loss: 0.4527 - accuracy: 0.8114 - 1s/epoch - 17ms/step
# Epoch 283/500
# 72/72 - 1s - loss: 0.4418 - accuracy: 0.8104 - 1s/epoch - 18ms/step
# Epoch 284/500
# 72/72 - 1s - loss: 0.4510 - accuracy: 0.8097 - 1s/epoch - 17ms/step
# Epoch 285/500
# 72/72 - 1s - loss: 0.4399 - accuracy: 0.8157 - 1s/epoch - 19ms/step
# Epoch 286/500
# 72/72 - 2s - loss: 0.4413 - accuracy: 0.8154 - 2s/epoch - 22ms/step
# Epoch 287/500
# 72/72 - 1s - loss: 0.4511 - accuracy: 0.8108 - 1s/epoch - 18ms/step
# Epoch 288/500
# 72/72 - 1s - loss: 0.4265 - accuracy: 0.8205 - 1s/epoch - 18ms/step
# Epoch 289/500
# 72/72 - 1s - loss: 0.4487 - accuracy: 0.8125 - 1s/epoch - 17ms/step
# Epoch 290/500
# 72/72 - 1s - loss: 0.4338 - accuracy: 0.8188 - 1s/epoch - 17ms/step
# Epoch 291/500
# 72/72 - 1s - loss: 0.4340 - accuracy: 0.8201 - 1s/epoch - 17ms/step
# Epoch 292/500
# 72/72 - 1s - loss: 0.4320 - accuracy: 0.8208 - 1s/epoch - 17ms/step
# Epoch 293/500
# 72/72 - 1s - loss: 0.4294 - accuracy: 0.8184 - 1s/epoch - 17ms/step
# Epoch 294/500
# 72/72 - 1s - loss: 0.4336 - accuracy: 0.8230 - 1s/epoch - 18ms/step
# Epoch 295/500
# 72/72 - 1s - loss: 0.4272 - accuracy: 0.8192 - 1s/epoch - 21ms/step
# Epoch 296/500
# 72/72 - 1s - loss: 0.4354 - accuracy: 0.8204 - 1s/epoch - 19ms/step
# Epoch 297/500
# 72/72 - 1s - loss: 0.4284 - accuracy: 0.8247 - 1s/epoch - 18ms/step
# Epoch 298/500
# 72/72 - 1s - loss: 0.4177 - accuracy: 0.8298 - 1s/epoch - 17ms/step
# Epoch 299/500
# 72/72 - 1s - loss: 0.4254 - accuracy: 0.8238 - 1s/epoch - 17ms/step
# Epoch 300/500
# 72/72 - 1s - loss: 0.4218 - accuracy: 0.8267 - 1s/epoch - 17ms/step
# Epoch 301/500
# 72/72 - 1s - loss: 0.4286 - accuracy: 0.8225 - 1s/epoch - 17ms/step
# Epoch 302/500
# 72/72 - 1s - loss: 0.4185 - accuracy: 0.8297 - 1s/epoch - 17ms/step
# Epoch 303/500
# 72/72 - 1s - loss: 0.4210 - accuracy: 0.8248 - 1s/epoch - 17ms/step
# Epoch 304/500
# 72/72 - 1s - loss: 0.4092 - accuracy: 0.8298 - 1s/epoch - 19ms/step
# Epoch 305/500
# 72/72 - 1s - loss: 0.4195 - accuracy: 0.8295 - 1s/epoch - 21ms/step
# Epoch 306/500
# 72/72 - 1s - loss: 0.4099 - accuracy: 0.8265 - 1s/epoch - 17ms/step
# Epoch 307/500
# 72/72 - 1s - loss: 0.4160 - accuracy: 0.8289 - 1s/epoch - 17ms/step
# Epoch 308/500
# 72/72 - 1s - loss: 0.4038 - accuracy: 0.8342 - 1s/epoch - 18ms/step
# Epoch 309/500
# 72/72 - 1s - loss: 0.4183 - accuracy: 0.8263 - 1s/epoch - 17ms/step
# Epoch 310/500
# 72/72 - 1s - loss: 0.4028 - accuracy: 0.8335 - 1s/epoch - 17ms/step
# Epoch 311/500
# 72/72 - 1s - loss: 0.4045 - accuracy: 0.8314 - 1s/epoch - 17ms/step
# Epoch 312/500
# 72/72 - 1s - loss: 0.4028 - accuracy: 0.8358 - 1s/epoch - 18ms/step
# Epoch 313/500
# 72/72 - 1s - loss: 0.4182 - accuracy: 0.8289 - 1s/epoch - 18ms/step
# Epoch 314/500
# 72/72 - 1s - loss: 0.4160 - accuracy: 0.8266 - 1s/epoch - 21ms/step
# Epoch 315/500
# 72/72 - 1s - loss: 0.3983 - accuracy: 0.8334 - 1s/epoch - 18ms/step
# Epoch 316/500
# 72/72 - 1s - loss: 0.4025 - accuracy: 0.8358 - 1s/epoch - 17ms/step
# Epoch 317/500
# 72/72 - 1s - loss: 0.4103 - accuracy: 0.8329 - 1s/epoch - 17ms/step
# Epoch 318/500
# 72/72 - 1s - loss: 0.3954 - accuracy: 0.8364 - 1s/epoch - 17ms/step
# Epoch 319/500
# 72/72 - 1s - loss: 0.3975 - accuracy: 0.8376 - 1s/epoch - 17ms/step
# Epoch 320/500
# 72/72 - 1s - loss: 0.3950 - accuracy: 0.8377 - 1s/epoch - 17ms/step
# Epoch 321/500
# 72/72 - 1s - loss: 0.3928 - accuracy: 0.8384 - 1s/epoch - 17ms/step
# Epoch 322/500
# 72/72 - 1s - loss: 0.3956 - accuracy: 0.8395 - 1s/epoch - 17ms/step
# Epoch 323/500
# 72/72 - 1s - loss: 0.4019 - accuracy: 0.8405 - 1s/epoch - 20ms/step
# Epoch 324/500
# 72/72 - 1s - loss: 0.3947 - accuracy: 0.8415 - 1s/epoch - 20ms/step
# Epoch 325/500
# 72/72 - 1s - loss: 0.3908 - accuracy: 0.8461 - 1s/epoch - 17ms/step
# Epoch 326/500
# 72/72 - 1s - loss: 0.3980 - accuracy: 0.8407 - 1s/epoch - 18ms/step
# Epoch 327/500
# 72/72 - 1s - loss: 0.4123 - accuracy: 0.8349 - 1s/epoch - 18ms/step
# Epoch 328/500
# 72/72 - 1s - loss: 0.4135 - accuracy: 0.8315 - 1s/epoch - 18ms/step
# Epoch 329/500
# 72/72 - 1s - loss: 0.4019 - accuracy: 0.8386 - 1s/epoch - 17ms/step
# Epoch 330/500
# 72/72 - 1s - loss: 0.3874 - accuracy: 0.8425 - 1s/epoch - 17ms/step
# Epoch 331/500
# 72/72 - 1s - loss: 0.3901 - accuracy: 0.8396 - 1s/epoch - 17ms/step
# Epoch 332/500
# 72/72 - 1s - loss: 0.3967 - accuracy: 0.8413 - 1s/epoch - 19ms/step
# Epoch 333/500
# 72/72 - 2s - loss: 0.3964 - accuracy: 0.8384 - 2s/epoch - 21ms/step
# Epoch 334/500
# 72/72 - 1s - loss: 0.3867 - accuracy: 0.8462 - 1s/epoch - 17ms/step
# Epoch 335/500
# 72/72 - 1s - loss: 0.3823 - accuracy: 0.8453 - 1s/epoch - 18ms/step
# Epoch 336/500
# 72/72 - 1s - loss: 0.3816 - accuracy: 0.8450 - 1s/epoch - 17ms/step
# Epoch 337/500
# 72/72 - 1s - loss: 0.3890 - accuracy: 0.8453 - 1s/epoch - 17ms/step
# Epoch 338/500
# 72/72 - 1s - loss: 0.3705 - accuracy: 0.8502 - 1s/epoch - 18ms/step
# Epoch 339/500
# 72/72 - 1s - loss: 0.3669 - accuracy: 0.8499 - 1s/epoch - 17ms/step
# Epoch 340/500
# 72/72 - 1s - loss: 0.3701 - accuracy: 0.8559 - 1s/epoch - 17ms/step
# Epoch 341/500
# 72/72 - 1s - loss: 0.3678 - accuracy: 0.8536 - 1s/epoch - 18ms/step
# Epoch 342/500
# 72/72 - 1s - loss: 0.3724 - accuracy: 0.8555 - 1s/epoch - 21ms/step
# Epoch 343/500
# 72/72 - 1s - loss: 0.3621 - accuracy: 0.8518 - 1s/epoch - 19ms/step
# Epoch 344/500
# 72/72 - 1s - loss: 0.3701 - accuracy: 0.8473 - 1s/epoch - 17ms/step
# Epoch 345/500
# 72/72 - 1s - loss: 0.3684 - accuracy: 0.8525 - 1s/epoch - 17ms/step
# Epoch 346/500
# 72/72 - 1s - loss: 0.3586 - accuracy: 0.8549 - 1s/epoch - 17ms/step
# Epoch 347/500
# 72/72 - 1s - loss: 0.3707 - accuracy: 0.8518 - 1s/epoch - 17ms/step
# Epoch 348/500
# 72/72 - 1s - loss: 0.3555 - accuracy: 0.8571 - 1s/epoch - 17ms/step
# Epoch 349/500
# 72/72 - 1s - loss: 0.3518 - accuracy: 0.8627 - 1s/epoch - 17ms/step
# Epoch 350/500
# 72/72 - 1s - loss: 0.3643 - accuracy: 0.8525 - 1s/epoch - 18ms/step
# Epoch 351/500
# 72/72 - 1s - loss: 0.3615 - accuracy: 0.8540 - 1s/epoch - 19ms/step
# Epoch 352/500
# 72/72 - 1s - loss: 0.3551 - accuracy: 0.8604 - 1s/epoch - 20ms/step
# Epoch 353/500
# 72/72 - 1s - loss: 0.3504 - accuracy: 0.8591 - 1s/epoch - 18ms/step
# Epoch 354/500
# 72/72 - 1s - loss: 0.3488 - accuracy: 0.8643 - 1s/epoch - 17ms/step
# Epoch 355/500
# 72/72 - 1s - loss: 0.3695 - accuracy: 0.8597 - 1s/epoch - 18ms/step
# Epoch 356/500
# 72/72 - 1s - loss: 0.3443 - accuracy: 0.8612 - 1s/epoch - 18ms/step
# Epoch 357/500
# 72/72 - 1s - loss: 0.3539 - accuracy: 0.8585 - 1s/epoch - 17ms/step
# Epoch 358/500
# 72/72 - 1s - loss: 0.3625 - accuracy: 0.8538 - 1s/epoch - 18ms/step
# Epoch 359/500
# 72/72 - 1s - loss: 0.3479 - accuracy: 0.8603 - 1s/epoch - 17ms/step
# Epoch 360/500
# 72/72 - 1s - loss: 0.3477 - accuracy: 0.8620 - 1s/epoch - 19ms/step
# Epoch 361/500
# 72/72 - 1s - loss: 0.3361 - accuracy: 0.8660 - 1s/epoch - 21ms/step
# Epoch 362/500
# 72/72 - 1s - loss: 0.3484 - accuracy: 0.8627 - 1s/epoch - 18ms/step
# Epoch 363/500
# 72/72 - 1s - loss: 0.3504 - accuracy: 0.8574 - 1s/epoch - 18ms/step
# Epoch 364/500
# 72/72 - 1s - loss: 0.3415 - accuracy: 0.8632 - 1s/epoch - 17ms/step
# Epoch 365/500
# 72/72 - 1s - loss: 0.3531 - accuracy: 0.8655 - 1s/epoch - 17ms/step
# Epoch 366/500
# 72/72 - 1s - loss: 0.3357 - accuracy: 0.8652 - 1s/epoch - 17ms/step
# Epoch 367/500
# 72/72 - 1s - loss: 0.3393 - accuracy: 0.8670 - 1s/epoch - 18ms/step
# Epoch 368/500
# 72/72 - 1s - loss: 0.3470 - accuracy: 0.8659 - 1s/epoch - 17ms/step
# Epoch 369/500
# 72/72 - 1s - loss: 0.3384 - accuracy: 0.8693 - 1s/epoch - 18ms/step
# Epoch 370/500
# 72/72 - 1s - loss: 0.3355 - accuracy: 0.8687 - 1s/epoch - 21ms/step
# Epoch 371/500
# 72/72 - 1s - loss: 0.3423 - accuracy: 0.8632 - 1s/epoch - 20ms/step
# Epoch 372/500
# 72/72 - 1s - loss: 0.3380 - accuracy: 0.8642 - 1s/epoch - 17ms/step
# Epoch 373/500
# 72/72 - 1s - loss: 0.3305 - accuracy: 0.8735 - 1s/epoch - 17ms/step
# Epoch 374/500
# 72/72 - 1s - loss: 0.3249 - accuracy: 0.8691 - 1s/epoch - 18ms/step
# Epoch 375/500
# 72/72 - 1s - loss: 0.3322 - accuracy: 0.8716 - 1s/epoch - 17ms/step
# Epoch 376/500
# 72/72 - 1s - loss: 0.3363 - accuracy: 0.8677 - 1s/epoch - 17ms/step
# Epoch 377/500
# 72/72 - 1s - loss: 0.3377 - accuracy: 0.8657 - 1s/epoch - 17ms/step
# Epoch 378/500
# 72/72 - 1s - loss: 0.3348 - accuracy: 0.8668 - 1s/epoch - 17ms/step
# Epoch 379/500
# 72/72 - 1s - loss: 0.3318 - accuracy: 0.8700 - 1s/epoch - 19ms/step
# Epoch 380/500
# 72/72 - 1s - loss: 0.3380 - accuracy: 0.8686 - 1s/epoch - 21ms/step
# Epoch 381/500
# 72/72 - 1s - loss: 0.3337 - accuracy: 0.8712 - 1s/epoch - 18ms/step
# Epoch 382/500
# 72/72 - 1s - loss: 0.3436 - accuracy: 0.8671 - 1s/epoch - 17ms/step
# Epoch 383/500
# 72/72 - 1s - loss: 0.3353 - accuracy: 0.8683 - 1s/epoch - 17ms/step
# Epoch 384/500
# 72/72 - 1s - loss: 0.3166 - accuracy: 0.8752 - 1s/epoch - 17ms/step
# Epoch 385/500
# 72/72 - 1s - loss: 0.3337 - accuracy: 0.8690 - 1s/epoch - 17ms/step
# Epoch 386/500
# 72/72 - 1s - loss: 0.3358 - accuracy: 0.8682 - 1s/epoch - 18ms/step
# Epoch 387/500
# 72/72 - 1s - loss: 0.3211 - accuracy: 0.8746 - 1s/epoch - 18ms/step
# Epoch 388/500
# 72/72 - 1s - loss: 0.3177 - accuracy: 0.8745 - 1s/epoch - 19ms/step
# Epoch 389/500
# 72/72 - 1s - loss: 0.3169 - accuracy: 0.8770 - 1s/epoch - 21ms/step
# Epoch 390/500
# 72/72 - 1s - loss: 0.3248 - accuracy: 0.8725 - 1s/epoch - 19ms/step
# Epoch 391/500
# 72/72 - 1s - loss: 0.3182 - accuracy: 0.8772 - 1s/epoch - 17ms/step
# Epoch 392/500
# 72/72 - 1s - loss: 0.3235 - accuracy: 0.8713 - 1s/epoch - 17ms/step
# Epoch 393/500
# 72/72 - 1s - loss: 0.3167 - accuracy: 0.8798 - 1s/epoch - 17ms/step
# Epoch 394/500
# 72/72 - 1s - loss: 0.3203 - accuracy: 0.8738 - 1s/epoch - 17ms/step
# Epoch 395/500
# 72/72 - 1s - loss: 0.3291 - accuracy: 0.8723 - 1s/epoch - 17ms/step
# Epoch 396/500
# 72/72 - 1s - loss: 0.3196 - accuracy: 0.8741 - 1s/epoch - 17ms/step
# Epoch 397/500
# 72/72 - 1s - loss: 0.3081 - accuracy: 0.8780 - 1s/epoch - 17ms/step
# Epoch 398/500
# 72/72 - 1s - loss: 0.3206 - accuracy: 0.8752 - 1s/epoch - 20ms/step
# Epoch 399/500
# 72/72 - 2s - loss: 0.3107 - accuracy: 0.8808 - 2s/epoch - 21ms/step
# Epoch 400/500
# 72/72 - 1s - loss: 0.3151 - accuracy: 0.8782 - 1s/epoch - 17ms/step
# Epoch 401/500
# 72/72 - 1s - loss: 0.3096 - accuracy: 0.8810 - 1s/epoch - 17ms/step
# Epoch 402/500
# 72/72 - 1s - loss: 0.3044 - accuracy: 0.8816 - 1s/epoch - 18ms/step
# Epoch 403/500
# 72/72 - 1s - loss: 0.3051 - accuracy: 0.8840 - 1s/epoch - 18ms/step
# Epoch 404/500
# 72/72 - 1s - loss: 0.3144 - accuracy: 0.8796 - 1s/epoch - 18ms/step
# Epoch 405/500
# 72/72 - 1s - loss: 0.2977 - accuracy: 0.8845 - 1s/epoch - 17ms/step
# Epoch 406/500
# 72/72 - 1s - loss: 0.3057 - accuracy: 0.8795 - 1s/epoch - 18ms/step
# Epoch 407/500
# 72/72 - 1s - loss: 0.3093 - accuracy: 0.8813 - 1s/epoch - 19ms/step
# Epoch 408/500
# 72/72 - 2s - loss: 0.3108 - accuracy: 0.8743 - 2s/epoch - 21ms/step
# Epoch 409/500
# 72/72 - 1s - loss: 0.2982 - accuracy: 0.8825 - 1s/epoch - 18ms/step
# Epoch 410/500
# 72/72 - 1s - loss: 0.3035 - accuracy: 0.8811 - 1s/epoch - 17ms/step
# Epoch 411/500
# 72/72 - 1s - loss: 0.3056 - accuracy: 0.8824 - 1s/epoch - 17ms/step
# Epoch 412/500
# 72/72 - 1s - loss: 0.2939 - accuracy: 0.8849 - 1s/epoch - 17ms/step
# Epoch 413/500
# 72/72 - 1s - loss: 0.2973 - accuracy: 0.8859 - 1s/epoch - 18ms/step
# Epoch 414/500
# 72/72 - 1s - loss: 0.2986 - accuracy: 0.8778 - 1s/epoch - 18ms/step
# Epoch 415/500
# 72/72 - 1s - loss: 0.2999 - accuracy: 0.8847 - 1s/epoch - 18ms/step
# Epoch 416/500
# 72/72 - 1s - loss: 0.3047 - accuracy: 0.8778 - 1s/epoch - 18ms/step
# Epoch 417/500
# 72/72 - 1s - loss: 0.3017 - accuracy: 0.8816 - 1s/epoch - 21ms/step
# Epoch 418/500
# 72/72 - 1s - loss: 0.3403 - accuracy: 0.8666 - 1s/epoch - 19ms/step
# Epoch 419/500
# 72/72 - 1s - loss: 0.3584 - accuracy: 0.8607 - 1s/epoch - 17ms/step
# Epoch 420/500
# 72/72 - 1s - loss: 0.3189 - accuracy: 0.8767 - 1s/epoch - 17ms/step
# Epoch 421/500
# 72/72 - 1s - loss: 0.3028 - accuracy: 0.8832 - 1s/epoch - 17ms/step
# Epoch 422/500
# 72/72 - 1s - loss: 0.2918 - accuracy: 0.8861 - 1s/epoch - 17ms/step
# Epoch 423/500
# 72/72 - 1s - loss: 0.3064 - accuracy: 0.8813 - 1s/epoch - 17ms/step
# Epoch 424/500
# 72/72 - 1s - loss: 0.3004 - accuracy: 0.8847 - 1s/epoch - 17ms/step
# Epoch 425/500
# 72/72 - 1s - loss: 0.2866 - accuracy: 0.8892 - 1s/epoch - 18ms/step
# Epoch 426/500
# 72/72 - 1s - loss: 0.3058 - accuracy: 0.8838 - 1s/epoch - 20ms/step
# Epoch 427/500
# 72/72 - 2s - loss: 0.2875 - accuracy: 0.8926 - 2s/epoch - 21ms/step
# Epoch 428/500
# 72/72 - 1s - loss: 0.2878 - accuracy: 0.8862 - 1s/epoch - 17ms/step
# Epoch 429/500
# 72/72 - 1s - loss: 0.2923 - accuracy: 0.8891 - 1s/epoch - 17ms/step
# Epoch 430/500
# 72/72 - 1s - loss: 0.2915 - accuracy: 0.8875 - 1s/epoch - 17ms/step
# Epoch 431/500
# 72/72 - 1s - loss: 0.2812 - accuracy: 0.8905 - 1s/epoch - 17ms/step
# Epoch 432/500
# 72/72 - 1s - loss: 0.2887 - accuracy: 0.8937 - 1s/epoch - 17ms/step
# Epoch 433/500
# 72/72 - 1s - loss: 0.2923 - accuracy: 0.8874 - 1s/epoch - 17ms/step
# Epoch 434/500
# 72/72 - 1s - loss: 0.2835 - accuracy: 0.8918 - 1s/epoch - 17ms/step
# Epoch 435/500
# 72/72 - 1s - loss: 0.2825 - accuracy: 0.8901 - 1s/epoch - 19ms/step
# Epoch 436/500
# 72/72 - 2s - loss: 0.2939 - accuracy: 0.8857 - 2s/epoch - 21ms/step
# Epoch 437/500
# 72/72 - 1s - loss: 0.2801 - accuracy: 0.8902 - 1s/epoch - 18ms/step
# Epoch 438/500
# 72/72 - 1s - loss: 0.2804 - accuracy: 0.8908 - 1s/epoch - 17ms/step
# Epoch 439/500
# 72/72 - 1s - loss: 0.2829 - accuracy: 0.8908 - 1s/epoch - 18ms/step
# Epoch 440/500
# 72/72 - 1s - loss: 0.2864 - accuracy: 0.8893 - 1s/epoch - 17ms/step
# Epoch 441/500
# 72/72 - 1s - loss: 0.2821 - accuracy: 0.8895 - 1s/epoch - 17ms/step
# Epoch 442/500
# 72/72 - 1s - loss: 0.2789 - accuracy: 0.8942 - 1s/epoch - 18ms/step
# Epoch 443/500
# 72/72 - 1s - loss: 0.2810 - accuracy: 0.8910 - 1s/epoch - 17ms/step
# Epoch 444/500
# 72/72 - 1s - loss: 0.2716 - accuracy: 0.8942 - 1s/epoch - 18ms/step
# Epoch 445/500
# 72/72 - 2s - loss: 0.2743 - accuracy: 0.8935 - 2s/epoch - 22ms/step
# Epoch 446/500
# 72/72 - 1s - loss: 0.2667 - accuracy: 0.8997 - 1s/epoch - 20ms/step
# Epoch 447/500
# 72/72 - 1s - loss: 0.2770 - accuracy: 0.8951 - 1s/epoch - 17ms/step
# Epoch 448/500
# 72/72 - 1s - loss: 0.2689 - accuracy: 0.8989 - 1s/epoch - 18ms/step
# Epoch 449/500
# 72/72 - 1s - loss: 0.2694 - accuracy: 0.8987 - 1s/epoch - 17ms/step
# Epoch 450/500
# 72/72 - 1s - loss: 0.2748 - accuracy: 0.8938 - 1s/epoch - 18ms/step
# Epoch 451/500
# 72/72 - 1s - loss: 0.2780 - accuracy: 0.8932 - 1s/epoch - 17ms/step
# Epoch 452/500
# 72/72 - 1s - loss: 0.2656 - accuracy: 0.8993 - 1s/epoch - 17ms/step
# Epoch 453/500
# 72/72 - 1s - loss: 0.2730 - accuracy: 0.8962 - 1s/epoch - 18ms/step
# Epoch 454/500
# 72/72 - 1s - loss: 0.2722 - accuracy: 0.8933 - 1s/epoch - 19ms/step
# Epoch 455/500
# 72/72 - 1s - loss: 0.2722 - accuracy: 0.8933 - 1s/epoch - 21ms/step
# Epoch 456/500
# 72/72 - 1s - loss: 0.2602 - accuracy: 0.9034 - 1s/epoch - 18ms/step
# Epoch 457/500
# 72/72 - 1s - loss: 0.2626 - accuracy: 0.9003 - 1s/epoch - 17ms/step
# Epoch 458/500
# 72/72 - 1s - loss: 0.2794 - accuracy: 0.8918 - 1s/epoch - 17ms/step
# Epoch 459/500
# 72/72 - 1s - loss: 0.2583 - accuracy: 0.9022 - 1s/epoch - 17ms/step
# Epoch 460/500
# 72/72 - 1s - loss: 0.2599 - accuracy: 0.9007 - 1s/epoch - 17ms/step
# Epoch 461/500
# 72/72 - 1s - loss: 0.2653 - accuracy: 0.8998 - 1s/epoch - 17ms/step
# Epoch 462/500
# 72/72 - 1s - loss: 0.2700 - accuracy: 0.8951 - 1s/epoch - 17ms/step
# Epoch 463/500
# 72/72 - 1s - loss: 0.2585 - accuracy: 0.9022 - 1s/epoch - 18ms/step
# Epoch 464/500
# 72/72 - 2s - loss: 0.2925 - accuracy: 0.8862 - 2s/epoch - 21ms/step
# Epoch 465/500
# 72/72 - 1s - loss: 0.2693 - accuracy: 0.8972 - 1s/epoch - 19ms/step
# Epoch 466/500
# 72/72 - 1s - loss: 0.2705 - accuracy: 0.9004 - 1s/epoch - 18ms/step
# Epoch 467/500
# 72/72 - 1s - loss: 0.2623 - accuracy: 0.9014 - 1s/epoch - 18ms/step
# Epoch 468/500
# 72/72 - 1s - loss: 0.2553 - accuracy: 0.9061 - 1s/epoch - 17ms/step
# Epoch 469/500
# 72/72 - 1s - loss: 0.2738 - accuracy: 0.8930 - 1s/epoch - 17ms/step
# Epoch 470/500
# 72/72 - 1s - loss: 0.2726 - accuracy: 0.8938 - 1s/epoch - 17ms/step
# Epoch 471/500
# 72/72 - 1s - loss: 0.2776 - accuracy: 0.8904 - 1s/epoch - 18ms/step
# Epoch 472/500
# 72/72 - 1s - loss: 0.2637 - accuracy: 0.8973 - 1s/epoch - 18ms/step
# Epoch 473/500
# 72/72 - 1s - loss: 0.2591 - accuracy: 0.9026 - 1s/epoch - 20ms/step
# Epoch 474/500
# 72/72 - 1s - loss: 0.2609 - accuracy: 0.8996 - 1s/epoch - 20ms/step
# Epoch 475/500
# 72/72 - 1s - loss: 0.2670 - accuracy: 0.9001 - 1s/epoch - 17ms/step
# Epoch 476/500
# 72/72 - 1s - loss: 0.2576 - accuracy: 0.9023 - 1s/epoch - 17ms/step
# Epoch 477/500
# 72/72 - 1s - loss: 0.2623 - accuracy: 0.9002 - 1s/epoch - 17ms/step
# Epoch 478/500
# 72/72 - 1s - loss: 0.2695 - accuracy: 0.8991 - 1s/epoch - 17ms/step
# Epoch 479/500
# 72/72 - 1s - loss: 0.2534 - accuracy: 0.9055 - 1s/epoch - 17ms/step
# Epoch 480/500
# 72/72 - 1s - loss: 0.2484 - accuracy: 0.9075 - 1s/epoch - 17ms/step
# Epoch 481/500
# 72/72 - 1s - loss: 0.2509 - accuracy: 0.9060 - 1s/epoch - 17ms/step
# Epoch 482/500
# 72/72 - 1s - loss: 0.2564 - accuracy: 0.9032 - 1s/epoch - 19ms/step
# Epoch 483/500
# 72/72 - 2s - loss: 0.2577 - accuracy: 0.9035 - 2s/epoch - 21ms/step
# Epoch 484/500
# 72/72 - 1s - loss: 0.2526 - accuracy: 0.9024 - 1s/epoch - 18ms/step
# Epoch 485/500
# 72/72 - 1s - loss: 0.2495 - accuracy: 0.9038 - 1s/epoch - 18ms/step
# Epoch 486/500
# 72/72 - 1s - loss: 0.2578 - accuracy: 0.9024 - 1s/epoch - 17ms/step
# Epoch 487/500
# 72/72 - 1s - loss: 0.2626 - accuracy: 0.8999 - 1s/epoch - 17ms/step
# Epoch 488/500
# 72/72 - 1s - loss: 0.2663 - accuracy: 0.9029 - 1s/epoch - 17ms/step
# Epoch 489/500
# 72/72 - 1s - loss: 0.2575 - accuracy: 0.9023 - 1s/epoch - 17ms/step
# Epoch 490/500
# 72/72 - 1s - loss: 0.2368 - accuracy: 0.9121 - 1s/epoch - 18ms/step
# Epoch 491/500
# 72/72 - 1s - loss: 0.2698 - accuracy: 0.9007 - 1s/epoch - 17ms/step
# Epoch 492/500
# 72/72 - 2s - loss: 0.2536 - accuracy: 0.9083 - 2s/epoch - 21ms/step
# Epoch 493/500
# 72/72 - 1s - loss: 0.2494 - accuracy: 0.9076 - 1s/epoch - 19ms/step
# Epoch 494/500
# 72/72 - 1s - loss: 0.2467 - accuracy: 0.9079 - 1s/epoch - 18ms/step
# Epoch 495/500
# 72/72 - 1s - loss: 0.2441 - accuracy: 0.9051 - 1s/epoch - 17ms/step
# Epoch 496/500
# 72/72 - 1s - loss: 0.2405 - accuracy: 0.9074 - 1s/epoch - 17ms/step
# Epoch 497/500
# 72/72 - 1s - loss: 0.2469 - accuracy: 0.9052 - 1s/epoch - 18ms/step
# Epoch 498/500
# 72/72 - 1s - loss: 0.2428 - accuracy: 0.9065 - 1s/epoch - 17ms/step
# Epoch 499/500
# 72/72 - 1s - loss: 0.2499 - accuracy: 0.9064 - 1s/epoch - 18ms/step
# Epoch 500/500
# 72/72 - 1s - loss: 0.2624 - accuracy: 0.9025 - 1s/epoch - 17ms/step
# 72/72 [==============================] - 1s 8ms/step
# 72/72 [==============================] - 0s 6ms/step
# 72/72 [==============================] - 0s 6ms/step
# accuracy_score: 0.7157
# cohen_kappa_score: 0.6446
# log_loss: 0.8602
# zero_one_loss: 0.2843
# hemming_loss: 0.2843
# matthews_corrcoef: 0.6469
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.5738232135772705
# 72/72 [==============================] - 1s 7ms/step - loss: 0.8602 - accuracy: 0.7157
# 72/72 [==============================] - 0s 6ms/step
# Test runtime: 1.8903062343597412
# 72/72 [==============================] - 1s 7ms/step
# 72/72 [==============================] - 1s 9ms/step - loss: 0.8602 - accuracy: 0.7157
# 72/72 [==============================] - 1s 8ms/step - loss: 0.8602 - accuracy: 0.7157
# 72/72 [==============================] - 0s 6ms/step
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8602 - accuracy: 0.7157
# 72/72 [==============================] - 0s 6ms/step
