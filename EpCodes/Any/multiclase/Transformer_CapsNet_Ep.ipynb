# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

import math

# %%
data_path6 = '/content/Epileptic Seizure Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  Labels[i] = Labels[i]-1

# %%
Labels
# Out:
# array([3, 0, 4, ..., 4, 2, 3])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 3    2300
# 0    2300
# 4    2300
# 1    2300
# 2    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, Labels, test_size=0.2, stratify=Labels, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (9200, 178)
# Train labels shape: (9200,)
# Test data shape: (2300, 178)
# Test labels shape: (2300,)

# %%
X_train.shape
# Out:
# (9200, 178)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (9200, 178, 1)

# %%
#classes
classes = [0, 1, 2, 3, 4]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %% [markdown]
# ## Transformer

# %%
# OPTIMIZER
LEARNING_RATE_2 = 1e-3
WEIGHT_DECAY_2 = 1e-4
LAYER_NORM_EPS_2 = 1e-6
PROJECTION_DIM_2 = 512 # no se puede modificar
NUM_HEADS_2 = 8
NUM_LAYERS_2 = 1
MLP_UNITS_2 = [
    PROJECTION_DIM_2 * 2,
    PROJECTION_DIM_2
]
def mlp(x, dropout_rate, hidden_units):
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
def transformer_2(encoded_patches):

    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS_2, key_dim=PROJECTION_DIM_2, dropout=0.1
    )(x1, x1)

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS_2, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x4, x2])
    return encoded_patches

def Transform_sh_2(inputs):
      # Iterate over the number of layers and stack up blocks of
      # Transformer.
    for i in range(NUM_LAYERS_2):
          # Add a Transformer block.
        encoded_patches = transformer_2(inputs)

    return encoded_patches

# %% [markdown]
# ## CapsNet

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=5
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,2,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 2, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %% [markdown]
# ## Transformer_Caps_Net

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  CVT1=Transform_sh_2(Pool_1)
  representation = tf.keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(CVT1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(representation)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7f8f1441db40>)
# Epoch 1/500
# 72/72 - 28s - loss: 1.2147 - accuracy: 0.4490 - 28s/epoch - 383ms/step
# Epoch 2/500
# 72/72 - 2s - loss: 0.9935 - accuracy: 0.5623 - 2s/epoch - 31ms/step
# Epoch 3/500
# 72/72 - 2s - loss: 0.9239 - accuracy: 0.5833 - 2s/epoch - 30ms/step
# Epoch 4/500
# 72/72 - 2s - loss: 0.8351 - accuracy: 0.6147 - 2s/epoch - 30ms/step
# Epoch 5/500
# 72/72 - 2s - loss: 0.7601 - accuracy: 0.6525 - 2s/epoch - 30ms/step
# Epoch 6/500
# 72/72 - 2s - loss: 0.7359 - accuracy: 0.6614 - 2s/epoch - 30ms/step
# Epoch 7/500
# 72/72 - 2s - loss: 0.7027 - accuracy: 0.6708 - 2s/epoch - 31ms/step
# Epoch 8/500
# 72/72 - 2s - loss: 0.6812 - accuracy: 0.6795 - 2s/epoch - 30ms/step
# Epoch 9/500
# 72/72 - 2s - loss: 0.6812 - accuracy: 0.6758 - 2s/epoch - 30ms/step
# Epoch 10/500
# 72/72 - 2s - loss: 0.6436 - accuracy: 0.6896 - 2s/epoch - 31ms/step
# Epoch 11/500
# 72/72 - 2s - loss: 0.6339 - accuracy: 0.7039 - 2s/epoch - 31ms/step
# Epoch 12/500
# 72/72 - 2s - loss: 0.6126 - accuracy: 0.7083 - 2s/epoch - 31ms/step
# Epoch 13/500
# 72/72 - 2s - loss: 0.6091 - accuracy: 0.7120 - 2s/epoch - 31ms/step
# Epoch 14/500
# 72/72 - 2s - loss: 0.6068 - accuracy: 0.7117 - 2s/epoch - 31ms/step
# Epoch 15/500
# 72/72 - 2s - loss: 0.6133 - accuracy: 0.7109 - 2s/epoch - 31ms/step
# Epoch 16/500
# 72/72 - 2s - loss: 0.5898 - accuracy: 0.7203 - 2s/epoch - 31ms/step
# Epoch 17/500
# 72/72 - 2s - loss: 0.6190 - accuracy: 0.7075 - 2s/epoch - 31ms/step
# Epoch 18/500
# 72/72 - 2s - loss: 0.5894 - accuracy: 0.7191 - 2s/epoch - 33ms/step
# Epoch 19/500
# 72/72 - 2s - loss: 0.5605 - accuracy: 0.7278 - 2s/epoch - 32ms/step
# Epoch 20/500
# 72/72 - 2s - loss: 0.5613 - accuracy: 0.7320 - 2s/epoch - 31ms/step
# Epoch 21/500
# 72/72 - 2s - loss: 0.5555 - accuracy: 0.7297 - 2s/epoch - 31ms/step
# Epoch 22/500
# 72/72 - 2s - loss: 0.5550 - accuracy: 0.7284 - 2s/epoch - 31ms/step
# Epoch 23/500
# 72/72 - 2s - loss: 0.5549 - accuracy: 0.7316 - 2s/epoch - 32ms/step
# Epoch 24/500
# 72/72 - 2s - loss: 0.5184 - accuracy: 0.7451 - 2s/epoch - 31ms/step
# Epoch 25/500
# 72/72 - 2s - loss: 0.5412 - accuracy: 0.7420 - 2s/epoch - 31ms/step
# Epoch 26/500
# 72/72 - 2s - loss: 0.5475 - accuracy: 0.7390 - 2s/epoch - 31ms/step
# Epoch 27/500
# 72/72 - 2s - loss: 0.5432 - accuracy: 0.7367 - 2s/epoch - 31ms/step
# Epoch 28/500
# 72/72 - 2s - loss: 0.5149 - accuracy: 0.7478 - 2s/epoch - 32ms/step
# Epoch 29/500
# 72/72 - 2s - loss: 0.4873 - accuracy: 0.7638 - 2s/epoch - 32ms/step
# Epoch 30/500
# 72/72 - 2s - loss: 0.4981 - accuracy: 0.7617 - 2s/epoch - 31ms/step
# Epoch 31/500
# 72/72 - 2s - loss: 0.5076 - accuracy: 0.7534 - 2s/epoch - 31ms/step
# Epoch 32/500
# 72/72 - 2s - loss: 0.4760 - accuracy: 0.7675 - 2s/epoch - 32ms/step
# Epoch 33/500
# 72/72 - 2s - loss: 0.4827 - accuracy: 0.7685 - 2s/epoch - 32ms/step
# Epoch 34/500
# 72/72 - 2s - loss: 0.4608 - accuracy: 0.7810 - 2s/epoch - 32ms/step
# Epoch 35/500
# 72/72 - 2s - loss: 0.4613 - accuracy: 0.7778 - 2s/epoch - 32ms/step
# Epoch 36/500
# 72/72 - 2s - loss: 0.4653 - accuracy: 0.7800 - 2s/epoch - 32ms/step
# Epoch 37/500
# 72/72 - 2s - loss: 0.4424 - accuracy: 0.7886 - 2s/epoch - 32ms/step
# Epoch 38/500
# 72/72 - 2s - loss: 0.4915 - accuracy: 0.7708 - 2s/epoch - 32ms/step
# Epoch 39/500
# 72/72 - 2s - loss: 0.4807 - accuracy: 0.7784 - 2s/epoch - 32ms/step
# Epoch 40/500
# 72/72 - 2s - loss: 0.4329 - accuracy: 0.7903 - 2s/epoch - 32ms/step
# Epoch 41/500
# 72/72 - 2s - loss: 0.4384 - accuracy: 0.7948 - 2s/epoch - 32ms/step
# Epoch 42/500
# 72/72 - 2s - loss: 0.4265 - accuracy: 0.7971 - 2s/epoch - 32ms/step
# Epoch 43/500
# 72/72 - 2s - loss: 0.4139 - accuracy: 0.8045 - 2s/epoch - 32ms/step
# Epoch 44/500
# 72/72 - 2s - loss: 0.4010 - accuracy: 0.8089 - 2s/epoch - 32ms/step
# Epoch 45/500
# 72/72 - 2s - loss: 0.3983 - accuracy: 0.8151 - 2s/epoch - 32ms/step
# Epoch 46/500
# 72/72 - 2s - loss: 0.4011 - accuracy: 0.8133 - 2s/epoch - 32ms/step
# Epoch 47/500
# 72/72 - 2s - loss: 0.3926 - accuracy: 0.8149 - 2s/epoch - 32ms/step
# Epoch 48/500
# 72/72 - 2s - loss: 0.4206 - accuracy: 0.8035 - 2s/epoch - 33ms/step
# Epoch 49/500
# 72/72 - 2s - loss: 0.3958 - accuracy: 0.8121 - 2s/epoch - 32ms/step
# Epoch 50/500
# 72/72 - 2s - loss: 0.3830 - accuracy: 0.8217 - 2s/epoch - 32ms/step
# Epoch 51/500
# 72/72 - 2s - loss: 0.3858 - accuracy: 0.8142 - 2s/epoch - 32ms/step
# Epoch 52/500
# 72/72 - 2s - loss: 0.3970 - accuracy: 0.8145 - 2s/epoch - 33ms/step
# Epoch 53/500
# 72/72 - 2s - loss: 0.3681 - accuracy: 0.8263 - 2s/epoch - 33ms/step
# Epoch 54/500
# 72/72 - 2s - loss: 0.3671 - accuracy: 0.8302 - 2s/epoch - 33ms/step
# Epoch 55/500
# 72/72 - 2s - loss: 0.3629 - accuracy: 0.8255 - 2s/epoch - 33ms/step
# Epoch 56/500
# 72/72 - 2s - loss: 0.3768 - accuracy: 0.8241 - 2s/epoch - 33ms/step
# Epoch 57/500
# 72/72 - 2s - loss: 0.3642 - accuracy: 0.8326 - 2s/epoch - 33ms/step
# Epoch 58/500
# 72/72 - 2s - loss: 0.3623 - accuracy: 0.8334 - 2s/epoch - 33ms/step
# Epoch 59/500
# 72/72 - 2s - loss: 0.3472 - accuracy: 0.8380 - 2s/epoch - 33ms/step
# Epoch 60/500
# 72/72 - 2s - loss: 0.3404 - accuracy: 0.8463 - 2s/epoch - 33ms/step
# Epoch 61/500
# 72/72 - 2s - loss: 0.3412 - accuracy: 0.8396 - 2s/epoch - 33ms/step
# Epoch 62/500
# 72/72 - 2s - loss: 0.3397 - accuracy: 0.8409 - 2s/epoch - 33ms/step
# Epoch 63/500
# 72/72 - 2s - loss: 0.3411 - accuracy: 0.8399 - 2s/epoch - 33ms/step
# Epoch 64/500
# 72/72 - 2s - loss: 0.3265 - accuracy: 0.8502 - 2s/epoch - 33ms/step
# Epoch 65/500
# 72/72 - 2s - loss: 0.3319 - accuracy: 0.8477 - 2s/epoch - 33ms/step
# Epoch 66/500
# 72/72 - 2s - loss: 0.3298 - accuracy: 0.8486 - 2s/epoch - 33ms/step
# Epoch 67/500
# 72/72 - 2s - loss: 0.3227 - accuracy: 0.8547 - 2s/epoch - 33ms/step
# Epoch 68/500
# 72/72 - 2s - loss: 0.3238 - accuracy: 0.8501 - 2s/epoch - 34ms/step
# Epoch 69/500
# 72/72 - 2s - loss: 0.3195 - accuracy: 0.8518 - 2s/epoch - 33ms/step
# Epoch 70/500
# 72/72 - 2s - loss: 0.3207 - accuracy: 0.8511 - 2s/epoch - 33ms/step
# Epoch 71/500
# 72/72 - 2s - loss: 0.3157 - accuracy: 0.8554 - 2s/epoch - 33ms/step
# Epoch 72/500
# 72/72 - 2s - loss: 0.3141 - accuracy: 0.8497 - 2s/epoch - 33ms/step
# Epoch 73/500
# 72/72 - 2s - loss: 0.3040 - accuracy: 0.8590 - 2s/epoch - 33ms/step
# Epoch 74/500
# 72/72 - 2s - loss: 0.3135 - accuracy: 0.8588 - 2s/epoch - 33ms/step
# Epoch 75/500
# 72/72 - 2s - loss: 0.3063 - accuracy: 0.8618 - 2s/epoch - 33ms/step
# Epoch 76/500
# 72/72 - 2s - loss: 0.2950 - accuracy: 0.8648 - 2s/epoch - 33ms/step
# Epoch 77/500
# 72/72 - 2s - loss: 0.2953 - accuracy: 0.8634 - 2s/epoch - 33ms/step
# Epoch 78/500
# 72/72 - 2s - loss: 0.2840 - accuracy: 0.8687 - 2s/epoch - 33ms/step
# Epoch 79/500
# 72/72 - 2s - loss: 0.2783 - accuracy: 0.8739 - 2s/epoch - 33ms/step
# Epoch 80/500
# 72/72 - 2s - loss: 0.2668 - accuracy: 0.8784 - 2s/epoch - 33ms/step
# Epoch 81/500
# 72/72 - 2s - loss: 0.2812 - accuracy: 0.8712 - 2s/epoch - 33ms/step
# Epoch 82/500
# 72/72 - 2s - loss: 0.3162 - accuracy: 0.8620 - 2s/epoch - 33ms/step
# Epoch 83/500
# 72/72 - 2s - loss: 0.3508 - accuracy: 0.8411 - 2s/epoch - 33ms/step
# Epoch 84/500
# 72/72 - 2s - loss: 0.2892 - accuracy: 0.8696 - 2s/epoch - 33ms/step
# Epoch 85/500
# 72/72 - 2s - loss: 0.2797 - accuracy: 0.8734 - 2s/epoch - 33ms/step
# Epoch 86/500
# 72/72 - 2s - loss: 0.2714 - accuracy: 0.8768 - 2s/epoch - 33ms/step
# Epoch 87/500
# 72/72 - 2s - loss: 0.2683 - accuracy: 0.8795 - 2s/epoch - 33ms/step
# Epoch 88/500
# 72/72 - 2s - loss: 0.2535 - accuracy: 0.8847 - 2s/epoch - 33ms/step
# Epoch 89/500
# 72/72 - 2s - loss: 0.2611 - accuracy: 0.8829 - 2s/epoch - 33ms/step
# Epoch 90/500
# 72/72 - 2s - loss: 0.2492 - accuracy: 0.8904 - 2s/epoch - 33ms/step
# Epoch 91/500
# 72/72 - 2s - loss: 0.2712 - accuracy: 0.8775 - 2s/epoch - 33ms/step
# Epoch 92/500
# 72/72 - 2s - loss: 0.2551 - accuracy: 0.8873 - 2s/epoch - 33ms/step
# Epoch 93/500
# 72/72 - 2s - loss: 0.2587 - accuracy: 0.8873 - 2s/epoch - 33ms/step
# Epoch 94/500
# 72/72 - 2s - loss: 0.2446 - accuracy: 0.8937 - 2s/epoch - 33ms/step
# Epoch 95/500
# 72/72 - 2s - loss: 0.2464 - accuracy: 0.8891 - 2s/epoch - 33ms/step
# Epoch 96/500
# 72/72 - 2s - loss: 0.2406 - accuracy: 0.8938 - 2s/epoch - 33ms/step
# Epoch 97/500
# 72/72 - 2s - loss: 0.2387 - accuracy: 0.8927 - 2s/epoch - 33ms/step
# Epoch 98/500
# 72/72 - 2s - loss: 0.2373 - accuracy: 0.8935 - 2s/epoch - 33ms/step
# Epoch 99/500
# 72/72 - 2s - loss: 0.2446 - accuracy: 0.8929 - 2s/epoch - 33ms/step
# Epoch 100/500
# 72/72 - 2s - loss: 0.2332 - accuracy: 0.8968 - 2s/epoch - 33ms/step
# Epoch 101/500
# 72/72 - 2s - loss: 0.2248 - accuracy: 0.9054 - 2s/epoch - 33ms/step
# Epoch 102/500
# 72/72 - 2s - loss: 0.2306 - accuracy: 0.8975 - 2s/epoch - 33ms/step
# Epoch 103/500
# 72/72 - 2s - loss: 0.2259 - accuracy: 0.9015 - 2s/epoch - 33ms/step
# Epoch 104/500
# 72/72 - 2s - loss: 0.2382 - accuracy: 0.8960 - 2s/epoch - 33ms/step
# Epoch 105/500
# 72/72 - 2s - loss: 0.2170 - accuracy: 0.9096 - 2s/epoch - 33ms/step
# Epoch 106/500
# 72/72 - 2s - loss: 0.2277 - accuracy: 0.9022 - 2s/epoch - 33ms/step
# Epoch 107/500
# 72/72 - 2s - loss: 0.2160 - accuracy: 0.9051 - 2s/epoch - 33ms/step
# Epoch 108/500
# 72/72 - 2s - loss: 0.2071 - accuracy: 0.9113 - 2s/epoch - 33ms/step
# Epoch 109/500
# 72/72 - 2s - loss: 0.2060 - accuracy: 0.9127 - 2s/epoch - 33ms/step
# Epoch 110/500
# 72/72 - 2s - loss: 0.2210 - accuracy: 0.9055 - 2s/epoch - 33ms/step
# Epoch 111/500
# 72/72 - 2s - loss: 0.2035 - accuracy: 0.9128 - 2s/epoch - 33ms/step
# Epoch 112/500
# 72/72 - 2s - loss: 0.2049 - accuracy: 0.9139 - 2s/epoch - 33ms/step
# Epoch 113/500
# 72/72 - 2s - loss: 0.2101 - accuracy: 0.9130 - 2s/epoch - 33ms/step
# Epoch 114/500
# 72/72 - 2s - loss: 0.1993 - accuracy: 0.9166 - 2s/epoch - 33ms/step
# Epoch 115/500
# 72/72 - 2s - loss: 0.1942 - accuracy: 0.9178 - 2s/epoch - 33ms/step
# Epoch 116/500
# 72/72 - 2s - loss: 0.1965 - accuracy: 0.9192 - 2s/epoch - 33ms/step
# Epoch 117/500
# 72/72 - 2s - loss: 0.1927 - accuracy: 0.9201 - 2s/epoch - 33ms/step
# Epoch 118/500
# 72/72 - 2s - loss: 0.1933 - accuracy: 0.9215 - 2s/epoch - 33ms/step
# Epoch 119/500
# 72/72 - 2s - loss: 0.1847 - accuracy: 0.9218 - 2s/epoch - 33ms/step
# Epoch 120/500
# 72/72 - 2s - loss: 0.1887 - accuracy: 0.9223 - 2s/epoch - 33ms/step
# Epoch 121/500
# 72/72 - 2s - loss: 0.1766 - accuracy: 0.9299 - 2s/epoch - 33ms/step
# Epoch 122/500
# 72/72 - 2s - loss: 0.1754 - accuracy: 0.9271 - 2s/epoch - 33ms/step
# Epoch 123/500
# 72/72 - 2s - loss: 0.1856 - accuracy: 0.9249 - 2s/epoch - 33ms/step
# Epoch 124/500
# 72/72 - 2s - loss: 0.1810 - accuracy: 0.9259 - 2s/epoch - 33ms/step
# Epoch 125/500
# 72/72 - 2s - loss: 0.1669 - accuracy: 0.9295 - 2s/epoch - 33ms/step
# Epoch 126/500
# 72/72 - 2s - loss: 0.1882 - accuracy: 0.9233 - 2s/epoch - 33ms/step
# Epoch 127/500
# 72/72 - 2s - loss: 0.1740 - accuracy: 0.9290 - 2s/epoch - 33ms/step
# Epoch 128/500
# 72/72 - 2s - loss: 0.1653 - accuracy: 0.9337 - 2s/epoch - 33ms/step
# Epoch 129/500
# 72/72 - 2s - loss: 0.1690 - accuracy: 0.9295 - 2s/epoch - 33ms/step
# Epoch 130/500
# 72/72 - 2s - loss: 0.1742 - accuracy: 0.9299 - 2s/epoch - 33ms/step
# Epoch 131/500
# 72/72 - 2s - loss: 0.1562 - accuracy: 0.9378 - 2s/epoch - 33ms/step
# Epoch 132/500
# 72/72 - 2s - loss: 0.1591 - accuracy: 0.9341 - 2s/epoch - 33ms/step
# Epoch 133/500
# 72/72 - 2s - loss: 0.1607 - accuracy: 0.9383 - 2s/epoch - 33ms/step
# Epoch 134/500
# 72/72 - 2s - loss: 0.1599 - accuracy: 0.9360 - 2s/epoch - 33ms/step
# Epoch 135/500
# 72/72 - 2s - loss: 0.1498 - accuracy: 0.9418 - 2s/epoch - 33ms/step
# Epoch 136/500
# 72/72 - 2s - loss: 0.1571 - accuracy: 0.9392 - 2s/epoch - 33ms/step
# Epoch 137/500
# 72/72 - 2s - loss: 0.1567 - accuracy: 0.9384 - 2s/epoch - 33ms/step
# Epoch 138/500
# 72/72 - 2s - loss: 0.1490 - accuracy: 0.9433 - 2s/epoch - 33ms/step
# Epoch 139/500
# 72/72 - 2s - loss: 0.1466 - accuracy: 0.9409 - 2s/epoch - 33ms/step
# Epoch 140/500
# 72/72 - 2s - loss: 0.1478 - accuracy: 0.9433 - 2s/epoch - 33ms/step
# Epoch 141/500
# 72/72 - 2s - loss: 0.1382 - accuracy: 0.9453 - 2s/epoch - 33ms/step
# Epoch 142/500
# 72/72 - 2s - loss: 0.1393 - accuracy: 0.9453 - 2s/epoch - 33ms/step
# Epoch 143/500
# 72/72 - 2s - loss: 0.1397 - accuracy: 0.9452 - 2s/epoch - 33ms/step
# Epoch 144/500
# 72/72 - 2s - loss: 0.1423 - accuracy: 0.9448 - 2s/epoch - 33ms/step
# Epoch 145/500
# 72/72 - 2s - loss: 0.1509 - accuracy: 0.9397 - 2s/epoch - 33ms/step
# Epoch 146/500
# 72/72 - 2s - loss: 0.1334 - accuracy: 0.9475 - 2s/epoch - 33ms/step
# Epoch 147/500
# 72/72 - 2s - loss: 0.1325 - accuracy: 0.9453 - 2s/epoch - 33ms/step
# Epoch 148/500
# 72/72 - 2s - loss: 0.1396 - accuracy: 0.9474 - 2s/epoch - 33ms/step
# Epoch 149/500
# 72/72 - 2s - loss: 0.1428 - accuracy: 0.9446 - 2s/epoch - 33ms/step
# Epoch 150/500
# 72/72 - 2s - loss: 0.1298 - accuracy: 0.9515 - 2s/epoch - 33ms/step
# Epoch 151/500
# 72/72 - 2s - loss: 0.1234 - accuracy: 0.9533 - 2s/epoch - 33ms/step
# Epoch 152/500
# 72/72 - 2s - loss: 0.1174 - accuracy: 0.9561 - 2s/epoch - 33ms/step
# Epoch 153/500
# 72/72 - 2s - loss: 0.1198 - accuracy: 0.9530 - 2s/epoch - 33ms/step
# Epoch 154/500
# 72/72 - 2s - loss: 0.1389 - accuracy: 0.9485 - 2s/epoch - 33ms/step
# Epoch 155/500
# 72/72 - 2s - loss: 0.1323 - accuracy: 0.9479 - 2s/epoch - 33ms/step
# Epoch 156/500
# 72/72 - 2s - loss: 0.1226 - accuracy: 0.9534 - 2s/epoch - 33ms/step
# Epoch 157/500
# 72/72 - 2s - loss: 0.1199 - accuracy: 0.9536 - 2s/epoch - 33ms/step
# Epoch 158/500
# 72/72 - 2s - loss: 0.1180 - accuracy: 0.9558 - 2s/epoch - 33ms/step
# Epoch 159/500
# 72/72 - 2s - loss: 0.1098 - accuracy: 0.9573 - 2s/epoch - 33ms/step
# Epoch 160/500
# 72/72 - 2s - loss: 0.1268 - accuracy: 0.9508 - 2s/epoch - 33ms/step
# Epoch 161/500
# 72/72 - 2s - loss: 0.0951 - accuracy: 0.9647 - 2s/epoch - 33ms/step
# Epoch 162/500
# 72/72 - 2s - loss: 0.1171 - accuracy: 0.9553 - 2s/epoch - 33ms/step
# Epoch 163/500
# 72/72 - 2s - loss: 0.1243 - accuracy: 0.9539 - 2s/epoch - 33ms/step
# Epoch 164/500
# 72/72 - 2s - loss: 0.1151 - accuracy: 0.9557 - 2s/epoch - 33ms/step
# Epoch 165/500
# 72/72 - 2s - loss: 0.1148 - accuracy: 0.9563 - 2s/epoch - 33ms/step
# Epoch 166/500
# 72/72 - 2s - loss: 0.1216 - accuracy: 0.9559 - 2s/epoch - 33ms/step
# Epoch 167/500
# 72/72 - 2s - loss: 0.1059 - accuracy: 0.9623 - 2s/epoch - 33ms/step
# Epoch 168/500
# 72/72 - 2s - loss: 0.1166 - accuracy: 0.9553 - 2s/epoch - 33ms/step
# Epoch 169/500
# 72/72 - 2s - loss: 0.1029 - accuracy: 0.9610 - 2s/epoch - 33ms/step
# Epoch 170/500
# 72/72 - 2s - loss: 0.1051 - accuracy: 0.9611 - 2s/epoch - 33ms/step
# Epoch 171/500
# 72/72 - 2s - loss: 0.1226 - accuracy: 0.9559 - 2s/epoch - 33ms/step
# Epoch 172/500
# 72/72 - 2s - loss: 0.1158 - accuracy: 0.9579 - 2s/epoch - 33ms/step
# Epoch 173/500
# 72/72 - 2s - loss: 0.1038 - accuracy: 0.9610 - 2s/epoch - 33ms/step
# Epoch 174/500
# 72/72 - 2s - loss: 0.0951 - accuracy: 0.9639 - 2s/epoch - 33ms/step
# Epoch 175/500
# 72/72 - 2s - loss: 0.0981 - accuracy: 0.9658 - 2s/epoch - 33ms/step
# Epoch 176/500
# 72/72 - 2s - loss: 0.1182 - accuracy: 0.9562 - 2s/epoch - 33ms/step
# Epoch 177/500
# 72/72 - 2s - loss: 0.0973 - accuracy: 0.9648 - 2s/epoch - 33ms/step
# Epoch 178/500
# 72/72 - 2s - loss: 0.0890 - accuracy: 0.9691 - 2s/epoch - 33ms/step
# Epoch 179/500
# 72/72 - 2s - loss: 0.1038 - accuracy: 0.9614 - 2s/epoch - 33ms/step
# Epoch 180/500
# 72/72 - 2s - loss: 0.0946 - accuracy: 0.9667 - 2s/epoch - 33ms/step
# Epoch 181/500
# 72/72 - 2s - loss: 0.0890 - accuracy: 0.9671 - 2s/epoch - 33ms/step
# Epoch 182/500
# 72/72 - 2s - loss: 0.0875 - accuracy: 0.9689 - 2s/epoch - 33ms/step
# Epoch 183/500
# 72/72 - 2s - loss: 0.0907 - accuracy: 0.9680 - 2s/epoch - 33ms/step
# Epoch 184/500
# 72/72 - 2s - loss: 0.0839 - accuracy: 0.9700 - 2s/epoch - 33ms/step
# Epoch 185/500
# 72/72 - 2s - loss: 0.1017 - accuracy: 0.9624 - 2s/epoch - 33ms/step
# Epoch 186/500
# 72/72 - 2s - loss: 0.0850 - accuracy: 0.9683 - 2s/epoch - 33ms/step
# Epoch 187/500
# 72/72 - 2s - loss: 0.1029 - accuracy: 0.9639 - 2s/epoch - 33ms/step
# Epoch 188/500
# 72/72 - 2s - loss: 0.0779 - accuracy: 0.9722 - 2s/epoch - 33ms/step
# Epoch 189/500
# 72/72 - 2s - loss: 0.0853 - accuracy: 0.9697 - 2s/epoch - 33ms/step
# Epoch 190/500
# 72/72 - 2s - loss: 0.0966 - accuracy: 0.9664 - 2s/epoch - 33ms/step
# Epoch 191/500
# 72/72 - 2s - loss: 0.0799 - accuracy: 0.9714 - 2s/epoch - 33ms/step
# Epoch 192/500
# 72/72 - 2s - loss: 0.0800 - accuracy: 0.9715 - 2s/epoch - 33ms/step
# Epoch 193/500
# 72/72 - 2s - loss: 0.0886 - accuracy: 0.9685 - 2s/epoch - 33ms/step
# Epoch 194/500
# 72/72 - 2s - loss: 0.0792 - accuracy: 0.9711 - 2s/epoch - 33ms/step
# Epoch 195/500
# 72/72 - 2s - loss: 0.0771 - accuracy: 0.9733 - 2s/epoch - 34ms/step
# Epoch 196/500
# 72/72 - 2s - loss: 0.0920 - accuracy: 0.9674 - 2s/epoch - 33ms/step
# Epoch 197/500
# 72/72 - 2s - loss: 0.0857 - accuracy: 0.9697 - 2s/epoch - 33ms/step
# Epoch 198/500
# 72/72 - 2s - loss: 0.0765 - accuracy: 0.9711 - 2s/epoch - 33ms/step
# Epoch 199/500
# 72/72 - 2s - loss: 0.0966 - accuracy: 0.9649 - 2s/epoch - 33ms/step
# Epoch 200/500
# 72/72 - 2s - loss: 0.0843 - accuracy: 0.9700 - 2s/epoch - 33ms/step
# Epoch 201/500
# 72/72 - 2s - loss: 0.0728 - accuracy: 0.9725 - 2s/epoch - 33ms/step
# Epoch 202/500
# 72/72 - 2s - loss: 0.0761 - accuracy: 0.9742 - 2s/epoch - 33ms/step
# Epoch 203/500
# 72/72 - 2s - loss: 0.0747 - accuracy: 0.9755 - 2s/epoch - 33ms/step
# Epoch 204/500
# 72/72 - 2s - loss: 0.0757 - accuracy: 0.9724 - 2s/epoch - 33ms/step
# Epoch 205/500
# 72/72 - 2s - loss: 0.0736 - accuracy: 0.9742 - 2s/epoch - 33ms/step
# Epoch 206/500
# 72/72 - 2s - loss: 0.0790 - accuracy: 0.9737 - 2s/epoch - 33ms/step
# Epoch 207/500
# 72/72 - 2s - loss: 0.0794 - accuracy: 0.9720 - 2s/epoch - 33ms/step
# Epoch 208/500
# 72/72 - 2s - loss: 0.0705 - accuracy: 0.9750 - 2s/epoch - 33ms/step
# Epoch 209/500
# 72/72 - 2s - loss: 0.0728 - accuracy: 0.9743 - 2s/epoch - 33ms/step
# Epoch 210/500
# 72/72 - 2s - loss: 0.0790 - accuracy: 0.9717 - 2s/epoch - 33ms/step
# Epoch 211/500
# 72/72 - 2s - loss: 0.0639 - accuracy: 0.9759 - 2s/epoch - 33ms/step
# Epoch 212/500
# 72/72 - 2s - loss: 0.0785 - accuracy: 0.9732 - 2s/epoch - 33ms/step
# Epoch 213/500
# 72/72 - 2s - loss: 0.0817 - accuracy: 0.9727 - 2s/epoch - 33ms/step
# Epoch 214/500
# 72/72 - 2s - loss: 0.0812 - accuracy: 0.9708 - 2s/epoch - 33ms/step
# Epoch 215/500
# 72/72 - 2s - loss: 0.0658 - accuracy: 0.9776 - 2s/epoch - 33ms/step
# Epoch 216/500
# 72/72 - 2s - loss: 0.0752 - accuracy: 0.9746 - 2s/epoch - 33ms/step
# Epoch 217/500
# 72/72 - 2s - loss: 0.0664 - accuracy: 0.9773 - 2s/epoch - 33ms/step
# Epoch 218/500
# 72/72 - 2s - loss: 0.0623 - accuracy: 0.9790 - 2s/epoch - 33ms/step
# Epoch 219/500
# 72/72 - 2s - loss: 0.0645 - accuracy: 0.9761 - 2s/epoch - 33ms/step
# Epoch 220/500
# 72/72 - 2s - loss: 0.0699 - accuracy: 0.9750 - 2s/epoch - 33ms/step
# Epoch 221/500
# 72/72 - 2s - loss: 0.0771 - accuracy: 0.9736 - 2s/epoch - 33ms/step
# Epoch 222/500
# 72/72 - 2s - loss: 0.0583 - accuracy: 0.9790 - 2s/epoch - 33ms/step
# Epoch 223/500
# 72/72 - 2s - loss: 0.0773 - accuracy: 0.9724 - 2s/epoch - 33ms/step
# Epoch 224/500
# 72/72 - 2s - loss: 0.0648 - accuracy: 0.9768 - 2s/epoch - 33ms/step
# Epoch 225/500
# 72/72 - 2s - loss: 0.0675 - accuracy: 0.9778 - 2s/epoch - 33ms/step
# Epoch 226/500
# 72/72 - 2s - loss: 0.0675 - accuracy: 0.9770 - 2s/epoch - 33ms/step
# Epoch 227/500
# 72/72 - 2s - loss: 0.0621 - accuracy: 0.9777 - 2s/epoch - 33ms/step
# Epoch 228/500
# 72/72 - 2s - loss: 0.0560 - accuracy: 0.9815 - 2s/epoch - 33ms/step
# Epoch 229/500
# 72/72 - 2s - loss: 0.0644 - accuracy: 0.9783 - 2s/epoch - 33ms/step
# Epoch 230/500
# 72/72 - 2s - loss: 0.0655 - accuracy: 0.9741 - 2s/epoch - 33ms/step
# Epoch 231/500
# 72/72 - 2s - loss: 0.0597 - accuracy: 0.9798 - 2s/epoch - 33ms/step
# Epoch 232/500
# 72/72 - 2s - loss: 0.0577 - accuracy: 0.9791 - 2s/epoch - 33ms/step
# Epoch 233/500
# 72/72 - 2s - loss: 0.0693 - accuracy: 0.9761 - 2s/epoch - 33ms/step
# Epoch 234/500
# 72/72 - 2s - loss: 0.0628 - accuracy: 0.9786 - 2s/epoch - 33ms/step
# Epoch 235/500
# 72/72 - 2s - loss: 0.0703 - accuracy: 0.9773 - 2s/epoch - 33ms/step
# Epoch 236/500
# 72/72 - 2s - loss: 0.0597 - accuracy: 0.9809 - 2s/epoch - 33ms/step
# Epoch 237/500
# 72/72 - 2s - loss: 0.0633 - accuracy: 0.9790 - 2s/epoch - 33ms/step
# Epoch 238/500
# 72/72 - 2s - loss: 0.0602 - accuracy: 0.9785 - 2s/epoch - 33ms/step
# Epoch 239/500
# 72/72 - 2s - loss: 0.0599 - accuracy: 0.9783 - 2s/epoch - 33ms/step
# Epoch 240/500
# 72/72 - 2s - loss: 0.0575 - accuracy: 0.9815 - 2s/epoch - 33ms/step
# Epoch 241/500
# 72/72 - 2s - loss: 0.0654 - accuracy: 0.9778 - 2s/epoch - 33ms/step
# Epoch 242/500
# 72/72 - 2s - loss: 0.0497 - accuracy: 0.9835 - 2s/epoch - 33ms/step
# Epoch 243/500
# 72/72 - 2s - loss: 0.0574 - accuracy: 0.9793 - 2s/epoch - 33ms/step
# Epoch 244/500
# 72/72 - 2s - loss: 0.0637 - accuracy: 0.9787 - 2s/epoch - 33ms/step
# Epoch 245/500
# 72/72 - 2s - loss: 0.0583 - accuracy: 0.9804 - 2s/epoch - 33ms/step
# Epoch 246/500
# 72/72 - 2s - loss: 0.0505 - accuracy: 0.9835 - 2s/epoch - 33ms/step
# Epoch 247/500
# 72/72 - 2s - loss: 0.0649 - accuracy: 0.9784 - 2s/epoch - 33ms/step
# Epoch 248/500
# 72/72 - 2s - loss: 0.0808 - accuracy: 0.9720 - 2s/epoch - 33ms/step
# Epoch 249/500
# 72/72 - 2s - loss: 0.0583 - accuracy: 0.9815 - 2s/epoch - 33ms/step
# Epoch 250/500
# 72/72 - 2s - loss: 0.0516 - accuracy: 0.9836 - 2s/epoch - 33ms/step
# Epoch 251/500
# 72/72 - 2s - loss: 0.0532 - accuracy: 0.9816 - 2s/epoch - 33ms/step
# Epoch 252/500
# 72/72 - 2s - loss: 0.0564 - accuracy: 0.9807 - 2s/epoch - 33ms/step
# Epoch 253/500
# 72/72 - 2s - loss: 0.0683 - accuracy: 0.9754 - 2s/epoch - 33ms/step
# Epoch 254/500
# 72/72 - 2s - loss: 0.0555 - accuracy: 0.9791 - 2s/epoch - 33ms/step
# Epoch 255/500
# 72/72 - 2s - loss: 0.0556 - accuracy: 0.9820 - 2s/epoch - 33ms/step
# Epoch 256/500
# 72/72 - 2s - loss: 0.0557 - accuracy: 0.9825 - 2s/epoch - 33ms/step
# Epoch 257/500
# 72/72 - 2s - loss: 0.0514 - accuracy: 0.9812 - 2s/epoch - 33ms/step
# Epoch 258/500
# 72/72 - 2s - loss: 0.0435 - accuracy: 0.9850 - 2s/epoch - 33ms/step
# Epoch 259/500
# 72/72 - 2s - loss: 0.0551 - accuracy: 0.9822 - 2s/epoch - 33ms/step
# Epoch 260/500
# 72/72 - 2s - loss: 0.0537 - accuracy: 0.9813 - 2s/epoch - 33ms/step
# Epoch 261/500
# 72/72 - 2s - loss: 0.0540 - accuracy: 0.9824 - 2s/epoch - 33ms/step
# Epoch 262/500
# 72/72 - 2s - loss: 0.0589 - accuracy: 0.9812 - 2s/epoch - 33ms/step
# Epoch 263/500
# 72/72 - 2s - loss: 0.0680 - accuracy: 0.9773 - 2s/epoch - 33ms/step
# Epoch 264/500
# 72/72 - 2s - loss: 0.0449 - accuracy: 0.9855 - 2s/epoch - 33ms/step
# Epoch 265/500
# 72/72 - 2s - loss: 0.0530 - accuracy: 0.9825 - 2s/epoch - 33ms/step
# Epoch 266/500
# 72/72 - 2s - loss: 0.0509 - accuracy: 0.9839 - 2s/epoch - 33ms/step
# Epoch 267/500
# 72/72 - 2s - loss: 0.0489 - accuracy: 0.9838 - 2s/epoch - 33ms/step
# Epoch 268/500
# 72/72 - 2s - loss: 0.0516 - accuracy: 0.9836 - 2s/epoch - 33ms/step
# Epoch 269/500
# 72/72 - 2s - loss: 0.0497 - accuracy: 0.9836 - 2s/epoch - 33ms/step
# Epoch 270/500
# 72/72 - 2s - loss: 0.0592 - accuracy: 0.9800 - 2s/epoch - 33ms/step
# Epoch 271/500
# 72/72 - 2s - loss: 0.0491 - accuracy: 0.9817 - 2s/epoch - 33ms/step
# Epoch 272/500
# 72/72 - 2s - loss: 0.0489 - accuracy: 0.9847 - 2s/epoch - 33ms/step
# Epoch 273/500
# 72/72 - 2s - loss: 0.0539 - accuracy: 0.9822 - 2s/epoch - 33ms/step
# Epoch 274/500
# 72/72 - 2s - loss: 0.0421 - accuracy: 0.9849 - 2s/epoch - 33ms/step
# Epoch 275/500
# 72/72 - 2s - loss: 0.0449 - accuracy: 0.9842 - 2s/epoch - 33ms/step
# Epoch 276/500
# 72/72 - 2s - loss: 0.0447 - accuracy: 0.9848 - 2s/epoch - 33ms/step
# Epoch 277/500
# 72/72 - 2s - loss: 0.0540 - accuracy: 0.9801 - 2s/epoch - 33ms/step
# Epoch 278/500
# 72/72 - 2s - loss: 0.0572 - accuracy: 0.9805 - 2s/epoch - 33ms/step
# Epoch 279/500
# 72/72 - 2s - loss: 0.0501 - accuracy: 0.9827 - 2s/epoch - 33ms/step
# Epoch 280/500
# 72/72 - 2s - loss: 0.0433 - accuracy: 0.9846 - 2s/epoch - 33ms/step
# Epoch 281/500
# 72/72 - 2s - loss: 0.0570 - accuracy: 0.9808 - 2s/epoch - 33ms/step
# Epoch 282/500
# 72/72 - 2s - loss: 0.0389 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 283/500
# 72/72 - 2s - loss: 0.0593 - accuracy: 0.9799 - 2s/epoch - 33ms/step
# Epoch 284/500
# 72/72 - 2s - loss: 0.0502 - accuracy: 0.9837 - 2s/epoch - 33ms/step
# Epoch 285/500
# 72/72 - 2s - loss: 0.0480 - accuracy: 0.9838 - 2s/epoch - 33ms/step
# Epoch 286/500
# 72/72 - 2s - loss: 0.0452 - accuracy: 0.9842 - 2s/epoch - 33ms/step
# Epoch 287/500
# 72/72 - 2s - loss: 0.0484 - accuracy: 0.9832 - 2s/epoch - 33ms/step
# Epoch 288/500
# 72/72 - 2s - loss: 0.0527 - accuracy: 0.9826 - 2s/epoch - 33ms/step
# Epoch 289/500
# 72/72 - 2s - loss: 0.0431 - accuracy: 0.9845 - 2s/epoch - 33ms/step
# Epoch 290/500
# 72/72 - 2s - loss: 0.0437 - accuracy: 0.9848 - 2s/epoch - 33ms/step
# Epoch 291/500
# 72/72 - 2s - loss: 0.0528 - accuracy: 0.9822 - 2s/epoch - 33ms/step
# Epoch 292/500
# 72/72 - 2s - loss: 0.0625 - accuracy: 0.9795 - 2s/epoch - 33ms/step
# Epoch 293/500
# 72/72 - 2s - loss: 0.0471 - accuracy: 0.9842 - 2s/epoch - 33ms/step
# Epoch 294/500
# 72/72 - 2s - loss: 0.0413 - accuracy: 0.9859 - 2s/epoch - 33ms/step
# Epoch 295/500
# 72/72 - 2s - loss: 0.0570 - accuracy: 0.9791 - 2s/epoch - 33ms/step
# Epoch 296/500
# 72/72 - 2s - loss: 0.0465 - accuracy: 0.9833 - 2s/epoch - 33ms/step
# Epoch 297/500
# 72/72 - 2s - loss: 0.0441 - accuracy: 0.9862 - 2s/epoch - 33ms/step
# Epoch 298/500
# 72/72 - 2s - loss: 0.0322 - accuracy: 0.9889 - 2s/epoch - 33ms/step
# Epoch 299/500
# 72/72 - 2s - loss: 0.0518 - accuracy: 0.9823 - 2s/epoch - 33ms/step
# Epoch 300/500
# 72/72 - 2s - loss: 0.0421 - accuracy: 0.9847 - 2s/epoch - 33ms/step
# Epoch 301/500
# 72/72 - 2s - loss: 0.0435 - accuracy: 0.9857 - 2s/epoch - 33ms/step
# Epoch 302/500
# 72/72 - 2s - loss: 0.0416 - accuracy: 0.9873 - 2s/epoch - 33ms/step
# Epoch 303/500
# 72/72 - 2s - loss: 0.0493 - accuracy: 0.9842 - 2s/epoch - 33ms/step
# Epoch 304/500
# 72/72 - 2s - loss: 0.0478 - accuracy: 0.9832 - 2s/epoch - 33ms/step
# Epoch 305/500
# 72/72 - 2s - loss: 0.0485 - accuracy: 0.9832 - 2s/epoch - 33ms/step
# Epoch 306/500
# 72/72 - 2s - loss: 0.0473 - accuracy: 0.9857 - 2s/epoch - 33ms/step
# Epoch 307/500
# 72/72 - 2s - loss: 0.0447 - accuracy: 0.9851 - 2s/epoch - 33ms/step
# Epoch 308/500
# 72/72 - 2s - loss: 0.0445 - accuracy: 0.9861 - 2s/epoch - 33ms/step
# Epoch 309/500
# 72/72 - 2s - loss: 0.0520 - accuracy: 0.9826 - 2s/epoch - 33ms/step
# Epoch 310/500
# 72/72 - 2s - loss: 0.0374 - accuracy: 0.9875 - 2s/epoch - 33ms/step
# Epoch 311/500
# 72/72 - 2s - loss: 0.0465 - accuracy: 0.9841 - 2s/epoch - 33ms/step
# Epoch 312/500
# 72/72 - 2s - loss: 0.0415 - accuracy: 0.9853 - 2s/epoch - 33ms/step
# Epoch 313/500
# 72/72 - 2s - loss: 0.0394 - accuracy: 0.9854 - 2s/epoch - 33ms/step
# Epoch 314/500
# 72/72 - 2s - loss: 0.0383 - accuracy: 0.9872 - 2s/epoch - 33ms/step
# Epoch 315/500
# 72/72 - 2s - loss: 0.0471 - accuracy: 0.9843 - 2s/epoch - 33ms/step
# Epoch 316/500
# 72/72 - 2s - loss: 0.0446 - accuracy: 0.9845 - 2s/epoch - 33ms/step
# Epoch 317/500
# 72/72 - 2s - loss: 0.0438 - accuracy: 0.9853 - 2s/epoch - 33ms/step
# Epoch 318/500
# 72/72 - 2s - loss: 0.0472 - accuracy: 0.9835 - 2s/epoch - 33ms/step
# Epoch 319/500
# 72/72 - 2s - loss: 0.0468 - accuracy: 0.9842 - 2s/epoch - 33ms/step
# Epoch 320/500
# 72/72 - 2s - loss: 0.0491 - accuracy: 0.9835 - 2s/epoch - 33ms/step
# Epoch 321/500
# 72/72 - 2s - loss: 0.0456 - accuracy: 0.9835 - 2s/epoch - 33ms/step
# Epoch 322/500
# 72/72 - 2s - loss: 0.0464 - accuracy: 0.9854 - 2s/epoch - 33ms/step
# Epoch 323/500
# 72/72 - 2s - loss: 0.0408 - accuracy: 0.9868 - 2s/epoch - 33ms/step
# Epoch 324/500
# 72/72 - 2s - loss: 0.0416 - accuracy: 0.9859 - 2s/epoch - 33ms/step
# Epoch 325/500
# 72/72 - 2s - loss: 0.0419 - accuracy: 0.9874 - 2s/epoch - 33ms/step
# Epoch 326/500
# 72/72 - 2s - loss: 0.0453 - accuracy: 0.9847 - 2s/epoch - 33ms/step
# Epoch 327/500
# 72/72 - 2s - loss: 0.0416 - accuracy: 0.9872 - 2s/epoch - 33ms/step
# Epoch 328/500
# 72/72 - 2s - loss: 0.0361 - accuracy: 0.9858 - 2s/epoch - 33ms/step
# Epoch 329/500
# 72/72 - 2s - loss: 0.0357 - accuracy: 0.9873 - 2s/epoch - 33ms/step
# Epoch 330/500
# 72/72 - 2s - loss: 0.0493 - accuracy: 0.9845 - 2s/epoch - 33ms/step
# Epoch 331/500
# 72/72 - 2s - loss: 0.0406 - accuracy: 0.9867 - 2s/epoch - 33ms/step
# Epoch 332/500
# 72/72 - 2s - loss: 0.0378 - accuracy: 0.9872 - 2s/epoch - 33ms/step
# Epoch 333/500
# 72/72 - 2s - loss: 0.0454 - accuracy: 0.9870 - 2s/epoch - 33ms/step
# Epoch 334/500
# 72/72 - 2s - loss: 0.0461 - accuracy: 0.9860 - 2s/epoch - 33ms/step
# Epoch 335/500
# 72/72 - 2s - loss: 0.0409 - accuracy: 0.9866 - 2s/epoch - 33ms/step
# Epoch 336/500
# 72/72 - 2s - loss: 0.0374 - accuracy: 0.9887 - 2s/epoch - 33ms/step
# Epoch 337/500
# 72/72 - 2s - loss: 0.0295 - accuracy: 0.9901 - 2s/epoch - 33ms/step
# Epoch 338/500
# 72/72 - 2s - loss: 0.0353 - accuracy: 0.9879 - 2s/epoch - 33ms/step
# Epoch 339/500
# 72/72 - 2s - loss: 0.0360 - accuracy: 0.9885 - 2s/epoch - 33ms/step
# Epoch 340/500
# 72/72 - 2s - loss: 0.0390 - accuracy: 0.9866 - 2s/epoch - 33ms/step
# Epoch 341/500
# 72/72 - 2s - loss: 0.0457 - accuracy: 0.9838 - 2s/epoch - 33ms/step
# Epoch 342/500
# 72/72 - 2s - loss: 0.0538 - accuracy: 0.9818 - 2s/epoch - 33ms/step
# Epoch 343/500
# 72/72 - 2s - loss: 0.0395 - accuracy: 0.9866 - 2s/epoch - 33ms/step
# Epoch 344/500
# 72/72 - 2s - loss: 0.0414 - accuracy: 0.9855 - 2s/epoch - 33ms/step
# Epoch 345/500
# 72/72 - 2s - loss: 0.0404 - accuracy: 0.9874 - 2s/epoch - 33ms/step
# Epoch 346/500
# 72/72 - 2s - loss: 0.0421 - accuracy: 0.9868 - 2s/epoch - 33ms/step
# Epoch 347/500
# 72/72 - 2s - loss: 0.0352 - accuracy: 0.9879 - 2s/epoch - 33ms/step
# Epoch 348/500
# 72/72 - 2s - loss: 0.0392 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 349/500
# 72/72 - 2s - loss: 0.0400 - accuracy: 0.9863 - 2s/epoch - 33ms/step
# Epoch 350/500
# 72/72 - 2s - loss: 0.0370 - accuracy: 0.9876 - 2s/epoch - 33ms/step
# Epoch 351/500
# 72/72 - 2s - loss: 0.0355 - accuracy: 0.9895 - 2s/epoch - 33ms/step
# Epoch 352/500
# 72/72 - 2s - loss: 0.0373 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 353/500
# 72/72 - 2s - loss: 0.0460 - accuracy: 0.9846 - 2s/epoch - 33ms/step
# Epoch 354/500
# 72/72 - 2s - loss: 0.0330 - accuracy: 0.9904 - 2s/epoch - 33ms/step
# Epoch 355/500
# 72/72 - 2s - loss: 0.0319 - accuracy: 0.9900 - 2s/epoch - 33ms/step
# Epoch 356/500
# 72/72 - 2s - loss: 0.0306 - accuracy: 0.9905 - 2s/epoch - 33ms/step
# Epoch 357/500
# 72/72 - 2s - loss: 0.0419 - accuracy: 0.9852 - 2s/epoch - 33ms/step
# Epoch 358/500
# 72/72 - 2s - loss: 0.0359 - accuracy: 0.9880 - 2s/epoch - 33ms/step
# Epoch 359/500
# 72/72 - 2s - loss: 0.0324 - accuracy: 0.9904 - 2s/epoch - 33ms/step
# Epoch 360/500
# 72/72 - 2s - loss: 0.0324 - accuracy: 0.9902 - 2s/epoch - 33ms/step
# Epoch 361/500
# 72/72 - 2s - loss: 0.0238 - accuracy: 0.9930 - 2s/epoch - 33ms/step
# Epoch 362/500
# 72/72 - 2s - loss: 0.0327 - accuracy: 0.9899 - 2s/epoch - 33ms/step
# Epoch 363/500
# 72/72 - 2s - loss: 0.0435 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 364/500
# 72/72 - 2s - loss: 0.0326 - accuracy: 0.9883 - 2s/epoch - 33ms/step
# Epoch 365/500
# 72/72 - 2s - loss: 0.0338 - accuracy: 0.9904 - 2s/epoch - 33ms/step
# Epoch 366/500
# 72/72 - 2s - loss: 0.0396 - accuracy: 0.9871 - 2s/epoch - 33ms/step
# Epoch 367/500
# 72/72 - 2s - loss: 0.0349 - accuracy: 0.9889 - 2s/epoch - 33ms/step
# Epoch 368/500
# 72/72 - 2s - loss: 0.0321 - accuracy: 0.9897 - 2s/epoch - 33ms/step
# Epoch 369/500
# 72/72 - 2s - loss: 0.0432 - accuracy: 0.9862 - 2s/epoch - 33ms/step
# Epoch 370/500
# 72/72 - 2s - loss: 0.0330 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 371/500
# 72/72 - 2s - loss: 0.0382 - accuracy: 0.9866 - 2s/epoch - 33ms/step
# Epoch 372/500
# 72/72 - 2s - loss: 0.0374 - accuracy: 0.9875 - 2s/epoch - 33ms/step
# Epoch 373/500
# 72/72 - 2s - loss: 0.0312 - accuracy: 0.9905 - 2s/epoch - 33ms/step
# Epoch 374/500
# 72/72 - 2s - loss: 0.0325 - accuracy: 0.9899 - 2s/epoch - 33ms/step
# Epoch 375/500
# 72/72 - 2s - loss: 0.0368 - accuracy: 0.9867 - 2s/epoch - 33ms/step
# Epoch 376/500
# 72/72 - 2s - loss: 0.0355 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 377/500
# 72/72 - 2s - loss: 0.0345 - accuracy: 0.9884 - 2s/epoch - 33ms/step
# Epoch 378/500
# 72/72 - 2s - loss: 0.0390 - accuracy: 0.9858 - 2s/epoch - 33ms/step
# Epoch 379/500
# 72/72 - 2s - loss: 0.0336 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 380/500
# 72/72 - 2s - loss: 0.0327 - accuracy: 0.9897 - 2s/epoch - 33ms/step
# Epoch 381/500
# 72/72 - 2s - loss: 0.0398 - accuracy: 0.9883 - 2s/epoch - 33ms/step
# Epoch 382/500
# 72/72 - 2s - loss: 0.0361 - accuracy: 0.9899 - 2s/epoch - 33ms/step
# Epoch 383/500
# 72/72 - 2s - loss: 0.0262 - accuracy: 0.9922 - 2s/epoch - 33ms/step
# Epoch 384/500
# 72/72 - 2s - loss: 0.0338 - accuracy: 0.9893 - 2s/epoch - 33ms/step
# Epoch 385/500
# 72/72 - 2s - loss: 0.0291 - accuracy: 0.9902 - 2s/epoch - 33ms/step
# Epoch 386/500
# 72/72 - 2s - loss: 0.0314 - accuracy: 0.9892 - 2s/epoch - 33ms/step
# Epoch 387/500
# 72/72 - 2s - loss: 0.0378 - accuracy: 0.9886 - 2s/epoch - 33ms/step
# Epoch 388/500
# 72/72 - 2s - loss: 0.0293 - accuracy: 0.9914 - 2s/epoch - 33ms/step
# Epoch 389/500
# 72/72 - 2s - loss: 0.0397 - accuracy: 0.9868 - 2s/epoch - 33ms/step
# Epoch 390/500
# 72/72 - 2s - loss: 0.0436 - accuracy: 0.9855 - 2s/epoch - 33ms/step
# Epoch 391/500
# 72/72 - 2s - loss: 0.0373 - accuracy: 0.9884 - 2s/epoch - 33ms/step
# Epoch 392/500
# 72/72 - 2s - loss: 0.0314 - accuracy: 0.9893 - 2s/epoch - 33ms/step
# Epoch 393/500
# 72/72 - 2s - loss: 0.0344 - accuracy: 0.9885 - 2s/epoch - 33ms/step
# Epoch 394/500
# 72/72 - 2s - loss: 0.0313 - accuracy: 0.9900 - 2s/epoch - 33ms/step
# Epoch 395/500
# 72/72 - 2s - loss: 0.0306 - accuracy: 0.9911 - 2s/epoch - 33ms/step
# Epoch 396/500
# 72/72 - 2s - loss: 0.0294 - accuracy: 0.9901 - 2s/epoch - 33ms/step
# Epoch 397/500
# 72/72 - 2s - loss: 0.0289 - accuracy: 0.9908 - 2s/epoch - 33ms/step
# Epoch 398/500
# 72/72 - 2s - loss: 0.0334 - accuracy: 0.9895 - 2s/epoch - 33ms/step
# Epoch 399/500
# 72/72 - 2s - loss: 0.0410 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 400/500
# 72/72 - 2s - loss: 0.0354 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 401/500
# 72/72 - 2s - loss: 0.0403 - accuracy: 0.9875 - 2s/epoch - 33ms/step
# Epoch 402/500
# 72/72 - 2s - loss: 0.0380 - accuracy: 0.9879 - 2s/epoch - 33ms/step
# Epoch 403/500
# 72/72 - 2s - loss: 0.0299 - accuracy: 0.9912 - 2s/epoch - 32ms/step
# Epoch 404/500
# 72/72 - 2s - loss: 0.0396 - accuracy: 0.9860 - 2s/epoch - 33ms/step
# Epoch 405/500
# 72/72 - 2s - loss: 0.0321 - accuracy: 0.9883 - 2s/epoch - 33ms/step
# Epoch 406/500
# 72/72 - 2s - loss: 0.0249 - accuracy: 0.9928 - 2s/epoch - 33ms/step
# Epoch 407/500
# 72/72 - 2s - loss: 0.0261 - accuracy: 0.9923 - 2s/epoch - 33ms/step
# Epoch 408/500
# 72/72 - 2s - loss: 0.0313 - accuracy: 0.9901 - 2s/epoch - 33ms/step
# Epoch 409/500
# 72/72 - 2s - loss: 0.0290 - accuracy: 0.9913 - 2s/epoch - 33ms/step
# Epoch 410/500
# 72/72 - 2s - loss: 0.0361 - accuracy: 0.9882 - 2s/epoch - 33ms/step
# Epoch 411/500
# 72/72 - 2s - loss: 0.0307 - accuracy: 0.9909 - 2s/epoch - 33ms/step
# Epoch 412/500
# 72/72 - 2s - loss: 0.0311 - accuracy: 0.9897 - 2s/epoch - 33ms/step
# Epoch 413/500
# 72/72 - 2s - loss: 0.0380 - accuracy: 0.9864 - 2s/epoch - 33ms/step
# Epoch 414/500
# 72/72 - 2s - loss: 0.0250 - accuracy: 0.9933 - 2s/epoch - 33ms/step
# Epoch 415/500
# 72/72 - 2s - loss: 0.0254 - accuracy: 0.9912 - 2s/epoch - 33ms/step
# Epoch 416/500
# 72/72 - 2s - loss: 0.0388 - accuracy: 0.9873 - 2s/epoch - 33ms/step
# Epoch 417/500
# 72/72 - 2s - loss: 0.0306 - accuracy: 0.9912 - 2s/epoch - 33ms/step
# Epoch 418/500
# 72/72 - 2s - loss: 0.0378 - accuracy: 0.9883 - 2s/epoch - 33ms/step
# Epoch 419/500
# 72/72 - 2s - loss: 0.0257 - accuracy: 0.9921 - 2s/epoch - 33ms/step
# Epoch 420/500
# 72/72 - 2s - loss: 0.0339 - accuracy: 0.9890 - 2s/epoch - 33ms/step
# Epoch 421/500
# 72/72 - 2s - loss: 0.0288 - accuracy: 0.9905 - 2s/epoch - 33ms/step
# Epoch 422/500
# 72/72 - 2s - loss: 0.0312 - accuracy: 0.9898 - 2s/epoch - 33ms/step
# Epoch 423/500
# 72/72 - 2s - loss: 0.0235 - accuracy: 0.9927 - 2s/epoch - 33ms/step
# Epoch 424/500
# 72/72 - 2s - loss: 0.0350 - accuracy: 0.9897 - 2s/epoch - 33ms/step
# Epoch 425/500
# 72/72 - 2s - loss: 0.0388 - accuracy: 0.9875 - 2s/epoch - 33ms/step
# Epoch 426/500
# 72/72 - 2s - loss: 0.0260 - accuracy: 0.9917 - 2s/epoch - 33ms/step
# Epoch 427/500
# 72/72 - 2s - loss: 0.0280 - accuracy: 0.9912 - 2s/epoch - 33ms/step
# Epoch 428/500
# 72/72 - 2s - loss: 0.0281 - accuracy: 0.9911 - 2s/epoch - 33ms/step
# Epoch 429/500
# 72/72 - 2s - loss: 0.0326 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 430/500
# 72/72 - 2s - loss: 0.0366 - accuracy: 0.9892 - 2s/epoch - 33ms/step
# Epoch 431/500
# 72/72 - 2s - loss: 0.0243 - accuracy: 0.9923 - 2s/epoch - 33ms/step
# Epoch 432/500
# 72/72 - 2s - loss: 0.0272 - accuracy: 0.9909 - 2s/epoch - 33ms/step
# Epoch 433/500
# 72/72 - 2s - loss: 0.0213 - accuracy: 0.9929 - 2s/epoch - 33ms/step
# Epoch 434/500
# 72/72 - 2s - loss: 0.0326 - accuracy: 0.9889 - 2s/epoch - 33ms/step
# Epoch 435/500
# 72/72 - 2s - loss: 0.0256 - accuracy: 0.9924 - 2s/epoch - 33ms/step
# Epoch 436/500
# 72/72 - 2s - loss: 0.0365 - accuracy: 0.9886 - 2s/epoch - 33ms/step
# Epoch 437/500
# 72/72 - 2s - loss: 0.0226 - accuracy: 0.9927 - 2s/epoch - 33ms/step
# Epoch 438/500
# 72/72 - 2s - loss: 0.0397 - accuracy: 0.9868 - 2s/epoch - 33ms/step
# Epoch 439/500
# 72/72 - 2s - loss: 0.0334 - accuracy: 0.9900 - 2s/epoch - 32ms/step
# Epoch 440/500
# 72/72 - 2s - loss: 0.0259 - accuracy: 0.9922 - 2s/epoch - 33ms/step
# Epoch 441/500
# 72/72 - 2s - loss: 0.0241 - accuracy: 0.9928 - 2s/epoch - 33ms/step
# Epoch 442/500
# 72/72 - 2s - loss: 0.0250 - accuracy: 0.9921 - 2s/epoch - 33ms/step
# Epoch 443/500
# 72/72 - 2s - loss: 0.0407 - accuracy: 0.9867 - 2s/epoch - 33ms/step
# Epoch 444/500
# 72/72 - 2s - loss: 0.0308 - accuracy: 0.9903 - 2s/epoch - 33ms/step
# Epoch 445/500
# 72/72 - 2s - loss: 0.0262 - accuracy: 0.9917 - 2s/epoch - 33ms/step
# Epoch 446/500
# 72/72 - 2s - loss: 0.0280 - accuracy: 0.9917 - 2s/epoch - 33ms/step
# Epoch 447/500
# 72/72 - 2s - loss: 0.0329 - accuracy: 0.9905 - 2s/epoch - 33ms/step
# Epoch 448/500
# 72/72 - 2s - loss: 0.0348 - accuracy: 0.9899 - 2s/epoch - 33ms/step
# Epoch 449/500
# 72/72 - 2s - loss: 0.0268 - accuracy: 0.9926 - 2s/epoch - 33ms/step
# Epoch 450/500
# 72/72 - 2s - loss: 0.0238 - accuracy: 0.9917 - 2s/epoch - 33ms/step
# Epoch 451/500
# 72/72 - 2s - loss: 0.0291 - accuracy: 0.9916 - 2s/epoch - 33ms/step
# Epoch 452/500
# 72/72 - 2s - loss: 0.0186 - accuracy: 0.9936 - 2s/epoch - 33ms/step
# Epoch 453/500
# 72/72 - 2s - loss: 0.0235 - accuracy: 0.9925 - 2s/epoch - 33ms/step
# Epoch 454/500
# 72/72 - 2s - loss: 0.0273 - accuracy: 0.9913 - 2s/epoch - 33ms/step
# Epoch 455/500
# 72/72 - 2s - loss: 0.0359 - accuracy: 0.9876 - 2s/epoch - 33ms/step
# Epoch 456/500
# 72/72 - 2s - loss: 0.0314 - accuracy: 0.9889 - 2s/epoch - 33ms/step
# Epoch 457/500
# 72/72 - 2s - loss: 0.0229 - accuracy: 0.9927 - 2s/epoch - 33ms/step
# Epoch 458/500
# 72/72 - 2s - loss: 0.0335 - accuracy: 0.9892 - 2s/epoch - 33ms/step
# Epoch 459/500
# 72/72 - 2s - loss: 0.0189 - accuracy: 0.9937 - 2s/epoch - 33ms/step
# Epoch 460/500
# 72/72 - 2s - loss: 0.0302 - accuracy: 0.9898 - 2s/epoch - 33ms/step
# Epoch 461/500
# 72/72 - 2s - loss: 0.0342 - accuracy: 0.9891 - 2s/epoch - 33ms/step
# Epoch 462/500
# 72/72 - 2s - loss: 0.0276 - accuracy: 0.9920 - 2s/epoch - 33ms/step
# Epoch 463/500
# 72/72 - 2s - loss: 0.0360 - accuracy: 0.9885 - 2s/epoch - 33ms/step
# Epoch 464/500
# 72/72 - 2s - loss: 0.0234 - accuracy: 0.9933 - 2s/epoch - 33ms/step
# Epoch 465/500
# 72/72 - 2s - loss: 0.0296 - accuracy: 0.9889 - 2s/epoch - 33ms/step
# Epoch 466/500
# 72/72 - 2s - loss: 0.0215 - accuracy: 0.9925 - 2s/epoch - 33ms/step
# Epoch 467/500
# 72/72 - 2s - loss: 0.0292 - accuracy: 0.9899 - 2s/epoch - 33ms/step
# Epoch 468/500
# 72/72 - 2s - loss: 0.0393 - accuracy: 0.9884 - 2s/epoch - 33ms/step
# Epoch 469/500
# 72/72 - 2s - loss: 0.0305 - accuracy: 0.9910 - 2s/epoch - 33ms/step
# Epoch 470/500
# 72/72 - 2s - loss: 0.0173 - accuracy: 0.9949 - 2s/epoch - 33ms/step
# Epoch 471/500
# 72/72 - 2s - loss: 0.0213 - accuracy: 0.9933 - 2s/epoch - 33ms/step
# Epoch 472/500
# 72/72 - 2s - loss: 0.0321 - accuracy: 0.9900 - 2s/epoch - 33ms/step
# Epoch 473/500
# 72/72 - 2s - loss: 0.0278 - accuracy: 0.9927 - 2s/epoch - 33ms/step
# Epoch 474/500
# 72/72 - 2s - loss: 0.0279 - accuracy: 0.9905 - 2s/epoch - 33ms/step
# Epoch 475/500
# 72/72 - 2s - loss: 0.0271 - accuracy: 0.9922 - 2s/epoch - 33ms/step
# Epoch 476/500
# 72/72 - 2s - loss: 0.0208 - accuracy: 0.9943 - 2s/epoch - 33ms/step
# Epoch 477/500
# 72/72 - 2s - loss: 0.0242 - accuracy: 0.9924 - 2s/epoch - 33ms/step
# Epoch 478/500
# 72/72 - 2s - loss: 0.0217 - accuracy: 0.9924 - 2s/epoch - 33ms/step
# Epoch 479/500
# 72/72 - 2s - loss: 0.0248 - accuracy: 0.9914 - 2s/epoch - 33ms/step
# Epoch 480/500
# 72/72 - 2s - loss: 0.0234 - accuracy: 0.9937 - 2s/epoch - 33ms/step
# Epoch 481/500
# 72/72 - 2s - loss: 0.0207 - accuracy: 0.9934 - 2s/epoch - 33ms/step
# Epoch 482/500
# 72/72 - 2s - loss: 0.0331 - accuracy: 0.9896 - 2s/epoch - 33ms/step
# Epoch 483/500
# 72/72 - 2s - loss: 0.0309 - accuracy: 0.9911 - 2s/epoch - 33ms/step
# Epoch 484/500
# 72/72 - 2s - loss: 0.0301 - accuracy: 0.9909 - 2s/epoch - 33ms/step
# Epoch 485/500
# 72/72 - 2s - loss: 0.0222 - accuracy: 0.9926 - 2s/epoch - 33ms/step
# Epoch 486/500
# 72/72 - 2s - loss: 0.0231 - accuracy: 0.9929 - 2s/epoch - 33ms/step
# Epoch 487/500
# 72/72 - 2s - loss: 0.0207 - accuracy: 0.9927 - 2s/epoch - 33ms/step
# Epoch 488/500
# 72/72 - 2s - loss: 0.0329 - accuracy: 0.9903 - 2s/epoch - 33ms/step
# Epoch 489/500
# 72/72 - 2s - loss: 0.0339 - accuracy: 0.9893 - 2s/epoch - 33ms/step
# Epoch 490/500
# 72/72 - 2s - loss: 0.0303 - accuracy: 0.9902 - 2s/epoch - 33ms/step
# Epoch 491/500
# 72/72 - 2s - loss: 0.0264 - accuracy: 0.9914 - 2s/epoch - 33ms/step
# Epoch 492/500
# 72/72 - 2s - loss: 0.0215 - accuracy: 0.9945 - 2s/epoch - 33ms/step
# Epoch 493/500
# 72/72 - 2s - loss: 0.0280 - accuracy: 0.9915 - 2s/epoch - 33ms/step
# Epoch 494/500
# 72/72 - 2s - loss: 0.0346 - accuracy: 0.9902 - 2s/epoch - 33ms/step
# Epoch 495/500
# 72/72 - 2s - loss: 0.0216 - accuracy: 0.9932 - 2s/epoch - 33ms/step
# Epoch 496/500
# 72/72 - 2s - loss: 0.0236 - accuracy: 0.9924 - 2s/epoch - 33ms/step
# Epoch 497/500
# 72/72 - 2s - loss: 0.0149 - accuracy: 0.9958 - 2s/epoch - 33ms/step
# Epoch 498/500
# 72/72 - 2s - loss: 0.0260 - accuracy: 0.9922 - 2s/epoch - 33ms/step
# Epoch 499/500
# 72/72 - 2s - loss: 0.0378 - accuracy: 0.9862 - 2s/epoch - 33ms/step
# Epoch 500/500
# 72/72 - 2s - loss: 0.0208 - accuracy: 0.9938 - 2s/epoch - 33ms/step
# 72/72 [==============================] - 1s 9ms/step
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 6ms/step
# accuracy_score: 0.8083
# cohen_kappa_score: 0.7603
# log_loss: 0.8516
# zero_one_loss: 0.1917
# hemming_loss: 0.1917
# matthews_corrcoef: 0.7620
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.05874228477478027
# 72/72 [==============================] - 1s 6ms/step - loss: 0.8516 - accuracy: 0.8083
# 72/72 [==============================] - 0s 5ms/step
# Test runtime: 1.5915703773498535
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8516 - accuracy: 0.8083
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8516 - accuracy: 0.8083
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8516 - accuracy: 0.8083
# 72/72 [==============================] - 0s 6ms/step
