# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 43.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

import math

# %%
data_path6 = '/content/Epileptic Seizure Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  Labels[i] = Labels[i]-1

# %%
Labels
# Out:
# array([3, 0, 4, ..., 4, 2, 3])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 3    2300
# 0    2300
# 4    2300
# 1    2300
# 2    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, Labels, test_size=0.2, stratify=Labels, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (9200, 178)
# Train labels shape: (9200,)
# Test data shape: (2300, 178)
# Test labels shape: (2300,)

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test=pca.transform(X_test)

# %%
X_train.shape
# Out:
# (9200, 41)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (9200, 41, 1)

# %%
#classes
classes = [0, 1, 2, 3, 4]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %% [markdown]
# ## Transformer

# %%
# OPTIMIZER
LEARNING_RATE_2 = 1e-3
WEIGHT_DECAY_2 = 1e-4
LAYER_NORM_EPS_2 = 1e-6
PROJECTION_DIM_2 = 512 # no se puede modificar
NUM_HEADS_2 = 8
NUM_LAYERS_2 = 1
MLP_UNITS_2 = [
    PROJECTION_DIM_2 * 2,
    PROJECTION_DIM_2
]
def mlp(x, dropout_rate, hidden_units):
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
def transformer_2(encoded_patches):

    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS_2, key_dim=PROJECTION_DIM_2, dropout=0.1
    )(x1, x1)

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS_2, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x4, x2])
    return encoded_patches

def Transform_sh_2(inputs):
      # Iterate over the number of layers and stack up blocks of
      # Transformer.
    for i in range(NUM_LAYERS_2):
          # Add a Transformer block.
        encoded_patches = transformer_2(inputs)

    return encoded_patches

# %% [markdown]
# ## CapsNet

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=5
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,1,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 1, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %% [markdown]
# ## Transformer_Caps_Net

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  #Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  CVT1=Transform_sh_2(Layer_1)
  representation = tf.keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(CVT1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(representation)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7fb16d88a560>)
# Epoch 1/500
# 72/72 - 24s - loss: 1.2616 - accuracy: 0.4108 - 24s/epoch - 335ms/step
# Epoch 2/500
# 72/72 - 1s - loss: 1.2763 - accuracy: 0.3992 - 1s/epoch - 17ms/step
# Epoch 3/500
# 72/72 - 1s - loss: 1.2934 - accuracy: 0.3986 - 1s/epoch - 17ms/step
# Epoch 4/500
# 72/72 - 1s - loss: 1.1672 - accuracy: 0.4647 - 1s/epoch - 17ms/step
# Epoch 5/500
# 72/72 - 1s - loss: 1.0855 - accuracy: 0.5203 - 1s/epoch - 17ms/step
# Epoch 6/500
# 72/72 - 1s - loss: 1.0112 - accuracy: 0.5573 - 1s/epoch - 17ms/step
# Epoch 7/500
# 72/72 - 1s - loss: 0.9148 - accuracy: 0.5916 - 1s/epoch - 17ms/step
# Epoch 8/500
# 72/72 - 1s - loss: 0.8811 - accuracy: 0.6058 - 1s/epoch - 18ms/step
# Epoch 9/500
# 72/72 - 1s - loss: 0.8537 - accuracy: 0.6154 - 1s/epoch - 18ms/step
# Epoch 10/500
# 72/72 - 1s - loss: 0.8303 - accuracy: 0.6188 - 1s/epoch - 17ms/step
# Epoch 11/500
# 72/72 - 1s - loss: 0.8486 - accuracy: 0.6179 - 1s/epoch - 17ms/step
# Epoch 12/500
# 72/72 - 1s - loss: 0.8228 - accuracy: 0.6292 - 1s/epoch - 17ms/step
# Epoch 13/500
# 72/72 - 1s - loss: 0.8082 - accuracy: 0.6322 - 1s/epoch - 17ms/step
# Epoch 14/500
# 72/72 - 1s - loss: 0.7953 - accuracy: 0.6361 - 1s/epoch - 17ms/step
# Epoch 15/500
# 72/72 - 1s - loss: 0.7940 - accuracy: 0.6384 - 1s/epoch - 17ms/step
# Epoch 16/500
# 72/72 - 1s - loss: 0.7882 - accuracy: 0.6428 - 1s/epoch - 17ms/step
# Epoch 17/500
# 72/72 - 1s - loss: 0.8039 - accuracy: 0.6300 - 1s/epoch - 18ms/step
# Epoch 18/500
# 72/72 - 1s - loss: 0.7718 - accuracy: 0.6446 - 1s/epoch - 18ms/step
# Epoch 19/500
# 72/72 - 1s - loss: 0.7770 - accuracy: 0.6489 - 1s/epoch - 17ms/step
# Epoch 20/500
# 72/72 - 1s - loss: 0.7680 - accuracy: 0.6450 - 1s/epoch - 17ms/step
# Epoch 21/500
# 72/72 - 1s - loss: 0.7606 - accuracy: 0.6505 - 1s/epoch - 17ms/step
# Epoch 22/500
# 72/72 - 1s - loss: 0.7506 - accuracy: 0.6535 - 1s/epoch - 17ms/step
# Epoch 23/500
# 72/72 - 1s - loss: 0.7549 - accuracy: 0.6551 - 1s/epoch - 17ms/step
# Epoch 24/500
# 72/72 - 1s - loss: 0.7417 - accuracy: 0.6552 - 1s/epoch - 17ms/step
# Epoch 25/500
# 72/72 - 1s - loss: 0.7820 - accuracy: 0.6432 - 1s/epoch - 17ms/step
# Epoch 26/500
# 72/72 - 1s - loss: 0.7539 - accuracy: 0.6596 - 1s/epoch - 18ms/step
# Epoch 27/500
# 72/72 - 1s - loss: 0.7541 - accuracy: 0.6511 - 1s/epoch - 18ms/step
# Epoch 28/500
# 72/72 - 1s - loss: 0.7395 - accuracy: 0.6580 - 1s/epoch - 17ms/step
# Epoch 29/500
# 72/72 - 1s - loss: 0.7377 - accuracy: 0.6622 - 1s/epoch - 17ms/step
# Epoch 30/500
# 72/72 - 1s - loss: 0.7323 - accuracy: 0.6625 - 1s/epoch - 17ms/step
# Epoch 31/500
# 72/72 - 1s - loss: 0.7289 - accuracy: 0.6615 - 1s/epoch - 17ms/step
# Epoch 32/500
# 72/72 - 1s - loss: 0.7403 - accuracy: 0.6571 - 1s/epoch - 17ms/step
# Epoch 33/500
# 72/72 - 1s - loss: 0.7313 - accuracy: 0.6643 - 1s/epoch - 17ms/step
# Epoch 34/500
# 72/72 - 1s - loss: 0.7298 - accuracy: 0.6590 - 1s/epoch - 17ms/step
# Epoch 35/500
# 72/72 - 1s - loss: 0.7468 - accuracy: 0.6530 - 1s/epoch - 17ms/step
# Epoch 36/500
# 72/72 - 1s - loss: 0.7190 - accuracy: 0.6675 - 1s/epoch - 18ms/step
# Epoch 37/500
# 72/72 - 1s - loss: 0.7117 - accuracy: 0.6645 - 1s/epoch - 18ms/step
# Epoch 38/500
# 72/72 - 1s - loss: 0.7153 - accuracy: 0.6684 - 1s/epoch - 17ms/step
# Epoch 39/500
# 72/72 - 1s - loss: 0.7259 - accuracy: 0.6626 - 1s/epoch - 17ms/step
# Epoch 40/500
# 72/72 - 1s - loss: 0.7189 - accuracy: 0.6686 - 1s/epoch - 19ms/step
# Epoch 41/500
# 72/72 - 1s - loss: 0.7127 - accuracy: 0.6664 - 1s/epoch - 19ms/step
# Epoch 42/500
# 72/72 - 1s - loss: 0.7117 - accuracy: 0.6715 - 1s/epoch - 19ms/step
# Epoch 43/500
# 72/72 - 1s - loss: 0.7156 - accuracy: 0.6710 - 1s/epoch - 17ms/step
# Epoch 44/500
# 72/72 - 1s - loss: 0.7144 - accuracy: 0.6712 - 1s/epoch - 17ms/step
# Epoch 45/500
# 72/72 - 1s - loss: 0.7133 - accuracy: 0.6701 - 1s/epoch - 18ms/step
# Epoch 46/500
# 72/72 - 1s - loss: 0.7125 - accuracy: 0.6674 - 1s/epoch - 18ms/step
# Epoch 47/500
# 72/72 - 1s - loss: 0.7115 - accuracy: 0.6715 - 1s/epoch - 17ms/step
# Epoch 48/500
# 72/72 - 1s - loss: 0.7044 - accuracy: 0.6742 - 1s/epoch - 18ms/step
# Epoch 49/500
# 72/72 - 1s - loss: 0.7086 - accuracy: 0.6759 - 1s/epoch - 18ms/step
# Epoch 50/500
# 72/72 - 1s - loss: 0.7140 - accuracy: 0.6660 - 1s/epoch - 18ms/step
# Epoch 51/500
# 72/72 - 1s - loss: 0.7116 - accuracy: 0.6679 - 1s/epoch - 18ms/step
# Epoch 52/500
# 72/72 - 1s - loss: 0.6999 - accuracy: 0.6736 - 1s/epoch - 17ms/step
# Epoch 53/500
# 72/72 - 1s - loss: 0.7031 - accuracy: 0.6760 - 1s/epoch - 17ms/step
# Epoch 54/500
# 72/72 - 1s - loss: 0.6964 - accuracy: 0.6753 - 1s/epoch - 18ms/step
# Epoch 55/500
# 72/72 - 1s - loss: 0.7000 - accuracy: 0.6741 - 1s/epoch - 18ms/step
# Epoch 56/500
# 72/72 - 1s - loss: 0.7005 - accuracy: 0.6746 - 1s/epoch - 18ms/step
# Epoch 57/500
# 72/72 - 1s - loss: 0.7020 - accuracy: 0.6734 - 1s/epoch - 18ms/step
# Epoch 58/500
# 72/72 - 1s - loss: 0.6889 - accuracy: 0.6749 - 1s/epoch - 18ms/step
# Epoch 59/500
# 72/72 - 1s - loss: 0.6986 - accuracy: 0.6780 - 1s/epoch - 18ms/step
# Epoch 60/500
# 72/72 - 1s - loss: 0.6849 - accuracy: 0.6814 - 1s/epoch - 18ms/step
# Epoch 61/500
# 72/72 - 1s - loss: 0.6898 - accuracy: 0.6800 - 1s/epoch - 18ms/step
# Epoch 62/500
# 72/72 - 1s - loss: 0.6920 - accuracy: 0.6802 - 1s/epoch - 18ms/step
# Epoch 63/500
# 72/72 - 1s - loss: 0.6851 - accuracy: 0.6841 - 1s/epoch - 18ms/step
# Epoch 64/500
# 72/72 - 1s - loss: 0.6837 - accuracy: 0.6859 - 1s/epoch - 18ms/step
# Epoch 65/500
# 72/72 - 1s - loss: 0.6901 - accuracy: 0.6786 - 1s/epoch - 18ms/step
# Epoch 66/500
# 72/72 - 1s - loss: 0.6912 - accuracy: 0.6805 - 1s/epoch - 18ms/step
# Epoch 67/500
# 72/72 - 1s - loss: 0.6873 - accuracy: 0.6795 - 1s/epoch - 18ms/step
# Epoch 68/500
# 72/72 - 1s - loss: 0.6784 - accuracy: 0.6938 - 1s/epoch - 18ms/step
# Epoch 69/500
# 72/72 - 1s - loss: 0.6886 - accuracy: 0.6898 - 1s/epoch - 18ms/step
# Epoch 70/500
# 72/72 - 1s - loss: 0.6845 - accuracy: 0.6855 - 1s/epoch - 18ms/step
# Epoch 71/500
# 72/72 - 1s - loss: 0.6784 - accuracy: 0.6842 - 1s/epoch - 18ms/step
# Epoch 72/500
# 72/72 - 1s - loss: 0.6825 - accuracy: 0.6862 - 1s/epoch - 18ms/step
# Epoch 73/500
# 72/72 - 1s - loss: 0.6728 - accuracy: 0.6880 - 1s/epoch - 18ms/step
# Epoch 74/500
# 72/72 - 1s - loss: 0.6770 - accuracy: 0.6902 - 1s/epoch - 18ms/step
# Epoch 75/500
# 72/72 - 1s - loss: 0.6691 - accuracy: 0.6946 - 1s/epoch - 18ms/step
# Epoch 76/500
# 72/72 - 1s - loss: 0.6770 - accuracy: 0.6887 - 1s/epoch - 17ms/step
# Epoch 77/500
# 72/72 - 1s - loss: 0.6722 - accuracy: 0.6891 - 1s/epoch - 18ms/step
# Epoch 78/500
# 72/72 - 1s - loss: 0.6773 - accuracy: 0.6909 - 1s/epoch - 17ms/step
# Epoch 79/500
# 72/72 - 1s - loss: 0.6743 - accuracy: 0.6888 - 1s/epoch - 17ms/step
# Epoch 80/500
# 72/72 - 1s - loss: 0.6720 - accuracy: 0.6941 - 1s/epoch - 18ms/step
# Epoch 81/500
# 72/72 - 1s - loss: 0.6717 - accuracy: 0.6973 - 1s/epoch - 18ms/step
# Epoch 82/500
# 72/72 - 1s - loss: 0.6753 - accuracy: 0.6899 - 1s/epoch - 18ms/step
# Epoch 83/500
# 72/72 - 1s - loss: 0.6771 - accuracy: 0.6940 - 1s/epoch - 18ms/step
# Epoch 84/500
# 72/72 - 1s - loss: 0.6682 - accuracy: 0.6972 - 1s/epoch - 17ms/step
# Epoch 85/500
# 72/72 - 1s - loss: 0.6688 - accuracy: 0.6960 - 1s/epoch - 17ms/step
# Epoch 86/500
# 72/72 - 1s - loss: 0.6749 - accuracy: 0.6917 - 1s/epoch - 17ms/step
# Epoch 87/500
# 72/72 - 1s - loss: 0.6648 - accuracy: 0.6995 - 1s/epoch - 17ms/step
# Epoch 88/500
# 72/72 - 1s - loss: 0.6657 - accuracy: 0.6977 - 1s/epoch - 17ms/step
# Epoch 89/500
# 72/72 - 1s - loss: 0.6663 - accuracy: 0.6955 - 1s/epoch - 17ms/step
# Epoch 90/500
# 72/72 - 1s - loss: 0.6660 - accuracy: 0.6937 - 1s/epoch - 17ms/step
# Epoch 91/500
# 72/72 - 1s - loss: 0.6624 - accuracy: 0.6935 - 1s/epoch - 18ms/step
# Epoch 92/500
# 72/72 - 1s - loss: 0.6564 - accuracy: 0.6999 - 1s/epoch - 18ms/step
# Epoch 93/500
# 72/72 - 1s - loss: 0.6582 - accuracy: 0.6976 - 1s/epoch - 17ms/step
# Epoch 94/500
# 72/72 - 1s - loss: 0.6582 - accuracy: 0.7005 - 1s/epoch - 17ms/step
# Epoch 95/500
# 72/72 - 1s - loss: 0.6550 - accuracy: 0.7070 - 1s/epoch - 18ms/step
# Epoch 96/500
# 72/72 - 1s - loss: 0.6596 - accuracy: 0.7002 - 1s/epoch - 18ms/step
# Epoch 97/500
# 72/72 - 1s - loss: 0.6628 - accuracy: 0.6988 - 1s/epoch - 17ms/step
# Epoch 98/500
# 72/72 - 1s - loss: 0.6473 - accuracy: 0.7068 - 1s/epoch - 18ms/step
# Epoch 99/500
# 72/72 - 1s - loss: 0.6584 - accuracy: 0.6990 - 1s/epoch - 17ms/step
# Epoch 100/500
# 72/72 - 1s - loss: 0.6524 - accuracy: 0.7025 - 1s/epoch - 18ms/step
# Epoch 101/500
# 72/72 - 1s - loss: 0.6535 - accuracy: 0.7045 - 1s/epoch - 18ms/step
# Epoch 102/500
# 72/72 - 1s - loss: 0.6563 - accuracy: 0.7034 - 1s/epoch - 17ms/step
# Epoch 103/500
# 72/72 - 1s - loss: 0.6487 - accuracy: 0.7077 - 1s/epoch - 17ms/step
# Epoch 104/500
# 72/72 - 1s - loss: 0.6502 - accuracy: 0.7065 - 1s/epoch - 17ms/step
# Epoch 105/500
# 72/72 - 1s - loss: 0.6461 - accuracy: 0.7084 - 1s/epoch - 17ms/step
# Epoch 106/500
# 72/72 - 1s - loss: 0.6506 - accuracy: 0.7083 - 1s/epoch - 17ms/step
# Epoch 107/500
# 72/72 - 1s - loss: 0.6453 - accuracy: 0.7028 - 1s/epoch - 18ms/step
# Epoch 108/500
# 72/72 - 1s - loss: 0.6491 - accuracy: 0.7113 - 1s/epoch - 17ms/step
# Epoch 109/500
# 72/72 - 1s - loss: 0.6513 - accuracy: 0.7105 - 1s/epoch - 18ms/step
# Epoch 110/500
# 72/72 - 1s - loss: 0.6479 - accuracy: 0.7087 - 1s/epoch - 18ms/step
# Epoch 111/500
# 72/72 - 1s - loss: 0.6503 - accuracy: 0.7030 - 1s/epoch - 18ms/step
# Epoch 112/500
# 72/72 - 1s - loss: 0.6456 - accuracy: 0.7078 - 1s/epoch - 17ms/step
# Epoch 113/500
# 72/72 - 1s - loss: 0.6444 - accuracy: 0.7084 - 1s/epoch - 17ms/step
# Epoch 114/500
# 72/72 - 1s - loss: 0.6420 - accuracy: 0.7129 - 1s/epoch - 17ms/step
# Epoch 115/500
# 72/72 - 1s - loss: 0.6428 - accuracy: 0.7123 - 1s/epoch - 17ms/step
# Epoch 116/500
# 72/72 - 1s - loss: 0.6397 - accuracy: 0.7126 - 1s/epoch - 18ms/step
# Epoch 117/500
# 72/72 - 1s - loss: 0.6400 - accuracy: 0.7111 - 1s/epoch - 18ms/step
# Epoch 118/500
# 72/72 - 1s - loss: 0.6349 - accuracy: 0.7143 - 1s/epoch - 18ms/step
# Epoch 119/500
# 72/72 - 1s - loss: 0.6556 - accuracy: 0.7041 - 1s/epoch - 18ms/step
# Epoch 120/500
# 72/72 - 1s - loss: 0.6578 - accuracy: 0.6975 - 1s/epoch - 18ms/step
# Epoch 121/500
# 72/72 - 1s - loss: 0.6369 - accuracy: 0.7161 - 1s/epoch - 18ms/step
# Epoch 122/500
# 72/72 - 1s - loss: 0.6399 - accuracy: 0.7130 - 1s/epoch - 18ms/step
# Epoch 123/500
# 72/72 - 1s - loss: 0.6352 - accuracy: 0.7173 - 1s/epoch - 17ms/step
# Epoch 124/500
# 72/72 - 1s - loss: 0.6303 - accuracy: 0.7195 - 1s/epoch - 18ms/step
# Epoch 125/500
# 72/72 - 1s - loss: 0.6283 - accuracy: 0.7147 - 1s/epoch - 18ms/step
# Epoch 126/500
# 72/72 - 1s - loss: 0.6352 - accuracy: 0.7216 - 1s/epoch - 18ms/step
# Epoch 127/500
# 72/72 - 1s - loss: 0.6392 - accuracy: 0.7133 - 1s/epoch - 18ms/step
# Epoch 128/500
# 72/72 - 1s - loss: 0.6302 - accuracy: 0.7142 - 1s/epoch - 18ms/step
# Epoch 129/500
# 72/72 - 1s - loss: 0.6295 - accuracy: 0.7171 - 1s/epoch - 18ms/step
# Epoch 130/500
# 72/72 - 1s - loss: 0.6255 - accuracy: 0.7196 - 1s/epoch - 17ms/step
# Epoch 131/500
# 72/72 - 1s - loss: 0.6280 - accuracy: 0.7153 - 1s/epoch - 18ms/step
# Epoch 132/500
# 72/72 - 1s - loss: 0.6404 - accuracy: 0.7105 - 1s/epoch - 17ms/step
# Epoch 133/500
# 72/72 - 1s - loss: 0.6298 - accuracy: 0.7158 - 1s/epoch - 18ms/step
# Epoch 134/500
# 72/72 - 1s - loss: 0.6236 - accuracy: 0.7122 - 1s/epoch - 17ms/step
# Epoch 135/500
# 72/72 - 1s - loss: 0.6239 - accuracy: 0.7203 - 1s/epoch - 18ms/step
# Epoch 136/500
# 72/72 - 1s - loss: 0.6271 - accuracy: 0.7158 - 1s/epoch - 18ms/step
# Epoch 137/500
# 72/72 - 1s - loss: 0.6170 - accuracy: 0.7199 - 1s/epoch - 18ms/step
# Epoch 138/500
# 72/72 - 1s - loss: 0.6339 - accuracy: 0.7157 - 1s/epoch - 18ms/step
# Epoch 139/500
# 72/72 - 1s - loss: 0.6211 - accuracy: 0.7241 - 1s/epoch - 17ms/step
# Epoch 140/500
# 72/72 - 1s - loss: 0.6279 - accuracy: 0.7207 - 1s/epoch - 17ms/step
# Epoch 141/500
# 72/72 - 1s - loss: 0.6229 - accuracy: 0.7182 - 1s/epoch - 17ms/step
# Epoch 142/500
# 72/72 - 1s - loss: 0.6251 - accuracy: 0.7199 - 1s/epoch - 18ms/step
# Epoch 143/500
# 72/72 - 1s - loss: 0.6195 - accuracy: 0.7179 - 1s/epoch - 17ms/step
# Epoch 144/500
# 72/72 - 1s - loss: 0.6172 - accuracy: 0.7197 - 1s/epoch - 17ms/step
# Epoch 145/500
# 72/72 - 1s - loss: 0.6818 - accuracy: 0.6943 - 1s/epoch - 18ms/step
# Epoch 146/500
# 72/72 - 1s - loss: 0.6680 - accuracy: 0.7038 - 1s/epoch - 18ms/step
# Epoch 147/500
# 72/72 - 1s - loss: 0.6474 - accuracy: 0.7093 - 1s/epoch - 18ms/step
# Epoch 148/500
# 72/72 - 1s - loss: 0.6472 - accuracy: 0.7112 - 1s/epoch - 17ms/step
# Epoch 149/500
# 72/72 - 1s - loss: 0.6407 - accuracy: 0.7135 - 1s/epoch - 17ms/step
# Epoch 150/500
# 72/72 - 1s - loss: 0.6259 - accuracy: 0.7209 - 1s/epoch - 17ms/step
# Epoch 151/500
# 72/72 - 1s - loss: 0.6228 - accuracy: 0.7203 - 1s/epoch - 17ms/step
# Epoch 152/500
# 72/72 - 1s - loss: 0.6235 - accuracy: 0.7210 - 1s/epoch - 17ms/step
# Epoch 153/500
# 72/72 - 1s - loss: 0.6178 - accuracy: 0.7236 - 1s/epoch - 17ms/step
# Epoch 154/500
# 72/72 - 1s - loss: 0.6236 - accuracy: 0.7204 - 1s/epoch - 17ms/step
# Epoch 155/500
# 72/72 - 1s - loss: 0.6205 - accuracy: 0.7208 - 1s/epoch - 18ms/step
# Epoch 156/500
# 72/72 - 1s - loss: 0.6175 - accuracy: 0.7212 - 1s/epoch - 20ms/step
# Epoch 157/500
# 72/72 - 1s - loss: 0.6174 - accuracy: 0.7222 - 1s/epoch - 18ms/step
# Epoch 158/500
# 72/72 - 1s - loss: 0.6141 - accuracy: 0.7271 - 1s/epoch - 18ms/step
# Epoch 159/500
# 72/72 - 1s - loss: 0.6109 - accuracy: 0.7252 - 1s/epoch - 17ms/step
# Epoch 160/500
# 72/72 - 1s - loss: 0.6106 - accuracy: 0.7193 - 1s/epoch - 17ms/step
# Epoch 161/500
# 72/72 - 1s - loss: 0.6175 - accuracy: 0.7195 - 1s/epoch - 17ms/step
# Epoch 162/500
# 72/72 - 1s - loss: 0.6550 - accuracy: 0.7013 - 1s/epoch - 17ms/step
# Epoch 163/500
# 72/72 - 1s - loss: 0.6258 - accuracy: 0.7212 - 1s/epoch - 17ms/step
# Epoch 164/500
# 72/72 - 1s - loss: 0.6146 - accuracy: 0.7213 - 1s/epoch - 18ms/step
# Epoch 165/500
# 72/72 - 1s - loss: 0.6104 - accuracy: 0.7250 - 1s/epoch - 18ms/step
# Epoch 166/500
# 72/72 - 1s - loss: 0.6070 - accuracy: 0.7250 - 1s/epoch - 18ms/step
# Epoch 167/500
# 72/72 - 1s - loss: 0.6080 - accuracy: 0.7250 - 1s/epoch - 17ms/step
# Epoch 168/500
# 72/72 - 1s - loss: 0.6046 - accuracy: 0.7257 - 1s/epoch - 18ms/step
# Epoch 169/500
# 72/72 - 1s - loss: 0.6043 - accuracy: 0.7302 - 1s/epoch - 17ms/step
# Epoch 170/500
# 72/72 - 1s - loss: 0.6061 - accuracy: 0.7248 - 1s/epoch - 17ms/step
# Epoch 171/500
# 72/72 - 1s - loss: 0.5978 - accuracy: 0.7260 - 1s/epoch - 17ms/step
# Epoch 172/500
# 72/72 - 1s - loss: 0.6059 - accuracy: 0.7214 - 1s/epoch - 17ms/step
# Epoch 173/500
# 72/72 - 1s - loss: 0.6072 - accuracy: 0.7273 - 1s/epoch - 17ms/step
# Epoch 174/500
# 72/72 - 1s - loss: 0.5992 - accuracy: 0.7322 - 1s/epoch - 18ms/step
# Epoch 175/500
# 72/72 - 1s - loss: 0.5985 - accuracy: 0.7263 - 1s/epoch - 18ms/step
# Epoch 176/500
# 72/72 - 1s - loss: 0.5979 - accuracy: 0.7270 - 1s/epoch - 18ms/step
# Epoch 177/500
# 72/72 - 1s - loss: 0.6066 - accuracy: 0.7301 - 1s/epoch - 18ms/step
# Epoch 178/500
# 72/72 - 1s - loss: 0.6027 - accuracy: 0.7259 - 1s/epoch - 17ms/step
# Epoch 179/500
# 72/72 - 1s - loss: 0.6125 - accuracy: 0.7230 - 1s/epoch - 17ms/step
# Epoch 180/500
# 72/72 - 1s - loss: 0.6156 - accuracy: 0.7233 - 1s/epoch - 17ms/step
# Epoch 181/500
# 72/72 - 1s - loss: 0.5990 - accuracy: 0.7313 - 1s/epoch - 17ms/step
# Epoch 182/500
# 72/72 - 1s - loss: 0.5983 - accuracy: 0.7277 - 1s/epoch - 17ms/step
# Epoch 183/500
# 72/72 - 1s - loss: 0.5950 - accuracy: 0.7322 - 1s/epoch - 18ms/step
# Epoch 184/500
# 72/72 - 1s - loss: 0.5921 - accuracy: 0.7341 - 1s/epoch - 18ms/step
# Epoch 185/500
# 72/72 - 1s - loss: 0.5945 - accuracy: 0.7305 - 1s/epoch - 17ms/step
# Epoch 186/500
# 72/72 - 1s - loss: 0.5883 - accuracy: 0.7332 - 1s/epoch - 17ms/step
# Epoch 187/500
# 72/72 - 1s - loss: 0.5934 - accuracy: 0.7318 - 1s/epoch - 18ms/step
# Epoch 188/500
# 72/72 - 1s - loss: 0.6016 - accuracy: 0.7276 - 1s/epoch - 17ms/step
# Epoch 189/500
# 72/72 - 1s - loss: 0.6038 - accuracy: 0.7270 - 1s/epoch - 17ms/step
# Epoch 190/500
# 72/72 - 1s - loss: 0.5977 - accuracy: 0.7332 - 1s/epoch - 17ms/step
# Epoch 191/500
# 72/72 - 1s - loss: 0.5897 - accuracy: 0.7305 - 1s/epoch - 17ms/step
# Epoch 192/500
# 72/72 - 1s - loss: 0.5972 - accuracy: 0.7326 - 1s/epoch - 18ms/step
# Epoch 193/500
# 72/72 - 1s - loss: 0.5854 - accuracy: 0.7384 - 1s/epoch - 19ms/step
# Epoch 194/500
# 72/72 - 1s - loss: 0.5941 - accuracy: 0.7321 - 1s/epoch - 17ms/step
# Epoch 195/500
# 72/72 - 1s - loss: 0.5891 - accuracy: 0.7420 - 1s/epoch - 18ms/step
# Epoch 196/500
# 72/72 - 1s - loss: 0.5912 - accuracy: 0.7363 - 1s/epoch - 17ms/step
# Epoch 197/500
# 72/72 - 1s - loss: 0.5802 - accuracy: 0.7371 - 1s/epoch - 18ms/step
# Epoch 198/500
# 72/72 - 1s - loss: 0.5854 - accuracy: 0.7359 - 1s/epoch - 18ms/step
# Epoch 199/500
# 72/72 - 1s - loss: 0.5926 - accuracy: 0.7347 - 1s/epoch - 18ms/step
# Epoch 200/500
# 72/72 - 1s - loss: 0.5853 - accuracy: 0.7357 - 1s/epoch - 17ms/step
# Epoch 201/500
# 72/72 - 1s - loss: 0.5812 - accuracy: 0.7399 - 1s/epoch - 18ms/step
# Epoch 202/500
# 72/72 - 1s - loss: 0.5885 - accuracy: 0.7353 - 1s/epoch - 18ms/step
# Epoch 203/500
# 72/72 - 1s - loss: 0.5803 - accuracy: 0.7402 - 1s/epoch - 18ms/step
# Epoch 204/500
# 72/72 - 1s - loss: 0.5812 - accuracy: 0.7377 - 1s/epoch - 17ms/step
# Epoch 205/500
# 72/72 - 1s - loss: 0.5824 - accuracy: 0.7390 - 1s/epoch - 17ms/step
# Epoch 206/500
# 72/72 - 1s - loss: 0.5773 - accuracy: 0.7351 - 1s/epoch - 17ms/step
# Epoch 207/500
# 72/72 - 1s - loss: 0.5737 - accuracy: 0.7407 - 1s/epoch - 18ms/step
# Epoch 208/500
# 72/72 - 1s - loss: 0.5775 - accuracy: 0.7399 - 1s/epoch - 17ms/step
# Epoch 209/500
# 72/72 - 1s - loss: 0.5878 - accuracy: 0.7402 - 1s/epoch - 17ms/step
# Epoch 210/500
# 72/72 - 1s - loss: 0.5829 - accuracy: 0.7346 - 1s/epoch - 18ms/step
# Epoch 211/500
# 72/72 - 1s - loss: 0.5864 - accuracy: 0.7405 - 1s/epoch - 18ms/step
# Epoch 212/500
# 72/72 - 1s - loss: 0.5749 - accuracy: 0.7459 - 1s/epoch - 18ms/step
# Epoch 213/500
# 72/72 - 1s - loss: 0.5724 - accuracy: 0.7390 - 1s/epoch - 17ms/step
# Epoch 214/500
# 72/72 - 1s - loss: 0.5760 - accuracy: 0.7433 - 1s/epoch - 17ms/step
# Epoch 215/500
# 72/72 - 1s - loss: 0.5880 - accuracy: 0.7360 - 1s/epoch - 17ms/step
# Epoch 216/500
# 72/72 - 1s - loss: 0.5725 - accuracy: 0.7448 - 1s/epoch - 17ms/step
# Epoch 217/500
# 72/72 - 1s - loss: 0.5673 - accuracy: 0.7448 - 1s/epoch - 18ms/step
# Epoch 218/500
# 72/72 - 1s - loss: 0.5827 - accuracy: 0.7413 - 1s/epoch - 17ms/step
# Epoch 219/500
# 72/72 - 1s - loss: 0.5739 - accuracy: 0.7420 - 1s/epoch - 17ms/step
# Epoch 220/500
# 72/72 - 1s - loss: 0.5634 - accuracy: 0.7459 - 1s/epoch - 18ms/step
# Epoch 221/500
# 72/72 - 1s - loss: 0.5667 - accuracy: 0.7402 - 1s/epoch - 18ms/step
# Epoch 222/500
# 72/72 - 1s - loss: 0.5769 - accuracy: 0.7311 - 1s/epoch - 17ms/step
# Epoch 223/500
# 72/72 - 1s - loss: 0.5760 - accuracy: 0.7434 - 1s/epoch - 18ms/step
# Epoch 224/500
# 72/72 - 1s - loss: 0.5764 - accuracy: 0.7407 - 1s/epoch - 17ms/step
# Epoch 225/500
# 72/72 - 1s - loss: 0.5636 - accuracy: 0.7398 - 1s/epoch - 17ms/step
# Epoch 226/500
# 72/72 - 1s - loss: 0.5677 - accuracy: 0.7433 - 1s/epoch - 18ms/step
# Epoch 227/500
# 72/72 - 1s - loss: 0.5626 - accuracy: 0.7476 - 1s/epoch - 17ms/step
# Epoch 228/500
# 72/72 - 1s - loss: 0.5641 - accuracy: 0.7442 - 1s/epoch - 17ms/step
# Epoch 229/500
# 72/72 - 1s - loss: 0.5762 - accuracy: 0.7439 - 1s/epoch - 18ms/step
# Epoch 230/500
# 72/72 - 1s - loss: 0.5701 - accuracy: 0.7441 - 1s/epoch - 18ms/step
# Epoch 231/500
# 72/72 - 1s - loss: 0.5803 - accuracy: 0.7387 - 1s/epoch - 17ms/step
# Epoch 232/500
# 72/72 - 1s - loss: 0.5625 - accuracy: 0.7490 - 1s/epoch - 17ms/step
# Epoch 233/500
# 72/72 - 1s - loss: 0.5602 - accuracy: 0.7495 - 1s/epoch - 17ms/step
# Epoch 234/500
# 72/72 - 1s - loss: 0.5650 - accuracy: 0.7462 - 1s/epoch - 17ms/step
# Epoch 235/500
# 72/72 - 1s - loss: 0.5614 - accuracy: 0.7476 - 1s/epoch - 17ms/step
# Epoch 236/500
# 72/72 - 1s - loss: 0.5872 - accuracy: 0.7378 - 1s/epoch - 18ms/step
# Epoch 237/500
# 72/72 - 1s - loss: 0.5623 - accuracy: 0.7522 - 1s/epoch - 18ms/step
# Epoch 238/500
# 72/72 - 1s - loss: 0.5769 - accuracy: 0.7437 - 1s/epoch - 18ms/step
# Epoch 239/500
# 72/72 - 1s - loss: 0.5692 - accuracy: 0.7428 - 1s/epoch - 18ms/step
# Epoch 240/500
# 72/72 - 1s - loss: 0.5725 - accuracy: 0.7404 - 1s/epoch - 18ms/step
# Epoch 241/500
# 72/72 - 1s - loss: 0.5563 - accuracy: 0.7540 - 1s/epoch - 17ms/step
# Epoch 242/500
# 72/72 - 1s - loss: 0.5588 - accuracy: 0.7502 - 1s/epoch - 17ms/step
# Epoch 243/500
# 72/72 - 1s - loss: 0.5620 - accuracy: 0.7533 - 1s/epoch - 17ms/step
# Epoch 244/500
# 72/72 - 1s - loss: 0.5544 - accuracy: 0.7538 - 1s/epoch - 17ms/step
# Epoch 245/500
# 72/72 - 1s - loss: 0.5539 - accuracy: 0.7522 - 1s/epoch - 18ms/step
# Epoch 246/500
# 72/72 - 1s - loss: 0.5635 - accuracy: 0.7460 - 1s/epoch - 18ms/step
# Epoch 247/500
# 72/72 - 1s - loss: 0.5585 - accuracy: 0.7498 - 1s/epoch - 18ms/step
# Epoch 248/500
# 72/72 - 1s - loss: 0.5528 - accuracy: 0.7507 - 1s/epoch - 18ms/step
# Epoch 249/500
# 72/72 - 1s - loss: 0.5443 - accuracy: 0.7577 - 1s/epoch - 18ms/step
# Epoch 250/500
# 72/72 - 1s - loss: 0.5546 - accuracy: 0.7457 - 1s/epoch - 17ms/step
# Epoch 251/500
# 72/72 - 1s - loss: 0.5613 - accuracy: 0.7507 - 1s/epoch - 17ms/step
# Epoch 252/500
# 72/72 - 1s - loss: 0.5602 - accuracy: 0.7482 - 1s/epoch - 17ms/step
# Epoch 253/500
# 72/72 - 1s - loss: 0.5668 - accuracy: 0.7435 - 1s/epoch - 18ms/step
# Epoch 254/500
# 72/72 - 1s - loss: 0.5535 - accuracy: 0.7495 - 1s/epoch - 17ms/step
# Epoch 255/500
# 72/72 - 1s - loss: 0.5439 - accuracy: 0.7592 - 1s/epoch - 18ms/step
# Epoch 256/500
# 72/72 - 1s - loss: 0.5453 - accuracy: 0.7527 - 1s/epoch - 18ms/step
# Epoch 257/500
# 72/72 - 1s - loss: 0.5442 - accuracy: 0.7568 - 1s/epoch - 18ms/step
# Epoch 258/500
# 72/72 - 1s - loss: 0.5239 - accuracy: 0.7646 - 1s/epoch - 18ms/step
# Epoch 259/500
# 72/72 - 1s - loss: 0.5485 - accuracy: 0.7587 - 1s/epoch - 17ms/step
# Epoch 260/500
# 72/72 - 1s - loss: 0.5491 - accuracy: 0.7554 - 1s/epoch - 17ms/step
# Epoch 261/500
# 72/72 - 1s - loss: 0.5561 - accuracy: 0.7526 - 1s/epoch - 17ms/step
# Epoch 262/500
# 72/72 - 1s - loss: 0.5577 - accuracy: 0.7542 - 1s/epoch - 18ms/step
# Epoch 263/500
# 72/72 - 1s - loss: 0.5570 - accuracy: 0.7542 - 1s/epoch - 17ms/step
# Epoch 264/500
# 72/72 - 1s - loss: 0.5500 - accuracy: 0.7583 - 1s/epoch - 17ms/step
# Epoch 265/500
# 72/72 - 1s - loss: 0.5465 - accuracy: 0.7588 - 1s/epoch - 18ms/step
# Epoch 266/500
# 72/72 - 1s - loss: 0.5426 - accuracy: 0.7601 - 1s/epoch - 18ms/step
# Epoch 267/500
# 72/72 - 1s - loss: 0.5383 - accuracy: 0.7574 - 1s/epoch - 18ms/step
# Epoch 268/500
# 72/72 - 1s - loss: 0.5372 - accuracy: 0.7604 - 1s/epoch - 17ms/step
# Epoch 269/500
# 72/72 - 1s - loss: 0.5338 - accuracy: 0.7608 - 1s/epoch - 17ms/step
# Epoch 270/500
# 72/72 - 1s - loss: 0.5350 - accuracy: 0.7627 - 1s/epoch - 18ms/step
# Epoch 271/500
# 72/72 - 1s - loss: 0.5429 - accuracy: 0.7540 - 1s/epoch - 17ms/step
# Epoch 272/500
# 72/72 - 1s - loss: 0.5310 - accuracy: 0.7604 - 1s/epoch - 17ms/step
# Epoch 273/500
# 72/72 - 1s - loss: 0.5466 - accuracy: 0.7603 - 1s/epoch - 17ms/step
# Epoch 274/500
# 72/72 - 1s - loss: 0.5410 - accuracy: 0.7572 - 1s/epoch - 17ms/step
# Epoch 275/500
# 72/72 - 1s - loss: 0.5340 - accuracy: 0.7621 - 1s/epoch - 18ms/step
# Epoch 276/500
# 72/72 - 1s - loss: 0.5391 - accuracy: 0.7597 - 1s/epoch - 19ms/step
# Epoch 277/500
# 72/72 - 1s - loss: 0.5331 - accuracy: 0.7696 - 1s/epoch - 17ms/step
# Epoch 278/500
# 72/72 - 1s - loss: 0.5442 - accuracy: 0.7545 - 1s/epoch - 17ms/step
# Epoch 279/500
# 72/72 - 1s - loss: 0.5326 - accuracy: 0.7647 - 1s/epoch - 17ms/step
# Epoch 280/500
# 72/72 - 1s - loss: 0.5255 - accuracy: 0.7687 - 1s/epoch - 17ms/step
# Epoch 281/500
# 72/72 - 1s - loss: 0.5328 - accuracy: 0.7638 - 1s/epoch - 18ms/step
# Epoch 282/500
# 72/72 - 1s - loss: 0.5299 - accuracy: 0.7704 - 1s/epoch - 17ms/step
# Epoch 283/500
# 72/72 - 1s - loss: 0.5305 - accuracy: 0.7672 - 1s/epoch - 17ms/step
# Epoch 284/500
# 72/72 - 1s - loss: 0.5279 - accuracy: 0.7663 - 1s/epoch - 18ms/step
# Epoch 285/500
# 72/72 - 1s - loss: 0.5359 - accuracy: 0.7607 - 1s/epoch - 18ms/step
# Epoch 286/500
# 72/72 - 1s - loss: 0.5357 - accuracy: 0.7628 - 1s/epoch - 18ms/step
# Epoch 287/500
# 72/72 - 1s - loss: 0.5262 - accuracy: 0.7658 - 1s/epoch - 18ms/step
# Epoch 288/500
# 72/72 - 1s - loss: 0.5403 - accuracy: 0.7633 - 1s/epoch - 17ms/step
# Epoch 289/500
# 72/72 - 1s - loss: 0.5299 - accuracy: 0.7652 - 1s/epoch - 18ms/step
# Epoch 290/500
# 72/72 - 1s - loss: 0.5260 - accuracy: 0.7652 - 1s/epoch - 17ms/step
# Epoch 291/500
# 72/72 - 1s - loss: 0.5220 - accuracy: 0.7659 - 1s/epoch - 18ms/step
# Epoch 292/500
# 72/72 - 1s - loss: 0.5324 - accuracy: 0.7685 - 1s/epoch - 18ms/step
# Epoch 293/500
# 72/72 - 1s - loss: 0.5337 - accuracy: 0.7650 - 1s/epoch - 18ms/step
# Epoch 294/500
# 72/72 - 1s - loss: 0.5274 - accuracy: 0.7671 - 1s/epoch - 18ms/step
# Epoch 295/500
# 72/72 - 1s - loss: 0.5288 - accuracy: 0.7720 - 1s/epoch - 18ms/step
# Epoch 296/500
# 72/72 - 1s - loss: 0.5271 - accuracy: 0.7675 - 1s/epoch - 18ms/step
# Epoch 297/500
# 72/72 - 1s - loss: 0.5208 - accuracy: 0.7679 - 1s/epoch - 17ms/step
# Epoch 298/500
# 72/72 - 1s - loss: 0.5250 - accuracy: 0.7718 - 1s/epoch - 17ms/step
# Epoch 299/500
# 72/72 - 1s - loss: 0.5266 - accuracy: 0.7692 - 1s/epoch - 17ms/step
# Epoch 300/500
# 72/72 - 1s - loss: 0.5219 - accuracy: 0.7670 - 1s/epoch - 18ms/step
# Epoch 301/500
# 72/72 - 1s - loss: 0.5062 - accuracy: 0.7738 - 1s/epoch - 18ms/step
# Epoch 302/500
# 72/72 - 1s - loss: 0.5256 - accuracy: 0.7704 - 1s/epoch - 17ms/step
# Epoch 303/500
# 72/72 - 1s - loss: 0.5396 - accuracy: 0.7603 - 1s/epoch - 18ms/step
# Epoch 304/500
# 72/72 - 1s - loss: 0.5331 - accuracy: 0.7600 - 1s/epoch - 18ms/step
# Epoch 305/500
# 72/72 - 1s - loss: 0.5252 - accuracy: 0.7657 - 1s/epoch - 18ms/step
# Epoch 306/500
# 72/72 - 1s - loss: 0.5378 - accuracy: 0.7649 - 1s/epoch - 18ms/step
# Epoch 307/500
# 72/72 - 1s - loss: 0.5169 - accuracy: 0.7707 - 1s/epoch - 17ms/step
# Epoch 308/500
# 72/72 - 1s - loss: 0.5195 - accuracy: 0.7729 - 1s/epoch - 18ms/step
# Epoch 309/500
# 72/72 - 1s - loss: 0.5081 - accuracy: 0.7766 - 1s/epoch - 17ms/step
# Epoch 310/500
# 72/72 - 1s - loss: 0.5167 - accuracy: 0.7747 - 1s/epoch - 17ms/step
# Epoch 311/500
# 72/72 - 1s - loss: 0.5123 - accuracy: 0.7716 - 1s/epoch - 17ms/step
# Epoch 312/500
# 72/72 - 1s - loss: 0.5167 - accuracy: 0.7700 - 1s/epoch - 18ms/step
# Epoch 313/500
# 72/72 - 1s - loss: 0.5014 - accuracy: 0.7773 - 1s/epoch - 18ms/step
# Epoch 314/500
# 72/72 - 1s - loss: 0.5151 - accuracy: 0.7707 - 1s/epoch - 17ms/step
# Epoch 315/500
# 72/72 - 1s - loss: 0.5167 - accuracy: 0.7750 - 1s/epoch - 17ms/step
# Epoch 316/500
# 72/72 - 1s - loss: 0.5080 - accuracy: 0.7810 - 1s/epoch - 18ms/step
# Epoch 317/500
# 72/72 - 1s - loss: 0.5091 - accuracy: 0.7762 - 1s/epoch - 18ms/step
# Epoch 318/500
# 72/72 - 1s - loss: 0.5028 - accuracy: 0.7808 - 1s/epoch - 18ms/step
# Epoch 319/500
# 72/72 - 1s - loss: 0.5046 - accuracy: 0.7778 - 1s/epoch - 18ms/step
# Epoch 320/500
# 72/72 - 1s - loss: 0.5062 - accuracy: 0.7808 - 1s/epoch - 18ms/step
# Epoch 321/500
# 72/72 - 1s - loss: 0.4983 - accuracy: 0.7839 - 1s/epoch - 18ms/step
# Epoch 322/500
# 72/72 - 1s - loss: 0.5084 - accuracy: 0.7788 - 1s/epoch - 18ms/step
# Epoch 323/500
# 72/72 - 1s - loss: 0.5033 - accuracy: 0.7779 - 1s/epoch - 17ms/step
# Epoch 324/500
# 72/72 - 1s - loss: 0.5005 - accuracy: 0.7821 - 1s/epoch - 17ms/step
# Epoch 325/500
# 72/72 - 1s - loss: 0.5067 - accuracy: 0.7810 - 1s/epoch - 18ms/step
# Epoch 326/500
# 72/72 - 1s - loss: 0.5046 - accuracy: 0.7763 - 1s/epoch - 17ms/step
# Epoch 327/500
# 72/72 - 1s - loss: 0.4993 - accuracy: 0.7807 - 1s/epoch - 18ms/step
# Epoch 328/500
# 72/72 - 1s - loss: 0.5042 - accuracy: 0.7799 - 1s/epoch - 17ms/step
# Epoch 329/500
# 72/72 - 1s - loss: 0.4963 - accuracy: 0.7846 - 1s/epoch - 17ms/step
# Epoch 330/500
# 72/72 - 1s - loss: 0.4953 - accuracy: 0.7864 - 1s/epoch - 17ms/step
# Epoch 331/500
# 72/72 - 1s - loss: 0.5025 - accuracy: 0.7798 - 1s/epoch - 18ms/step
# Epoch 332/500
# 72/72 - 1s - loss: 0.4966 - accuracy: 0.7810 - 1s/epoch - 18ms/step
# Epoch 333/500
# 72/72 - 1s - loss: 0.5032 - accuracy: 0.7810 - 1s/epoch - 18ms/step
# Epoch 334/500
# 72/72 - 1s - loss: 0.4977 - accuracy: 0.7830 - 1s/epoch - 18ms/step
# Epoch 335/500
# 72/72 - 1s - loss: 0.4995 - accuracy: 0.7821 - 1s/epoch - 18ms/step
# Epoch 336/500
# 72/72 - 1s - loss: 0.4959 - accuracy: 0.7749 - 1s/epoch - 18ms/step
# Epoch 337/500
# 72/72 - 1s - loss: 0.5005 - accuracy: 0.7829 - 1s/epoch - 17ms/step
# Epoch 338/500
# 72/72 - 1s - loss: 0.5024 - accuracy: 0.7813 - 1s/epoch - 17ms/step
# Epoch 339/500
# 72/72 - 1s - loss: 0.4931 - accuracy: 0.7849 - 1s/epoch - 17ms/step
# Epoch 340/500
# 72/72 - 1s - loss: 0.4846 - accuracy: 0.7854 - 1s/epoch - 18ms/step
# Epoch 341/500
# 72/72 - 1s - loss: 0.4957 - accuracy: 0.7820 - 1s/epoch - 18ms/step
# Epoch 342/500
# 72/72 - 1s - loss: 0.4893 - accuracy: 0.7852 - 1s/epoch - 17ms/step
# Epoch 343/500
# 72/72 - 1s - loss: 0.4996 - accuracy: 0.7813 - 1s/epoch - 17ms/step
# Epoch 344/500
# 72/72 - 1s - loss: 0.4851 - accuracy: 0.7863 - 1s/epoch - 17ms/step
# Epoch 345/500
# 72/72 - 1s - loss: 0.4957 - accuracy: 0.7875 - 1s/epoch - 18ms/step
# Epoch 346/500
# 72/72 - 1s - loss: 0.4844 - accuracy: 0.7851 - 1s/epoch - 17ms/step
# Epoch 347/500
# 72/72 - 1s - loss: 0.4843 - accuracy: 0.7853 - 1s/epoch - 18ms/step
# Epoch 348/500
# 72/72 - 1s - loss: 0.4807 - accuracy: 0.7924 - 1s/epoch - 17ms/step
# Epoch 349/500
# 72/72 - 1s - loss: 0.4915 - accuracy: 0.7863 - 1s/epoch - 18ms/step
# Epoch 350/500
# 72/72 - 1s - loss: 0.4929 - accuracy: 0.7916 - 1s/epoch - 18ms/step
# Epoch 351/500
# 72/72 - 1s - loss: 0.4935 - accuracy: 0.7850 - 1s/epoch - 17ms/step
# Epoch 352/500
# 72/72 - 1s - loss: 0.4830 - accuracy: 0.7874 - 1s/epoch - 17ms/step
# Epoch 353/500
# 72/72 - 1s - loss: 0.4947 - accuracy: 0.7836 - 1s/epoch - 17ms/step
# Epoch 354/500
# 72/72 - 1s - loss: 0.4819 - accuracy: 0.7886 - 1s/epoch - 17ms/step
# Epoch 355/500
# 72/72 - 1s - loss: 0.4798 - accuracy: 0.7924 - 1s/epoch - 18ms/step
# Epoch 356/500
# 72/72 - 1s - loss: 0.4895 - accuracy: 0.7824 - 1s/epoch - 17ms/step
# Epoch 357/500
# 72/72 - 1s - loss: 0.4798 - accuracy: 0.7896 - 1s/epoch - 17ms/step
# Epoch 358/500
# 72/72 - 1s - loss: 0.4835 - accuracy: 0.7870 - 1s/epoch - 18ms/step
# Epoch 359/500
# 72/72 - 1s - loss: 0.4806 - accuracy: 0.7874 - 1s/epoch - 18ms/step
# Epoch 360/500
# 72/72 - 1s - loss: 0.4772 - accuracy: 0.7883 - 1s/epoch - 17ms/step
# Epoch 361/500
# 72/72 - 1s - loss: 0.4815 - accuracy: 0.7909 - 1s/epoch - 17ms/step
# Epoch 362/500
# 72/72 - 1s - loss: 0.4721 - accuracy: 0.7960 - 1s/epoch - 17ms/step
# Epoch 363/500
# 72/72 - 1s - loss: 0.4688 - accuracy: 0.7963 - 1s/epoch - 18ms/step
# Epoch 364/500
# 72/72 - 1s - loss: 0.4749 - accuracy: 0.7957 - 1s/epoch - 18ms/step
# Epoch 365/500
# 72/72 - 1s - loss: 0.4777 - accuracy: 0.7916 - 1s/epoch - 18ms/step
# Epoch 366/500
# 72/72 - 1s - loss: 0.4820 - accuracy: 0.7932 - 1s/epoch - 18ms/step
# Epoch 367/500
# 72/72 - 1s - loss: 0.4640 - accuracy: 0.7984 - 1s/epoch - 18ms/step
# Epoch 368/500
# 72/72 - 1s - loss: 0.4749 - accuracy: 0.7957 - 1s/epoch - 18ms/step
# Epoch 369/500
# 72/72 - 1s - loss: 0.4717 - accuracy: 0.7940 - 1s/epoch - 18ms/step
# Epoch 370/500
# 72/72 - 1s - loss: 0.4679 - accuracy: 0.7974 - 1s/epoch - 17ms/step
# Epoch 371/500
# 72/72 - 1s - loss: 0.4677 - accuracy: 0.8008 - 1s/epoch - 17ms/step
# Epoch 372/500
# 72/72 - 1s - loss: 0.4640 - accuracy: 0.7972 - 1s/epoch - 18ms/step
# Epoch 373/500
# 72/72 - 1s - loss: 0.4598 - accuracy: 0.7996 - 1s/epoch - 17ms/step
# Epoch 374/500
# 72/72 - 1s - loss: 0.4634 - accuracy: 0.8016 - 1s/epoch - 17ms/step
# Epoch 375/500
# 72/72 - 1s - loss: 0.4782 - accuracy: 0.7937 - 1s/epoch - 17ms/step
# Epoch 376/500
# 72/72 - 1s - loss: 0.4565 - accuracy: 0.8021 - 1s/epoch - 17ms/step
# Epoch 377/500
# 72/72 - 1s - loss: 0.4607 - accuracy: 0.7988 - 1s/epoch - 18ms/step
# Epoch 378/500
# 72/72 - 1s - loss: 0.4630 - accuracy: 0.8005 - 1s/epoch - 18ms/step
# Epoch 379/500
# 72/72 - 1s - loss: 0.4650 - accuracy: 0.7998 - 1s/epoch - 17ms/step
# Epoch 380/500
# 72/72 - 1s - loss: 0.4690 - accuracy: 0.7993 - 1s/epoch - 17ms/step
# Epoch 381/500
# 72/72 - 1s - loss: 0.4756 - accuracy: 0.7929 - 1s/epoch - 17ms/step
# Epoch 382/500
# 72/72 - 1s - loss: 0.4675 - accuracy: 0.8018 - 1s/epoch - 17ms/step
# Epoch 383/500
# 72/72 - 1s - loss: 0.4503 - accuracy: 0.8061 - 1s/epoch - 17ms/step
# Epoch 384/500
# 72/72 - 1s - loss: 0.4552 - accuracy: 0.8036 - 1s/epoch - 17ms/step
# Epoch 385/500
# 72/72 - 1s - loss: 0.4616 - accuracy: 0.8016 - 1s/epoch - 17ms/step
# Epoch 386/500
# 72/72 - 1s - loss: 0.4625 - accuracy: 0.8012 - 1s/epoch - 18ms/step
# Epoch 387/500
# 72/72 - 1s - loss: 0.4540 - accuracy: 0.8066 - 1s/epoch - 18ms/step
# Epoch 388/500
# 72/72 - 1s - loss: 0.4519 - accuracy: 0.8049 - 1s/epoch - 17ms/step
# Epoch 389/500
# 72/72 - 1s - loss: 0.4589 - accuracy: 0.7987 - 1s/epoch - 17ms/step
# Epoch 390/500
# 72/72 - 1s - loss: 0.4485 - accuracy: 0.8078 - 1s/epoch - 17ms/step
# Epoch 391/500
# 72/72 - 1s - loss: 0.4564 - accuracy: 0.8066 - 1s/epoch - 17ms/step
# Epoch 392/500
# 72/72 - 1s - loss: 0.4571 - accuracy: 0.8049 - 1s/epoch - 17ms/step
# Epoch 393/500
# 72/72 - 1s - loss: 0.4445 - accuracy: 0.8104 - 1s/epoch - 17ms/step
# Epoch 394/500
# 72/72 - 1s - loss: 0.4515 - accuracy: 0.8048 - 1s/epoch - 17ms/step
# Epoch 395/500
# 72/72 - 1s - loss: 0.4467 - accuracy: 0.8122 - 1s/epoch - 18ms/step
# Epoch 396/500
# 72/72 - 1s - loss: 0.4582 - accuracy: 0.8047 - 1s/epoch - 18ms/step
# Epoch 397/500
# 72/72 - 1s - loss: 0.4573 - accuracy: 0.8029 - 1s/epoch - 17ms/step
# Epoch 398/500
# 72/72 - 1s - loss: 0.4980 - accuracy: 0.7871 - 1s/epoch - 17ms/step
# Epoch 399/500
# 72/72 - 1s - loss: 0.4825 - accuracy: 0.7943 - 1s/epoch - 17ms/step
# Epoch 400/500
# 72/72 - 1s - loss: 0.4641 - accuracy: 0.8020 - 1s/epoch - 17ms/step
# Epoch 401/500
# 72/72 - 1s - loss: 0.4508 - accuracy: 0.8012 - 1s/epoch - 17ms/step
# Epoch 402/500
# 72/72 - 1s - loss: 0.4574 - accuracy: 0.8049 - 1s/epoch - 17ms/step
# Epoch 403/500
# 72/72 - 1s - loss: 0.4540 - accuracy: 0.8024 - 1s/epoch - 17ms/step
# Epoch 404/500
# 72/72 - 1s - loss: 0.4440 - accuracy: 0.8080 - 1s/epoch - 17ms/step
# Epoch 405/500
# 72/72 - 1s - loss: 0.4388 - accuracy: 0.8150 - 1s/epoch - 18ms/step
# Epoch 406/500
# 72/72 - 1s - loss: 0.4422 - accuracy: 0.8174 - 1s/epoch - 18ms/step
# Epoch 407/500
# 72/72 - 1s - loss: 0.4460 - accuracy: 0.8143 - 1s/epoch - 17ms/step
# Epoch 408/500
# 72/72 - 1s - loss: 0.4547 - accuracy: 0.8060 - 1s/epoch - 17ms/step
# Epoch 409/500
# 72/72 - 1s - loss: 0.4457 - accuracy: 0.8122 - 1s/epoch - 17ms/step
# Epoch 410/500
# 72/72 - 1s - loss: 0.4447 - accuracy: 0.8129 - 1s/epoch - 17ms/step
# Epoch 411/500
# 72/72 - 1s - loss: 0.4616 - accuracy: 0.7993 - 1s/epoch - 17ms/step
# Epoch 412/500
# 72/72 - 1s - loss: 0.4411 - accuracy: 0.8105 - 1s/epoch - 17ms/step
# Epoch 413/500
# 72/72 - 1s - loss: 0.4456 - accuracy: 0.8099 - 1s/epoch - 17ms/step
# Epoch 414/500
# 72/72 - 1s - loss: 0.4419 - accuracy: 0.8062 - 1s/epoch - 18ms/step
# Epoch 415/500
# 72/72 - 1s - loss: 0.4449 - accuracy: 0.8101 - 1s/epoch - 18ms/step
# Epoch 416/500
# 72/72 - 1s - loss: 0.4368 - accuracy: 0.8168 - 1s/epoch - 17ms/step
# Epoch 417/500
# 72/72 - 1s - loss: 0.4371 - accuracy: 0.8120 - 1s/epoch - 17ms/step
# Epoch 418/500
# 72/72 - 1s - loss: 0.4413 - accuracy: 0.8137 - 1s/epoch - 17ms/step
# Epoch 419/500
# 72/72 - 1s - loss: 0.4323 - accuracy: 0.8145 - 1s/epoch - 17ms/step
# Epoch 420/500
# 72/72 - 1s - loss: 0.4446 - accuracy: 0.8042 - 1s/epoch - 18ms/step
# Epoch 421/500
# 72/72 - 1s - loss: 0.4237 - accuracy: 0.8203 - 1s/epoch - 17ms/step
# Epoch 422/500
# 72/72 - 1s - loss: 0.4201 - accuracy: 0.8204 - 1s/epoch - 17ms/step
# Epoch 423/500
# 72/72 - 1s - loss: 0.4291 - accuracy: 0.8184 - 1s/epoch - 18ms/step
# Epoch 424/500
# 72/72 - 1s - loss: 0.4315 - accuracy: 0.8166 - 1s/epoch - 18ms/step
# Epoch 425/500
# 72/72 - 1s - loss: 0.4266 - accuracy: 0.8201 - 1s/epoch - 18ms/step
# Epoch 426/500
# 72/72 - 1s - loss: 0.4300 - accuracy: 0.8159 - 1s/epoch - 18ms/step
# Epoch 427/500
# 72/72 - 1s - loss: 0.4321 - accuracy: 0.8143 - 1s/epoch - 18ms/step
# Epoch 428/500
# 72/72 - 1s - loss: 0.4229 - accuracy: 0.8183 - 1s/epoch - 18ms/step
# Epoch 429/500
# 72/72 - 1s - loss: 0.4165 - accuracy: 0.8249 - 1s/epoch - 18ms/step
# Epoch 430/500
# 72/72 - 1s - loss: 0.4196 - accuracy: 0.8230 - 1s/epoch - 17ms/step
# Epoch 431/500
# 72/72 - 1s - loss: 0.4322 - accuracy: 0.8165 - 1s/epoch - 17ms/step
# Epoch 432/500
# 72/72 - 1s - loss: 0.4387 - accuracy: 0.8205 - 1s/epoch - 18ms/step
# Epoch 433/500
# 72/72 - 1s - loss: 0.4181 - accuracy: 0.8261 - 1s/epoch - 18ms/step
# Epoch 434/500
# 72/72 - 1s - loss: 0.4175 - accuracy: 0.8263 - 1s/epoch - 18ms/step
# Epoch 435/500
# 72/72 - 1s - loss: 0.4217 - accuracy: 0.8247 - 1s/epoch - 18ms/step
# Epoch 436/500
# 72/72 - 1s - loss: 0.4212 - accuracy: 0.8220 - 1s/epoch - 17ms/step
# Epoch 437/500
# 72/72 - 1s - loss: 0.4298 - accuracy: 0.8208 - 1s/epoch - 17ms/step
# Epoch 438/500
# 72/72 - 1s - loss: 0.4155 - accuracy: 0.8296 - 1s/epoch - 17ms/step
# Epoch 439/500
# 72/72 - 1s - loss: 0.4156 - accuracy: 0.8303 - 1s/epoch - 17ms/step
# Epoch 440/500
# 72/72 - 1s - loss: 0.4125 - accuracy: 0.8271 - 1s/epoch - 17ms/step
# Epoch 441/500
# 72/72 - 1s - loss: 0.4050 - accuracy: 0.8263 - 1s/epoch - 17ms/step
# Epoch 442/500
# 72/72 - 1s - loss: 0.4104 - accuracy: 0.8246 - 1s/epoch - 18ms/step
# Epoch 443/500
# 72/72 - 1s - loss: 0.4255 - accuracy: 0.8198 - 1s/epoch - 18ms/step
# Epoch 444/500
# 72/72 - 1s - loss: 0.4152 - accuracy: 0.8289 - 1s/epoch - 18ms/step
# Epoch 445/500
# 72/72 - 1s - loss: 0.4162 - accuracy: 0.8264 - 1s/epoch - 18ms/step
# Epoch 446/500
# 72/72 - 1s - loss: 0.4101 - accuracy: 0.8329 - 1s/epoch - 18ms/step
# Epoch 447/500
# 72/72 - 1s - loss: 0.4060 - accuracy: 0.8288 - 1s/epoch - 17ms/step
# Epoch 448/500
# 72/72 - 1s - loss: 0.4218 - accuracy: 0.8232 - 1s/epoch - 17ms/step
# Epoch 449/500
# 72/72 - 1s - loss: 0.4122 - accuracy: 0.8260 - 1s/epoch - 17ms/step
# Epoch 450/500
# 72/72 - 1s - loss: 0.4158 - accuracy: 0.8228 - 1s/epoch - 17ms/step
# Epoch 451/500
# 72/72 - 1s - loss: 0.4113 - accuracy: 0.8278 - 1s/epoch - 18ms/step
# Epoch 452/500
# 72/72 - 1s - loss: 0.4139 - accuracy: 0.8313 - 1s/epoch - 18ms/step
# Epoch 453/500
# 72/72 - 1s - loss: 0.4091 - accuracy: 0.8288 - 1s/epoch - 17ms/step
# Epoch 454/500
# 72/72 - 1s - loss: 0.4101 - accuracy: 0.8295 - 1s/epoch - 18ms/step
# Epoch 455/500
# 72/72 - 1s - loss: 0.4121 - accuracy: 0.8299 - 1s/epoch - 18ms/step
# Epoch 456/500
# 72/72 - 1s - loss: 0.4030 - accuracy: 0.8304 - 1s/epoch - 17ms/step
# Epoch 457/500
# 72/72 - 1s - loss: 0.4052 - accuracy: 0.8329 - 1s/epoch - 17ms/step
# Epoch 458/500
# 72/72 - 1s - loss: 0.3985 - accuracy: 0.8318 - 1s/epoch - 18ms/step
# Epoch 459/500
# 72/72 - 1s - loss: 0.4030 - accuracy: 0.8283 - 1s/epoch - 17ms/step
# Epoch 460/500
# 72/72 - 1s - loss: 0.4058 - accuracy: 0.8298 - 1s/epoch - 18ms/step
# Epoch 461/500
# 72/72 - 1s - loss: 0.4025 - accuracy: 0.8314 - 1s/epoch - 18ms/step
# Epoch 462/500
# 72/72 - 1s - loss: 0.3985 - accuracy: 0.8329 - 1s/epoch - 18ms/step
# Epoch 463/500
# 72/72 - 1s - loss: 0.3939 - accuracy: 0.8397 - 1s/epoch - 18ms/step
# Epoch 464/500
# 72/72 - 1s - loss: 0.3967 - accuracy: 0.8332 - 1s/epoch - 18ms/step
# Epoch 465/500
# 72/72 - 1s - loss: 0.3999 - accuracy: 0.8287 - 1s/epoch - 17ms/step
# Epoch 466/500
# 72/72 - 1s - loss: 0.4024 - accuracy: 0.8354 - 1s/epoch - 17ms/step
# Epoch 467/500
# 72/72 - 1s - loss: 0.4126 - accuracy: 0.8241 - 1s/epoch - 17ms/step
# Epoch 468/500
# 72/72 - 1s - loss: 0.4020 - accuracy: 0.8317 - 1s/epoch - 17ms/step
# Epoch 469/500
# 72/72 - 1s - loss: 0.3826 - accuracy: 0.8405 - 1s/epoch - 18ms/step
# Epoch 470/500
# 72/72 - 1s - loss: 0.4055 - accuracy: 0.8352 - 1s/epoch - 18ms/step
# Epoch 471/500
# 72/72 - 1s - loss: 0.3975 - accuracy: 0.8357 - 1s/epoch - 17ms/step
# Epoch 472/500
# 72/72 - 1s - loss: 0.3842 - accuracy: 0.8428 - 1s/epoch - 17ms/step
# Epoch 473/500
# 72/72 - 1s - loss: 0.4022 - accuracy: 0.8345 - 1s/epoch - 18ms/step
# Epoch 474/500
# 72/72 - 1s - loss: 0.3907 - accuracy: 0.8333 - 1s/epoch - 17ms/step
# Epoch 475/500
# 72/72 - 1s - loss: 0.3853 - accuracy: 0.8378 - 1s/epoch - 18ms/step
# Epoch 476/500
# 72/72 - 1s - loss: 0.3965 - accuracy: 0.8410 - 1s/epoch - 18ms/step
# Epoch 477/500
# 72/72 - 1s - loss: 0.3982 - accuracy: 0.8334 - 1s/epoch - 18ms/step
# Epoch 478/500
# 72/72 - 1s - loss: 0.3758 - accuracy: 0.8420 - 1s/epoch - 18ms/step
# Epoch 479/500
# 72/72 - 1s - loss: 0.4068 - accuracy: 0.8323 - 1s/epoch - 18ms/step
# Epoch 480/500
# 72/72 - 1s - loss: 0.3874 - accuracy: 0.8408 - 1s/epoch - 18ms/step
# Epoch 481/500
# 72/72 - 1s - loss: 0.3977 - accuracy: 0.8355 - 1s/epoch - 17ms/step
# Epoch 482/500
# 72/72 - 1s - loss: 0.4090 - accuracy: 0.8271 - 1s/epoch - 17ms/step
# Epoch 483/500
# 72/72 - 1s - loss: 0.3794 - accuracy: 0.8393 - 1s/epoch - 18ms/step
# Epoch 484/500
# 72/72 - 1s - loss: 0.3970 - accuracy: 0.8361 - 1s/epoch - 18ms/step
# Epoch 485/500
# 72/72 - 1s - loss: 0.3744 - accuracy: 0.8424 - 1s/epoch - 17ms/step
# Epoch 486/500
# 72/72 - 1s - loss: 0.3825 - accuracy: 0.8422 - 1s/epoch - 17ms/step
# Epoch 487/500
# 72/72 - 1s - loss: 0.3879 - accuracy: 0.8399 - 1s/epoch - 18ms/step
# Epoch 488/500
# 72/72 - 1s - loss: 0.3790 - accuracy: 0.8464 - 1s/epoch - 18ms/step
# Epoch 489/500
# 72/72 - 1s - loss: 0.3726 - accuracy: 0.8443 - 1s/epoch - 18ms/step
# Epoch 490/500
# 72/72 - 1s - loss: 0.3816 - accuracy: 0.8411 - 1s/epoch - 17ms/step
# Epoch 491/500
# 72/72 - 1s - loss: 0.3821 - accuracy: 0.8412 - 1s/epoch - 18ms/step
# Epoch 492/500
# 72/72 - 1s - loss: 0.3754 - accuracy: 0.8405 - 1s/epoch - 17ms/step
# Epoch 493/500
# 72/72 - 1s - loss: 0.3819 - accuracy: 0.8432 - 1s/epoch - 18ms/step
# Epoch 494/500
# 72/72 - 1s - loss: 0.3812 - accuracy: 0.8433 - 1s/epoch - 18ms/step
# Epoch 495/500
# 72/72 - 1s - loss: 0.3816 - accuracy: 0.8437 - 1s/epoch - 17ms/step
# Epoch 496/500
# 72/72 - 1s - loss: 0.3701 - accuracy: 0.8475 - 1s/epoch - 17ms/step
# Epoch 497/500
# 72/72 - 1s - loss: 0.3754 - accuracy: 0.8452 - 1s/epoch - 18ms/step
# Epoch 498/500
# 72/72 - 1s - loss: 0.3825 - accuracy: 0.8418 - 1s/epoch - 18ms/step
# Epoch 499/500
# 72/72 - 1s - loss: 0.3632 - accuracy: 0.8505 - 1s/epoch - 17ms/step
# Epoch 500/500
# 72/72 - 1s - loss: 0.3706 - accuracy: 0.8497 - 1s/epoch - 17ms/step
# 72/72 [==============================] - 1s 7ms/step
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 5ms/step
# accuracy_score: 0.5778
# cohen_kappa_score: 0.4723
# log_loss: 1.3876
# zero_one_loss: 0.4222
# hemming_loss: 0.4222
# matthews_corrcoef: 0.4828
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.5694499015808105
# 72/72 [==============================] - 1s 6ms/step - loss: 1.3876 - accuracy: 0.5778
# 72/72 [==============================] - 0s 5ms/step
# Test runtime: 1.7286717891693115
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 6ms/step - loss: 1.3876 - accuracy: 0.5778
# 72/72 [==============================] - 0s 6ms/step - loss: 1.3876 - accuracy: 0.5778
# 72/72 [==============================] - 0s 5ms/step
# 72/72 [==============================] - 0s 7ms/step - loss: 1.3876 - accuracy: 0.5778
# 72/72 [==============================] - 0s 6ms/step
