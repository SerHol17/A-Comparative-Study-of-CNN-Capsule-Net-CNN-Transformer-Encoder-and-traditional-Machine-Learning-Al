# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
data_path6 = '/content/Epileptic Seizure Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  Labels[i] = Labels[i]-1

# %%
Labels
# Out:
# array([3, 0, 4, ..., 4, 2, 3])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 3    2300
# 0    2300
# 4    2300
# 1    2300
# 2    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, Labels, test_size=0.2, stratify=Labels, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (9200, 178)
# Train labels shape: (9200,)
# Test data shape: (2300, 178)
# Test labels shape: (2300,)

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test=pca.transform(X_test)

# %%
X_train.shape
# Out:
# (9200, 41)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (9200, 41, 1)

# %%
#classes
classes = [0, 1, 2, 3, 4]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=5
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,1,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 1, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  #Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(Layer_1)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7f0ad224af80>)
# Epoch 1/500
# 72/72 - 19s - loss: 1.2186 - accuracy: 0.4437 - 19s/epoch - 270ms/step
# Epoch 2/500
# 72/72 - 1s - loss: 0.9880 - accuracy: 0.5627 - 760ms/epoch - 11ms/step
# Epoch 3/500
# 72/72 - 1s - loss: 0.9179 - accuracy: 0.5910 - 777ms/epoch - 11ms/step
# Epoch 4/500
# 72/72 - 1s - loss: 0.8895 - accuracy: 0.6014 - 786ms/epoch - 11ms/step
# Epoch 5/500
# 72/72 - 1s - loss: 0.8598 - accuracy: 0.6158 - 771ms/epoch - 11ms/step
# Epoch 6/500
# 72/72 - 1s - loss: 0.8464 - accuracy: 0.6192 - 757ms/epoch - 11ms/step
# Epoch 7/500
# 72/72 - 1s - loss: 0.8288 - accuracy: 0.6292 - 771ms/epoch - 11ms/step
# Epoch 8/500
# 72/72 - 1s - loss: 0.8305 - accuracy: 0.6250 - 774ms/epoch - 11ms/step
# Epoch 9/500
# 72/72 - 1s - loss: 0.8225 - accuracy: 0.6205 - 774ms/epoch - 11ms/step
# Epoch 10/500
# 72/72 - 1s - loss: 0.8166 - accuracy: 0.6351 - 769ms/epoch - 11ms/step
# Epoch 11/500
# 72/72 - 1s - loss: 0.7985 - accuracy: 0.6352 - 965ms/epoch - 13ms/step
# Epoch 12/500
# 72/72 - 1s - loss: 0.7932 - accuracy: 0.6383 - 998ms/epoch - 14ms/step
# Epoch 13/500
# 72/72 - 1s - loss: 0.7968 - accuracy: 0.6379 - 865ms/epoch - 12ms/step
# Epoch 14/500
# 72/72 - 1s - loss: 0.7878 - accuracy: 0.6447 - 790ms/epoch - 11ms/step
# Epoch 15/500
# 72/72 - 1s - loss: 0.7677 - accuracy: 0.6496 - 919ms/epoch - 13ms/step
# Epoch 16/500
# 72/72 - 1s - loss: 0.7751 - accuracy: 0.6452 - 1s/epoch - 18ms/step
# Epoch 17/500
# 72/72 - 1s - loss: 0.7635 - accuracy: 0.6526 - 1s/epoch - 18ms/step
# Epoch 18/500
# 72/72 - 1s - loss: 0.7578 - accuracy: 0.6528 - 1s/epoch - 19ms/step
# Epoch 19/500
# 72/72 - 1s - loss: 0.7545 - accuracy: 0.6559 - 799ms/epoch - 11ms/step
# Epoch 20/500
# 72/72 - 1s - loss: 0.7539 - accuracy: 0.6485 - 777ms/epoch - 11ms/step
# Epoch 21/500
# 72/72 - 1s - loss: 0.7594 - accuracy: 0.6500 - 798ms/epoch - 11ms/step
# Epoch 22/500
# 72/72 - 1s - loss: 0.7563 - accuracy: 0.6466 - 775ms/epoch - 11ms/step
# Epoch 23/500
# 72/72 - 1s - loss: 0.7601 - accuracy: 0.6516 - 859ms/epoch - 12ms/step
# Epoch 24/500
# 72/72 - 1s - loss: 0.7449 - accuracy: 0.6559 - 1s/epoch - 14ms/step
# Epoch 25/500
# 72/72 - 1s - loss: 0.7378 - accuracy: 0.6627 - 1s/epoch - 14ms/step
# Epoch 26/500
# 72/72 - 1s - loss: 0.7515 - accuracy: 0.6562 - 781ms/epoch - 11ms/step
# Epoch 27/500
# 72/72 - 1s - loss: 0.7433 - accuracy: 0.6557 - 781ms/epoch - 11ms/step
# Epoch 28/500
# 72/72 - 1s - loss: 0.7381 - accuracy: 0.6609 - 788ms/epoch - 11ms/step
# Epoch 29/500
# 72/72 - 1s - loss: 0.7329 - accuracy: 0.6613 - 794ms/epoch - 11ms/step
# Epoch 30/500
# 72/72 - 1s - loss: 0.7302 - accuracy: 0.6607 - 792ms/epoch - 11ms/step
# Epoch 31/500
# 72/72 - 1s - loss: 0.7200 - accuracy: 0.6696 - 775ms/epoch - 11ms/step
# Epoch 32/500
# 72/72 - 1s - loss: 0.7237 - accuracy: 0.6682 - 785ms/epoch - 11ms/step
# Epoch 33/500
# 72/72 - 1s - loss: 0.7281 - accuracy: 0.6620 - 786ms/epoch - 11ms/step
# Epoch 34/500
# 72/72 - 1s - loss: 0.7193 - accuracy: 0.6659 - 789ms/epoch - 11ms/step
# Epoch 35/500
# 72/72 - 1s - loss: 0.7281 - accuracy: 0.6624 - 780ms/epoch - 11ms/step
# Epoch 36/500
# 72/72 - 1s - loss: 0.7246 - accuracy: 0.6639 - 792ms/epoch - 11ms/step
# Epoch 37/500
# 72/72 - 1s - loss: 0.7228 - accuracy: 0.6630 - 784ms/epoch - 11ms/step
# Epoch 38/500
# 72/72 - 1s - loss: 0.7257 - accuracy: 0.6616 - 933ms/epoch - 13ms/step
# Epoch 39/500
# 72/72 - 1s - loss: 0.7075 - accuracy: 0.6654 - 1s/epoch - 14ms/step
# Epoch 40/500
# 72/72 - 1s - loss: 0.7143 - accuracy: 0.6679 - 956ms/epoch - 13ms/step
# Epoch 41/500
# 72/72 - 1s - loss: 0.7054 - accuracy: 0.6670 - 796ms/epoch - 11ms/step
# Epoch 42/500
# 72/72 - 1s - loss: 0.7119 - accuracy: 0.6712 - 780ms/epoch - 11ms/step
# Epoch 43/500
# 72/72 - 1s - loss: 0.7013 - accuracy: 0.6684 - 798ms/epoch - 11ms/step
# Epoch 44/500
# 72/72 - 1s - loss: 0.7025 - accuracy: 0.6726 - 799ms/epoch - 11ms/step
# Epoch 45/500
# 72/72 - 1s - loss: 0.7037 - accuracy: 0.6698 - 810ms/epoch - 11ms/step
# Epoch 46/500
# 72/72 - 1s - loss: 0.7182 - accuracy: 0.6659 - 801ms/epoch - 11ms/step
# Epoch 47/500
# 72/72 - 1s - loss: 0.7089 - accuracy: 0.6680 - 808ms/epoch - 11ms/step
# Epoch 48/500
# 72/72 - 1s - loss: 0.7016 - accuracy: 0.6714 - 821ms/epoch - 11ms/step
# Epoch 49/500
# 72/72 - 1s - loss: 0.7036 - accuracy: 0.6722 - 800ms/epoch - 11ms/step
# Epoch 50/500
# 72/72 - 1s - loss: 0.7039 - accuracy: 0.6763 - 790ms/epoch - 11ms/step
# Epoch 51/500
# 72/72 - 1s - loss: 0.6966 - accuracy: 0.6760 - 796ms/epoch - 11ms/step
# Epoch 52/500
# 72/72 - 1s - loss: 0.7101 - accuracy: 0.6702 - 790ms/epoch - 11ms/step
# Epoch 53/500
# 72/72 - 1s - loss: 0.6964 - accuracy: 0.6757 - 1s/epoch - 14ms/step
# Epoch 54/500
# 72/72 - 1s - loss: 0.6972 - accuracy: 0.6751 - 1s/epoch - 14ms/step
# Epoch 55/500
# 72/72 - 1s - loss: 0.6968 - accuracy: 0.6726 - 859ms/epoch - 12ms/step
# Epoch 56/500
# 72/72 - 1s - loss: 0.6870 - accuracy: 0.6759 - 794ms/epoch - 11ms/step
# Epoch 57/500
# 72/72 - 1s - loss: 0.6984 - accuracy: 0.6775 - 800ms/epoch - 11ms/step
# Epoch 58/500
# 72/72 - 1s - loss: 0.6887 - accuracy: 0.6796 - 795ms/epoch - 11ms/step
# Epoch 59/500
# 72/72 - 1s - loss: 0.7013 - accuracy: 0.6729 - 793ms/epoch - 11ms/step
# Epoch 60/500
# 72/72 - 1s - loss: 0.6932 - accuracy: 0.6782 - 805ms/epoch - 11ms/step
# Epoch 61/500
# 72/72 - 1s - loss: 0.6840 - accuracy: 0.6739 - 810ms/epoch - 11ms/step
# Epoch 62/500
# 72/72 - 1s - loss: 0.6903 - accuracy: 0.6758 - 812ms/epoch - 11ms/step
# Epoch 63/500
# 72/72 - 1s - loss: 0.6870 - accuracy: 0.6770 - 814ms/epoch - 11ms/step
# Epoch 64/500
# 72/72 - 1s - loss: 0.6892 - accuracy: 0.6734 - 807ms/epoch - 11ms/step
# Epoch 65/500
# 72/72 - 1s - loss: 0.6798 - accuracy: 0.6805 - 818ms/epoch - 11ms/step
# Epoch 66/500
# 72/72 - 1s - loss: 0.6896 - accuracy: 0.6764 - 824ms/epoch - 11ms/step
# Epoch 67/500
# 72/72 - 1s - loss: 0.6944 - accuracy: 0.6718 - 953ms/epoch - 13ms/step
# Epoch 68/500
# 72/72 - 1s - loss: 0.6787 - accuracy: 0.6825 - 1s/epoch - 14ms/step
# Epoch 69/500
# 72/72 - 1s - loss: 0.6833 - accuracy: 0.6767 - 951ms/epoch - 13ms/step
# Epoch 70/500
# 72/72 - 1s - loss: 0.6812 - accuracy: 0.6750 - 813ms/epoch - 11ms/step
# Epoch 71/500
# 72/72 - 1s - loss: 0.6720 - accuracy: 0.6810 - 808ms/epoch - 11ms/step
# Epoch 72/500
# 72/72 - 1s - loss: 0.6815 - accuracy: 0.6775 - 824ms/epoch - 11ms/step
# Epoch 73/500
# 72/72 - 1s - loss: 0.6693 - accuracy: 0.6895 - 809ms/epoch - 11ms/step
# Epoch 74/500
# 72/72 - 1s - loss: 0.6730 - accuracy: 0.6822 - 814ms/epoch - 11ms/step
# Epoch 75/500
# 72/72 - 1s - loss: 0.6766 - accuracy: 0.6805 - 810ms/epoch - 11ms/step
# Epoch 76/500
# 72/72 - 1s - loss: 0.6735 - accuracy: 0.6833 - 804ms/epoch - 11ms/step
# Epoch 77/500
# 72/72 - 1s - loss: 0.6712 - accuracy: 0.6804 - 807ms/epoch - 11ms/step
# Epoch 78/500
# 72/72 - 1s - loss: 0.6731 - accuracy: 0.6855 - 815ms/epoch - 11ms/step
# Epoch 79/500
# 72/72 - 1s - loss: 0.6744 - accuracy: 0.6824 - 806ms/epoch - 11ms/step
# Epoch 80/500
# 72/72 - 1s - loss: 0.6663 - accuracy: 0.6918 - 810ms/epoch - 11ms/step
# Epoch 81/500
# 72/72 - 1s - loss: 0.6743 - accuracy: 0.6866 - 891ms/epoch - 12ms/step
# Epoch 82/500
# 72/72 - 1s - loss: 0.6769 - accuracy: 0.6878 - 1s/epoch - 15ms/step
# Epoch 83/500
# 72/72 - 1s - loss: 0.6652 - accuracy: 0.6922 - 1s/epoch - 14ms/step
# Epoch 84/500
# 72/72 - 1s - loss: 0.6652 - accuracy: 0.6910 - 806ms/epoch - 11ms/step
# Epoch 85/500
# 72/72 - 1s - loss: 0.6686 - accuracy: 0.6926 - 804ms/epoch - 11ms/step
# Epoch 86/500
# 72/72 - 1s - loss: 0.6699 - accuracy: 0.6861 - 799ms/epoch - 11ms/step
# Epoch 87/500
# 72/72 - 1s - loss: 0.6671 - accuracy: 0.6890 - 803ms/epoch - 11ms/step
# Epoch 88/500
# 72/72 - 1s - loss: 0.6635 - accuracy: 0.7017 - 801ms/epoch - 11ms/step
# Epoch 89/500
# 72/72 - 1s - loss: 0.6602 - accuracy: 0.6959 - 809ms/epoch - 11ms/step
# Epoch 90/500
# 72/72 - 1s - loss: 0.6602 - accuracy: 0.6904 - 810ms/epoch - 11ms/step
# Epoch 91/500
# 72/72 - 1s - loss: 0.6646 - accuracy: 0.6983 - 829ms/epoch - 12ms/step
# Epoch 92/500
# 72/72 - 1s - loss: 0.6578 - accuracy: 0.6954 - 792ms/epoch - 11ms/step
# Epoch 93/500
# 72/72 - 1s - loss: 0.6714 - accuracy: 0.6923 - 787ms/epoch - 11ms/step
# Epoch 94/500
# 72/72 - 1s - loss: 0.6681 - accuracy: 0.6903 - 805ms/epoch - 11ms/step
# Epoch 95/500
# 72/72 - 1s - loss: 0.6571 - accuracy: 0.7002 - 798ms/epoch - 11ms/step
# Epoch 96/500
# 72/72 - 1s - loss: 0.6540 - accuracy: 0.7025 - 973ms/epoch - 14ms/step
# Epoch 97/500
# 72/72 - 1s - loss: 0.6664 - accuracy: 0.6907 - 1s/epoch - 14ms/step
# Epoch 98/500
# 72/72 - 1s - loss: 0.7116 - accuracy: 0.6718 - 869ms/epoch - 12ms/step
# Epoch 99/500
# 72/72 - 1s - loss: 0.7006 - accuracy: 0.6787 - 804ms/epoch - 11ms/step
# Epoch 100/500
# 72/72 - 1s - loss: 0.6789 - accuracy: 0.6841 - 797ms/epoch - 11ms/step
# Epoch 101/500
# 72/72 - 1s - loss: 0.6762 - accuracy: 0.6834 - 792ms/epoch - 11ms/step
# Epoch 102/500
# 72/72 - 1s - loss: 0.6722 - accuracy: 0.6812 - 804ms/epoch - 11ms/step
# Epoch 103/500
# 72/72 - 1s - loss: 0.6680 - accuracy: 0.6841 - 803ms/epoch - 11ms/step
# Epoch 104/500
# 72/72 - 1s - loss: 0.6634 - accuracy: 0.6873 - 793ms/epoch - 11ms/step
# Epoch 105/500
# 72/72 - 1s - loss: 0.6545 - accuracy: 0.6985 - 791ms/epoch - 11ms/step
# Epoch 106/500
# 72/72 - 1s - loss: 0.6555 - accuracy: 0.6978 - 792ms/epoch - 11ms/step
# Epoch 107/500
# 72/72 - 1s - loss: 0.6606 - accuracy: 0.6962 - 795ms/epoch - 11ms/step
# Epoch 108/500
# 72/72 - 1s - loss: 0.6538 - accuracy: 0.6964 - 796ms/epoch - 11ms/step
# Epoch 109/500
# 72/72 - 1s - loss: 0.6419 - accuracy: 0.7089 - 803ms/epoch - 11ms/step
# Epoch 110/500
# 72/72 - 1s - loss: 0.6420 - accuracy: 0.7034 - 923ms/epoch - 13ms/step
# Epoch 111/500
# 72/72 - 1s - loss: 0.6996 - accuracy: 0.6945 - 1s/epoch - 15ms/step
# Epoch 112/500
# 72/72 - 1s - loss: 0.7206 - accuracy: 0.6812 - 1s/epoch - 14ms/step
# Epoch 113/500
# 72/72 - 1s - loss: 0.7378 - accuracy: 0.6728 - 807ms/epoch - 11ms/step
# Epoch 114/500
# 72/72 - 1s - loss: 0.7055 - accuracy: 0.6830 - 809ms/epoch - 11ms/step
# Epoch 115/500
# 72/72 - 1s - loss: 0.6883 - accuracy: 0.6918 - 810ms/epoch - 11ms/step
# Epoch 116/500
# 72/72 - 1s - loss: 0.6779 - accuracy: 0.6942 - 810ms/epoch - 11ms/step
# Epoch 117/500
# 72/72 - 1s - loss: 0.6777 - accuracy: 0.6912 - 805ms/epoch - 11ms/step
# Epoch 118/500
# 72/72 - 1s - loss: 0.6647 - accuracy: 0.7000 - 795ms/epoch - 11ms/step
# Epoch 119/500
# 72/72 - 1s - loss: 0.6541 - accuracy: 0.7038 - 793ms/epoch - 11ms/step
# Epoch 120/500
# 72/72 - 1s - loss: 0.6523 - accuracy: 0.7025 - 808ms/epoch - 11ms/step
# Epoch 121/500
# 72/72 - 1s - loss: 0.6482 - accuracy: 0.7077 - 787ms/epoch - 11ms/step
# Epoch 122/500
# 72/72 - 1s - loss: 0.6426 - accuracy: 0.7128 - 798ms/epoch - 11ms/step
# Epoch 123/500
# 72/72 - 1s - loss: 0.6471 - accuracy: 0.7070 - 791ms/epoch - 11ms/step
# Epoch 124/500
# 72/72 - 1s - loss: 0.6433 - accuracy: 0.7063 - 794ms/epoch - 11ms/step
# Epoch 125/500
# 72/72 - 1s - loss: 0.6484 - accuracy: 0.7040 - 1s/epoch - 14ms/step
# Epoch 126/500
# 72/72 - 1s - loss: 0.6437 - accuracy: 0.7007 - 1s/epoch - 15ms/step
# Epoch 127/500
# 72/72 - 1s - loss: 0.6452 - accuracy: 0.7054 - 852ms/epoch - 12ms/step
# Epoch 128/500
# 72/72 - 1s - loss: 0.6416 - accuracy: 0.7073 - 784ms/epoch - 11ms/step
# Epoch 129/500
# 72/72 - 1s - loss: 0.6354 - accuracy: 0.7135 - 799ms/epoch - 11ms/step
# Epoch 130/500
# 72/72 - 1s - loss: 0.6339 - accuracy: 0.7162 - 795ms/epoch - 11ms/step
# Epoch 131/500
# 72/72 - 1s - loss: 0.6411 - accuracy: 0.7204 - 801ms/epoch - 11ms/step
# Epoch 132/500
# 72/72 - 1s - loss: 0.6357 - accuracy: 0.7168 - 795ms/epoch - 11ms/step
# Epoch 133/500
# 72/72 - 1s - loss: 0.7392 - accuracy: 0.6618 - 794ms/epoch - 11ms/step
# Epoch 134/500
# 72/72 - 1s - loss: 1.0229 - accuracy: 0.5253 - 799ms/epoch - 11ms/step
# Epoch 135/500
# 72/72 - 1s - loss: 0.9207 - accuracy: 0.5786 - 799ms/epoch - 11ms/step
# Epoch 136/500
# 72/72 - 1s - loss: 0.8312 - accuracy: 0.6210 - 785ms/epoch - 11ms/step
# Epoch 137/500
# 72/72 - 1s - loss: 0.7912 - accuracy: 0.6449 - 786ms/epoch - 11ms/step
# Epoch 138/500
# 72/72 - 1s - loss: 0.7841 - accuracy: 0.6485 - 799ms/epoch - 11ms/step
# Epoch 139/500
# 72/72 - 1s - loss: 0.7643 - accuracy: 0.6560 - 899ms/epoch - 12ms/step
# Epoch 140/500
# 72/72 - 1s - loss: 0.7461 - accuracy: 0.6612 - 988ms/epoch - 14ms/step
# Epoch 141/500
# 72/72 - 1s - loss: 0.7506 - accuracy: 0.6595 - 981ms/epoch - 14ms/step
# Epoch 142/500
# 72/72 - 1s - loss: 0.7548 - accuracy: 0.6601 - 789ms/epoch - 11ms/step
# Epoch 143/500
# 72/72 - 1s - loss: 0.7677 - accuracy: 0.6555 - 798ms/epoch - 11ms/step
# Epoch 144/500
# 72/72 - 1s - loss: 0.7318 - accuracy: 0.6668 - 782ms/epoch - 11ms/step
# Epoch 145/500
# 72/72 - 1s - loss: 0.7372 - accuracy: 0.6567 - 808ms/epoch - 11ms/step
# Epoch 146/500
# 72/72 - 1s - loss: 0.7565 - accuracy: 0.6591 - 796ms/epoch - 11ms/step
# Epoch 147/500
# 72/72 - 1s - loss: 0.7431 - accuracy: 0.6690 - 798ms/epoch - 11ms/step
# Epoch 148/500
# 72/72 - 1s - loss: 0.7422 - accuracy: 0.6611 - 791ms/epoch - 11ms/step
# Epoch 149/500
# 72/72 - 1s - loss: 0.7671 - accuracy: 0.6596 - 792ms/epoch - 11ms/step
# Epoch 150/500
# 72/72 - 1s - loss: 0.7354 - accuracy: 0.6637 - 794ms/epoch - 11ms/step
# Epoch 151/500
# 72/72 - 1s - loss: 0.7147 - accuracy: 0.6722 - 790ms/epoch - 11ms/step
# Epoch 152/500
# 72/72 - 1s - loss: 0.7103 - accuracy: 0.6750 - 790ms/epoch - 11ms/step
# Epoch 153/500
# 72/72 - 1s - loss: 0.7028 - accuracy: 0.6748 - 785ms/epoch - 11ms/step
# Epoch 154/500
# 72/72 - 1s - loss: 0.7075 - accuracy: 0.6753 - 939ms/epoch - 13ms/step
# Epoch 155/500
# 72/72 - 1s - loss: 0.6967 - accuracy: 0.6779 - 1s/epoch - 14ms/step
# Epoch 156/500
# 72/72 - 1s - loss: 0.6854 - accuracy: 0.6799 - 885ms/epoch - 12ms/step
# Epoch 157/500
# 72/72 - 1s - loss: 0.6844 - accuracy: 0.6787 - 797ms/epoch - 11ms/step
# Epoch 158/500
# 72/72 - 1s - loss: 0.6804 - accuracy: 0.6828 - 791ms/epoch - 11ms/step
# Epoch 159/500
# 72/72 - 1s - loss: 0.6703 - accuracy: 0.6876 - 788ms/epoch - 11ms/step
# Epoch 160/500
# 72/72 - 1s - loss: 0.7306 - accuracy: 0.6718 - 788ms/epoch - 11ms/step
# Epoch 161/500
# 72/72 - 1s - loss: 0.7317 - accuracy: 0.6614 - 793ms/epoch - 11ms/step
# Epoch 162/500
# 72/72 - 1s - loss: 0.7224 - accuracy: 0.6676 - 796ms/epoch - 11ms/step
# Epoch 163/500
# 72/72 - 1s - loss: 0.6995 - accuracy: 0.6789 - 808ms/epoch - 11ms/step
# Epoch 164/500
# 72/72 - 1s - loss: 0.6856 - accuracy: 0.6820 - 811ms/epoch - 11ms/step
# Epoch 165/500
# 72/72 - 1s - loss: 0.6848 - accuracy: 0.6814 - 790ms/epoch - 11ms/step
# Epoch 166/500
# 72/72 - 1s - loss: 0.6712 - accuracy: 0.6860 - 794ms/epoch - 11ms/step
# Epoch 167/500
# 72/72 - 1s - loss: 0.6741 - accuracy: 0.6860 - 806ms/epoch - 11ms/step
# Epoch 168/500
# 72/72 - 1s - loss: 0.6715 - accuracy: 0.6902 - 840ms/epoch - 12ms/step
# Epoch 169/500
# 72/72 - 1s - loss: 0.7117 - accuracy: 0.6720 - 1s/epoch - 14ms/step
# Epoch 170/500
# 72/72 - 1s - loss: 0.7071 - accuracy: 0.6716 - 1s/epoch - 14ms/step
# Epoch 171/500
# 72/72 - 1s - loss: 0.6817 - accuracy: 0.6809 - 795ms/epoch - 11ms/step
# Epoch 172/500
# 72/72 - 1s - loss: 0.6754 - accuracy: 0.6870 - 787ms/epoch - 11ms/step
# Epoch 173/500
# 72/72 - 1s - loss: 0.8152 - accuracy: 0.6362 - 803ms/epoch - 11ms/step
# Epoch 174/500
# 72/72 - 1s - loss: 0.6924 - accuracy: 0.6834 - 792ms/epoch - 11ms/step
# Epoch 175/500
# 72/72 - 1s - loss: 0.6769 - accuracy: 0.6861 - 800ms/epoch - 11ms/step
# Epoch 176/500
# 72/72 - 1s - loss: 0.6689 - accuracy: 0.6901 - 789ms/epoch - 11ms/step
# Epoch 177/500
# 72/72 - 1s - loss: 0.6679 - accuracy: 0.6876 - 796ms/epoch - 11ms/step
# Epoch 178/500
# 72/72 - 1s - loss: 0.6624 - accuracy: 0.6936 - 808ms/epoch - 11ms/step
# Epoch 179/500
# 72/72 - 1s - loss: 0.6876 - accuracy: 0.6808 - 798ms/epoch - 11ms/step
# Epoch 180/500
# 72/72 - 1s - loss: 0.6867 - accuracy: 0.6854 - 800ms/epoch - 11ms/step
# Epoch 181/500
# 72/72 - 1s - loss: 0.6712 - accuracy: 0.6863 - 796ms/epoch - 11ms/step
# Epoch 182/500
# 72/72 - 1s - loss: 0.6546 - accuracy: 0.6974 - 800ms/epoch - 11ms/step
# Epoch 183/500
# 72/72 - 1s - loss: 0.6621 - accuracy: 0.6938 - 950ms/epoch - 13ms/step
# Epoch 184/500
# 72/72 - 1s - loss: 0.6493 - accuracy: 0.7060 - 1s/epoch - 14ms/step
# Epoch 185/500
# 72/72 - 1s - loss: 0.6578 - accuracy: 0.7008 - 926ms/epoch - 13ms/step
# Epoch 186/500
# 72/72 - 1s - loss: 0.6472 - accuracy: 0.7064 - 797ms/epoch - 11ms/step
# Epoch 187/500
# 72/72 - 1s - loss: 0.6349 - accuracy: 0.7082 - 793ms/epoch - 11ms/step
# Epoch 188/500
# 72/72 - 1s - loss: 0.6480 - accuracy: 0.7089 - 797ms/epoch - 11ms/step
# Epoch 189/500
# 72/72 - 1s - loss: 0.6396 - accuracy: 0.7080 - 806ms/epoch - 11ms/step
# Epoch 190/500
# 72/72 - 1s - loss: 0.6442 - accuracy: 0.7098 - 789ms/epoch - 11ms/step
# Epoch 191/500
# 72/72 - 1s - loss: 0.6563 - accuracy: 0.7053 - 798ms/epoch - 11ms/step
# Epoch 192/500
# 72/72 - 1s - loss: 0.6517 - accuracy: 0.7072 - 791ms/epoch - 11ms/step
# Epoch 193/500
# 72/72 - 1s - loss: 0.6379 - accuracy: 0.7109 - 819ms/epoch - 11ms/step
# Epoch 194/500
# 72/72 - 1s - loss: 0.6416 - accuracy: 0.7111 - 800ms/epoch - 11ms/step
# Epoch 195/500
# 72/72 - 1s - loss: 0.6591 - accuracy: 0.7043 - 799ms/epoch - 11ms/step
# Epoch 196/500
# 72/72 - 1s - loss: 0.6485 - accuracy: 0.7114 - 811ms/epoch - 11ms/step
# Epoch 197/500
# 72/72 - 1s - loss: 0.6627 - accuracy: 0.7029 - 811ms/epoch - 11ms/step
# Epoch 198/500
# 72/72 - 1s - loss: 0.6583 - accuracy: 0.7058 - 1s/epoch - 14ms/step
# Epoch 199/500
# 72/72 - 1s - loss: 0.6416 - accuracy: 0.7108 - 1s/epoch - 15ms/step
# Epoch 200/500
# 72/72 - 1s - loss: 0.6360 - accuracy: 0.7105 - 849ms/epoch - 12ms/step
# Epoch 201/500
# 72/72 - 1s - loss: 0.6285 - accuracy: 0.7153 - 803ms/epoch - 11ms/step
# Epoch 202/500
# 72/72 - 1s - loss: 0.6236 - accuracy: 0.7191 - 814ms/epoch - 11ms/step
# Epoch 203/500
# 72/72 - 1s - loss: 0.6342 - accuracy: 0.7122 - 805ms/epoch - 11ms/step
# Epoch 204/500
# 72/72 - 1s - loss: 0.6317 - accuracy: 0.7159 - 798ms/epoch - 11ms/step
# Epoch 205/500
# 72/72 - 1s - loss: 0.6339 - accuracy: 0.7147 - 812ms/epoch - 11ms/step
# Epoch 206/500
# 72/72 - 1s - loss: 0.6937 - accuracy: 0.6968 - 813ms/epoch - 11ms/step
# Epoch 207/500
# 72/72 - 1s - loss: 0.6504 - accuracy: 0.7042 - 797ms/epoch - 11ms/step
# Epoch 208/500
# 72/72 - 1s - loss: 0.6498 - accuracy: 0.7082 - 810ms/epoch - 11ms/step
# Epoch 209/500
# 72/72 - 1s - loss: 0.6357 - accuracy: 0.7127 - 808ms/epoch - 11ms/step
# Epoch 210/500
# 72/72 - 1s - loss: 0.6321 - accuracy: 0.7175 - 810ms/epoch - 11ms/step
# Epoch 211/500
# 72/72 - 1s - loss: 0.6322 - accuracy: 0.7178 - 816ms/epoch - 11ms/step
# Epoch 212/500
# 72/72 - 1s - loss: 0.6303 - accuracy: 0.7180 - 990ms/epoch - 14ms/step
# Epoch 213/500
# 72/72 - 1s - loss: 0.6457 - accuracy: 0.7150 - 1s/epoch - 14ms/step
# Epoch 214/500
# 72/72 - 1s - loss: 0.6269 - accuracy: 0.7226 - 934ms/epoch - 13ms/step
# Epoch 215/500
# 72/72 - 1s - loss: 0.6220 - accuracy: 0.7202 - 813ms/epoch - 11ms/step
# Epoch 216/500
# 72/72 - 1s - loss: 0.6258 - accuracy: 0.7170 - 808ms/epoch - 11ms/step
# Epoch 217/500
# 72/72 - 1s - loss: 0.6205 - accuracy: 0.7184 - 813ms/epoch - 11ms/step
# Epoch 218/500
# 72/72 - 1s - loss: 0.6459 - accuracy: 0.7121 - 813ms/epoch - 11ms/step
# Epoch 219/500
# 72/72 - 1s - loss: 0.6890 - accuracy: 0.6959 - 812ms/epoch - 11ms/step
# Epoch 220/500
# 72/72 - 1s - loss: 0.6604 - accuracy: 0.7079 - 815ms/epoch - 11ms/step
# Epoch 221/500
# 72/72 - 1s - loss: 0.6618 - accuracy: 0.7032 - 811ms/epoch - 11ms/step
# Epoch 222/500
# 72/72 - 1s - loss: 0.6447 - accuracy: 0.7120 - 798ms/epoch - 11ms/step
# Epoch 223/500
# 72/72 - 1s - loss: 0.6329 - accuracy: 0.7123 - 809ms/epoch - 11ms/step
# Epoch 224/500
# 72/72 - 1s - loss: 0.6320 - accuracy: 0.7139 - 810ms/epoch - 11ms/step
# Epoch 225/500
# 72/72 - 1s - loss: 0.6288 - accuracy: 0.7149 - 804ms/epoch - 11ms/step
# Epoch 226/500
# 72/72 - 1s - loss: 0.6317 - accuracy: 0.7141 - 897ms/epoch - 12ms/step
# Epoch 227/500
# 72/72 - 1s - loss: 0.6463 - accuracy: 0.7137 - 1s/epoch - 15ms/step
# Epoch 228/500
# 72/72 - 1s - loss: 0.6386 - accuracy: 0.7100 - 990ms/epoch - 14ms/step
# Epoch 229/500
# 72/72 - 1s - loss: 0.6309 - accuracy: 0.7183 - 797ms/epoch - 11ms/step
# Epoch 230/500
# 72/72 - 1s - loss: 0.6229 - accuracy: 0.7221 - 800ms/epoch - 11ms/step
# Epoch 231/500
# 72/72 - 1s - loss: 0.6159 - accuracy: 0.7228 - 792ms/epoch - 11ms/step
# Epoch 232/500
# 72/72 - 1s - loss: 0.6190 - accuracy: 0.7223 - 806ms/epoch - 11ms/step
# Epoch 233/500
# 72/72 - 1s - loss: 0.6036 - accuracy: 0.7282 - 797ms/epoch - 11ms/step
# Epoch 234/500
# 72/72 - 1s - loss: 0.6093 - accuracy: 0.7233 - 787ms/epoch - 11ms/step
# Epoch 235/500
# 72/72 - 1s - loss: 0.6145 - accuracy: 0.7246 - 821ms/epoch - 11ms/step
# Epoch 236/500
# 72/72 - 1s - loss: 0.6119 - accuracy: 0.7262 - 833ms/epoch - 12ms/step
# Epoch 237/500
# 72/72 - 1s - loss: 0.6081 - accuracy: 0.7263 - 799ms/epoch - 11ms/step
# Epoch 238/500
# 72/72 - 1s - loss: 0.6055 - accuracy: 0.7275 - 804ms/epoch - 11ms/step
# Epoch 239/500
# 72/72 - 1s - loss: 0.6229 - accuracy: 0.7193 - 794ms/epoch - 11ms/step
# Epoch 240/500
# 72/72 - 1s - loss: 0.6068 - accuracy: 0.7282 - 808ms/epoch - 11ms/step
# Epoch 241/500
# 72/72 - 1s - loss: 0.6043 - accuracy: 0.7251 - 1s/epoch - 14ms/step
# Epoch 242/500
# 72/72 - 1s - loss: 0.5977 - accuracy: 0.7278 - 1s/epoch - 15ms/step
# Epoch 243/500
# 72/72 - 1s - loss: 0.6102 - accuracy: 0.7270 - 855ms/epoch - 12ms/step
# Epoch 244/500
# 72/72 - 1s - loss: 0.6100 - accuracy: 0.7245 - 802ms/epoch - 11ms/step
# Epoch 245/500
# 72/72 - 1s - loss: 0.5987 - accuracy: 0.7340 - 804ms/epoch - 11ms/step
# Epoch 246/500
# 72/72 - 1s - loss: 0.5962 - accuracy: 0.7318 - 799ms/epoch - 11ms/step
# Epoch 247/500
# 72/72 - 1s - loss: 0.6048 - accuracy: 0.7282 - 801ms/epoch - 11ms/step
# Epoch 248/500
# 72/72 - 1s - loss: 0.6002 - accuracy: 0.7285 - 806ms/epoch - 11ms/step
# Epoch 249/500
# 72/72 - 1s - loss: 0.6100 - accuracy: 0.7318 - 793ms/epoch - 11ms/step
# Epoch 250/500
# 72/72 - 1s - loss: 0.6060 - accuracy: 0.7282 - 801ms/epoch - 11ms/step
# Epoch 251/500
# 72/72 - 1s - loss: 0.5929 - accuracy: 0.7349 - 809ms/epoch - 11ms/step
# Epoch 252/500
# 72/72 - 1s - loss: 0.5968 - accuracy: 0.7358 - 798ms/epoch - 11ms/step
# Epoch 253/500
# 72/72 - 1s - loss: 0.6002 - accuracy: 0.7301 - 808ms/epoch - 11ms/step
# Epoch 254/500
# 72/72 - 1s - loss: 0.6040 - accuracy: 0.7265 - 814ms/epoch - 11ms/step
# Epoch 255/500
# 72/72 - 1s - loss: 0.6194 - accuracy: 0.7222 - 955ms/epoch - 13ms/step
# Epoch 256/500
# 72/72 - 1s - loss: 0.6299 - accuracy: 0.7187 - 1s/epoch - 15ms/step
# Epoch 257/500
# 72/72 - 1s - loss: 0.6132 - accuracy: 0.7287 - 969ms/epoch - 13ms/step
# Epoch 258/500
# 72/72 - 1s - loss: 0.5966 - accuracy: 0.7330 - 792ms/epoch - 11ms/step
# Epoch 259/500
# 72/72 - 1s - loss: 0.5894 - accuracy: 0.7332 - 803ms/epoch - 11ms/step
# Epoch 260/500
# 72/72 - 1s - loss: 0.5888 - accuracy: 0.7376 - 803ms/epoch - 11ms/step
# Epoch 261/500
# 72/72 - 1s - loss: 0.5926 - accuracy: 0.7295 - 805ms/epoch - 11ms/step
# Epoch 262/500
# 72/72 - 1s - loss: 0.5887 - accuracy: 0.7357 - 812ms/epoch - 11ms/step
# Epoch 263/500
# 72/72 - 1s - loss: 0.5898 - accuracy: 0.7327 - 806ms/epoch - 11ms/step
# Epoch 264/500
# 72/72 - 1s - loss: 0.5903 - accuracy: 0.7343 - 811ms/epoch - 11ms/step
# Epoch 265/500
# 72/72 - 1s - loss: 0.5931 - accuracy: 0.7335 - 812ms/epoch - 11ms/step
# Epoch 266/500
# 72/72 - 1s - loss: 0.5894 - accuracy: 0.7341 - 806ms/epoch - 11ms/step
# Epoch 267/500
# 72/72 - 1s - loss: 0.5926 - accuracy: 0.7307 - 806ms/epoch - 11ms/step
# Epoch 268/500
# 72/72 - 1s - loss: 0.5949 - accuracy: 0.7360 - 802ms/epoch - 11ms/step
# Epoch 269/500
# 72/72 - 1s - loss: 0.5924 - accuracy: 0.7340 - 847ms/epoch - 12ms/step
# Epoch 270/500
# 72/72 - 1s - loss: 0.5872 - accuracy: 0.7375 - 1s/epoch - 14ms/step
# Epoch 271/500
# 72/72 - 1s - loss: 0.5776 - accuracy: 0.7461 - 1s/epoch - 15ms/step
# Epoch 272/500
# 72/72 - 1s - loss: 0.5843 - accuracy: 0.7358 - 822ms/epoch - 11ms/step
# Epoch 273/500
# 72/72 - 1s - loss: 0.5838 - accuracy: 0.7403 - 803ms/epoch - 11ms/step
# Epoch 274/500
# 72/72 - 1s - loss: 0.5788 - accuracy: 0.7400 - 798ms/epoch - 11ms/step
# Epoch 275/500
# 72/72 - 1s - loss: 0.5801 - accuracy: 0.7382 - 792ms/epoch - 11ms/step
# Epoch 276/500
# 72/72 - 1s - loss: 0.5980 - accuracy: 0.7292 - 809ms/epoch - 11ms/step
# Epoch 277/500
# 72/72 - 1s - loss: 0.6013 - accuracy: 0.7238 - 810ms/epoch - 11ms/step
# Epoch 278/500
# 72/72 - 1s - loss: 0.5921 - accuracy: 0.7313 - 801ms/epoch - 11ms/step
# Epoch 279/500
# 72/72 - 1s - loss: 0.5873 - accuracy: 0.7380 - 808ms/epoch - 11ms/step
# Epoch 280/500
# 72/72 - 1s - loss: 0.5859 - accuracy: 0.7385 - 807ms/epoch - 11ms/step
# Epoch 281/500
# 72/72 - 1s - loss: 0.5711 - accuracy: 0.7415 - 794ms/epoch - 11ms/step
# Epoch 282/500
# 72/72 - 1s - loss: 0.5866 - accuracy: 0.7364 - 799ms/epoch - 11ms/step
# Epoch 283/500
# 72/72 - 1s - loss: 0.5767 - accuracy: 0.7418 - 797ms/epoch - 11ms/step
# Epoch 284/500
# 72/72 - 1s - loss: 0.5672 - accuracy: 0.7501 - 1s/epoch - 14ms/step
# Epoch 285/500
# 72/72 - 1s - loss: 0.5702 - accuracy: 0.7433 - 1s/epoch - 15ms/step
# Epoch 286/500
# 72/72 - 1s - loss: 0.5702 - accuracy: 0.7477 - 896ms/epoch - 12ms/step
# Epoch 287/500
# 72/72 - 1s - loss: 0.5742 - accuracy: 0.7397 - 804ms/epoch - 11ms/step
# Epoch 288/500
# 72/72 - 1s - loss: 0.5711 - accuracy: 0.7432 - 804ms/epoch - 11ms/step
# Epoch 289/500
# 72/72 - 1s - loss: 0.5720 - accuracy: 0.7474 - 809ms/epoch - 11ms/step
# Epoch 290/500
# 72/72 - 1s - loss: 0.5778 - accuracy: 0.7423 - 799ms/epoch - 11ms/step
# Epoch 291/500
# 72/72 - 1s - loss: 0.5657 - accuracy: 0.7448 - 799ms/epoch - 11ms/step
# Epoch 292/500
# 72/72 - 1s - loss: 0.5643 - accuracy: 0.7446 - 796ms/epoch - 11ms/step
# Epoch 293/500
# 72/72 - 1s - loss: 0.5640 - accuracy: 0.7464 - 800ms/epoch - 11ms/step
# Epoch 294/500
# 72/72 - 1s - loss: 0.5662 - accuracy: 0.7435 - 801ms/epoch - 11ms/step
# Epoch 295/500
# 72/72 - 1s - loss: 0.5705 - accuracy: 0.7428 - 793ms/epoch - 11ms/step
# Epoch 296/500
# 72/72 - 1s - loss: 0.5520 - accuracy: 0.7537 - 804ms/epoch - 11ms/step
# Epoch 297/500
# 72/72 - 1s - loss: 0.5684 - accuracy: 0.7447 - 801ms/epoch - 11ms/step
# Epoch 298/500
# 72/72 - 1s - loss: 0.5680 - accuracy: 0.7426 - 882ms/epoch - 12ms/step
# Epoch 299/500
# 72/72 - 1s - loss: 0.5698 - accuracy: 0.7462 - 1s/epoch - 14ms/step
# Epoch 300/500
# 72/72 - 1s - loss: 0.5545 - accuracy: 0.7503 - 1s/epoch - 14ms/step
# Epoch 301/500
# 72/72 - 1s - loss: 0.5565 - accuracy: 0.7543 - 802ms/epoch - 11ms/step
# Epoch 302/500
# 72/72 - 1s - loss: 0.5583 - accuracy: 0.7535 - 794ms/epoch - 11ms/step
# Epoch 303/500
# 72/72 - 1s - loss: 0.5446 - accuracy: 0.7582 - 801ms/epoch - 11ms/step
# Epoch 304/500
# 72/72 - 1s - loss: 0.5595 - accuracy: 0.7498 - 791ms/epoch - 11ms/step
# Epoch 305/500
# 72/72 - 1s - loss: 0.5554 - accuracy: 0.7512 - 794ms/epoch - 11ms/step
# Epoch 306/500
# 72/72 - 1s - loss: 0.5518 - accuracy: 0.7522 - 809ms/epoch - 11ms/step
# Epoch 307/500
# 72/72 - 1s - loss: 0.5504 - accuracy: 0.7522 - 802ms/epoch - 11ms/step
# Epoch 308/500
# 72/72 - 1s - loss: 0.5446 - accuracy: 0.7596 - 821ms/epoch - 11ms/step
# Epoch 309/500
# 72/72 - 1s - loss: 0.5507 - accuracy: 0.7516 - 795ms/epoch - 11ms/step
# Epoch 310/500
# 72/72 - 1s - loss: 0.5479 - accuracy: 0.7547 - 797ms/epoch - 11ms/step
# Epoch 311/500
# 72/72 - 1s - loss: 0.5606 - accuracy: 0.7526 - 800ms/epoch - 11ms/step
# Epoch 312/500
# 72/72 - 1s - loss: 0.5506 - accuracy: 0.7522 - 804ms/epoch - 11ms/step
# Epoch 313/500
# 72/72 - 1s - loss: 0.5546 - accuracy: 0.7502 - 1s/epoch - 14ms/step
# Epoch 314/500
# 72/72 - 1s - loss: 0.5489 - accuracy: 0.7577 - 1s/epoch - 14ms/step
# Epoch 315/500
# 72/72 - 1s - loss: 0.5504 - accuracy: 0.7547 - 850ms/epoch - 12ms/step
# Epoch 316/500
# 72/72 - 1s - loss: 0.5499 - accuracy: 0.7561 - 813ms/epoch - 11ms/step
# Epoch 317/500
# 72/72 - 1s - loss: 0.5476 - accuracy: 0.7589 - 810ms/epoch - 11ms/step
# Epoch 318/500
# 72/72 - 1s - loss: 0.5555 - accuracy: 0.7522 - 799ms/epoch - 11ms/step
# Epoch 319/500
# 72/72 - 1s - loss: 0.5437 - accuracy: 0.7604 - 797ms/epoch - 11ms/step
# Epoch 320/500
# 72/72 - 1s - loss: 0.5414 - accuracy: 0.7614 - 798ms/epoch - 11ms/step
# Epoch 321/500
# 72/72 - 1s - loss: 0.5478 - accuracy: 0.7575 - 794ms/epoch - 11ms/step
# Epoch 322/500
# 72/72 - 1s - loss: 0.5655 - accuracy: 0.7518 - 801ms/epoch - 11ms/step
# Epoch 323/500
# 72/72 - 1s - loss: 0.5500 - accuracy: 0.7549 - 798ms/epoch - 11ms/step
# Epoch 324/500
# 72/72 - 1s - loss: 0.5567 - accuracy: 0.7539 - 803ms/epoch - 11ms/step
# Epoch 325/500
# 72/72 - 1s - loss: 0.5502 - accuracy: 0.7549 - 789ms/epoch - 11ms/step
# Epoch 326/500
# 72/72 - 1s - loss: 0.5361 - accuracy: 0.7629 - 792ms/epoch - 11ms/step
# Epoch 327/500
# 72/72 - 1s - loss: 0.5383 - accuracy: 0.7630 - 925ms/epoch - 13ms/step
# Epoch 328/500
# 72/72 - 1s - loss: 0.5362 - accuracy: 0.7645 - 1s/epoch - 14ms/step
# Epoch 329/500
# 72/72 - 1s - loss: 0.5462 - accuracy: 0.7595 - 966ms/epoch - 13ms/step
# Epoch 330/500
# 72/72 - 1s - loss: 0.5572 - accuracy: 0.7552 - 789ms/epoch - 11ms/step
# Epoch 331/500
# 72/72 - 1s - loss: 0.5369 - accuracy: 0.7634 - 794ms/epoch - 11ms/step
# Epoch 332/500
# 72/72 - 1s - loss: 0.5441 - accuracy: 0.7589 - 792ms/epoch - 11ms/step
# Epoch 333/500
# 72/72 - 1s - loss: 0.5462 - accuracy: 0.7577 - 801ms/epoch - 11ms/step
# Epoch 334/500
# 72/72 - 1s - loss: 0.5334 - accuracy: 0.7655 - 804ms/epoch - 11ms/step
# Epoch 335/500
# 72/72 - 1s - loss: 0.5374 - accuracy: 0.7688 - 799ms/epoch - 11ms/step
# Epoch 336/500
# 72/72 - 1s - loss: 0.5357 - accuracy: 0.7660 - 797ms/epoch - 11ms/step
# Epoch 337/500
# 72/72 - 1s - loss: 0.5364 - accuracy: 0.7574 - 794ms/epoch - 11ms/step
# Epoch 338/500
# 72/72 - 1s - loss: 0.5343 - accuracy: 0.7588 - 805ms/epoch - 11ms/step
# Epoch 339/500
# 72/72 - 1s - loss: 0.5308 - accuracy: 0.7649 - 807ms/epoch - 11ms/step
# Epoch 340/500
# 72/72 - 1s - loss: 0.5277 - accuracy: 0.7654 - 806ms/epoch - 11ms/step
# Epoch 341/500
# 72/72 - 1s - loss: 0.5309 - accuracy: 0.7685 - 800ms/epoch - 11ms/step
# Epoch 342/500
# 72/72 - 1s - loss: 0.5210 - accuracy: 0.7736 - 972ms/epoch - 13ms/step
# Epoch 343/500
# 72/72 - 1s - loss: 0.5173 - accuracy: 0.7699 - 1s/epoch - 14ms/step
# Epoch 344/500
# 72/72 - 1s - loss: 0.5195 - accuracy: 0.7737 - 908ms/epoch - 13ms/step
# Epoch 345/500
# 72/72 - 1s - loss: 0.5235 - accuracy: 0.7717 - 805ms/epoch - 11ms/step
# Epoch 346/500
# 72/72 - 1s - loss: 0.5351 - accuracy: 0.7662 - 805ms/epoch - 11ms/step
# Epoch 347/500
# 72/72 - 1s - loss: 0.5283 - accuracy: 0.7647 - 804ms/epoch - 11ms/step
# Epoch 348/500
# 72/72 - 1s - loss: 0.5225 - accuracy: 0.7738 - 804ms/epoch - 11ms/step
# Epoch 349/500
# 72/72 - 1s - loss: 0.5253 - accuracy: 0.7664 - 793ms/epoch - 11ms/step
# Epoch 350/500
# 72/72 - 1s - loss: 0.5229 - accuracy: 0.7738 - 794ms/epoch - 11ms/step
# Epoch 351/500
# 72/72 - 1s - loss: 0.5266 - accuracy: 0.7713 - 798ms/epoch - 11ms/step
# Epoch 352/500
# 72/72 - 1s - loss: 0.5176 - accuracy: 0.7723 - 794ms/epoch - 11ms/step
# Epoch 353/500
# 72/72 - 1s - loss: 0.5197 - accuracy: 0.7683 - 794ms/epoch - 11ms/step
# Epoch 354/500
# 72/72 - 1s - loss: 0.5259 - accuracy: 0.7690 - 799ms/epoch - 11ms/step
# Epoch 355/500
# 72/72 - 1s - loss: 0.5263 - accuracy: 0.7682 - 803ms/epoch - 11ms/step
# Epoch 356/500
# 72/72 - 1s - loss: 0.5123 - accuracy: 0.7733 - 880ms/epoch - 12ms/step
# Epoch 357/500
# 72/72 - 1s - loss: 0.5195 - accuracy: 0.7704 - 987ms/epoch - 14ms/step
# Epoch 358/500
# 72/72 - 1s - loss: 0.5159 - accuracy: 0.7713 - 984ms/epoch - 14ms/step
# Epoch 359/500
# 72/72 - 1s - loss: 0.5224 - accuracy: 0.7695 - 799ms/epoch - 11ms/step
# Epoch 360/500
# 72/72 - 1s - loss: 0.5098 - accuracy: 0.7733 - 789ms/epoch - 11ms/step
# Epoch 361/500
# 72/72 - 1s - loss: 0.5249 - accuracy: 0.7663 - 796ms/epoch - 11ms/step
# Epoch 362/500
# 72/72 - 1s - loss: 0.5285 - accuracy: 0.7672 - 797ms/epoch - 11ms/step
# Epoch 363/500
# 72/72 - 1s - loss: 0.5147 - accuracy: 0.7745 - 811ms/epoch - 11ms/step
# Epoch 364/500
# 72/72 - 1s - loss: 0.5088 - accuracy: 0.7818 - 797ms/epoch - 11ms/step
# Epoch 365/500
# 72/72 - 1s - loss: 0.5139 - accuracy: 0.7760 - 791ms/epoch - 11ms/step
# Epoch 366/500
# 72/72 - 1s - loss: 0.5059 - accuracy: 0.7784 - 801ms/epoch - 11ms/step
# Epoch 367/500
# 72/72 - 1s - loss: 0.5082 - accuracy: 0.7776 - 796ms/epoch - 11ms/step
# Epoch 368/500
# 72/72 - 1s - loss: 0.5118 - accuracy: 0.7738 - 794ms/epoch - 11ms/step
# Epoch 369/500
# 72/72 - 1s - loss: 0.5162 - accuracy: 0.7738 - 799ms/epoch - 11ms/step
# Epoch 370/500
# 72/72 - 1s - loss: 0.5122 - accuracy: 0.7768 - 799ms/epoch - 11ms/step
# Epoch 371/500
# 72/72 - 1s - loss: 0.5090 - accuracy: 0.7754 - 965ms/epoch - 13ms/step
# Epoch 372/500
# 72/72 - 1s - loss: 0.4979 - accuracy: 0.7798 - 1s/epoch - 14ms/step
# Epoch 373/500
# 72/72 - 1s - loss: 0.5037 - accuracy: 0.7824 - 918ms/epoch - 13ms/step
# Epoch 374/500
# 72/72 - 1s - loss: 0.5125 - accuracy: 0.7790 - 799ms/epoch - 11ms/step
# Epoch 375/500
# 72/72 - 1s - loss: 0.5056 - accuracy: 0.7775 - 811ms/epoch - 11ms/step
# Epoch 376/500
# 72/72 - 1s - loss: 0.5112 - accuracy: 0.7772 - 790ms/epoch - 11ms/step
# Epoch 377/500
# 72/72 - 1s - loss: 0.4966 - accuracy: 0.7840 - 1s/epoch - 15ms/step
# Epoch 378/500
# 72/72 - 1s - loss: 0.4995 - accuracy: 0.7820 - 1s/epoch - 17ms/step
# Epoch 379/500
# 72/72 - 1s - loss: 0.5001 - accuracy: 0.7787 - 1s/epoch - 17ms/step
# Epoch 380/500
# 72/72 - 1s - loss: 0.4961 - accuracy: 0.7816 - 1s/epoch - 18ms/step
# Epoch 381/500
# 72/72 - 1s - loss: 0.4945 - accuracy: 0.7811 - 1s/epoch - 20ms/step
# Epoch 382/500
# 72/72 - 1s - loss: 0.4996 - accuracy: 0.7799 - 1s/epoch - 19ms/step
# Epoch 383/500
# 72/72 - 2s - loss: 0.4816 - accuracy: 0.7842 - 2s/epoch - 28ms/step
# Epoch 384/500
# 72/72 - 1s - loss: 0.5093 - accuracy: 0.7771 - 1s/epoch - 15ms/step
# Epoch 385/500
# 72/72 - 1s - loss: 0.5080 - accuracy: 0.7786 - 793ms/epoch - 11ms/step
# Epoch 386/500
# 72/72 - 1s - loss: 0.4913 - accuracy: 0.7857 - 790ms/epoch - 11ms/step
# Epoch 387/500
# 72/72 - 1s - loss: 0.4877 - accuracy: 0.7872 - 791ms/epoch - 11ms/step
# Epoch 388/500
# 72/72 - 1s - loss: 0.4961 - accuracy: 0.7864 - 788ms/epoch - 11ms/step
# Epoch 389/500
# 72/72 - 1s - loss: 0.4920 - accuracy: 0.7884 - 793ms/epoch - 11ms/step
# Epoch 390/500
# 72/72 - 1s - loss: 0.5091 - accuracy: 0.7767 - 960ms/epoch - 13ms/step
# Epoch 391/500
# 72/72 - 1s - loss: 0.5224 - accuracy: 0.7713 - 1s/epoch - 16ms/step
# Epoch 392/500
# 72/72 - 1s - loss: 0.5048 - accuracy: 0.7792 - 989ms/epoch - 14ms/step
# Epoch 393/500
# 72/72 - 1s - loss: 0.4889 - accuracy: 0.7867 - 798ms/epoch - 11ms/step
# Epoch 394/500
# 72/72 - 1s - loss: 0.4926 - accuracy: 0.7877 - 799ms/epoch - 11ms/step
# Epoch 395/500
# 72/72 - 1s - loss: 0.4919 - accuracy: 0.7829 - 974ms/epoch - 14ms/step
# Epoch 396/500
# 72/72 - 1s - loss: 0.4819 - accuracy: 0.7929 - 1s/epoch - 14ms/step
# Epoch 397/500
# 72/72 - 1s - loss: 0.4827 - accuracy: 0.7882 - 884ms/epoch - 12ms/step
# Epoch 398/500
# 72/72 - 1s - loss: 0.4901 - accuracy: 0.7835 - 818ms/epoch - 11ms/step
# Epoch 399/500
# 72/72 - 1s - loss: 0.4827 - accuracy: 0.7886 - 808ms/epoch - 11ms/step
# Epoch 400/500
# 72/72 - 1s - loss: 0.4890 - accuracy: 0.7901 - 799ms/epoch - 11ms/step
# Epoch 401/500
# 72/72 - 1s - loss: 0.4896 - accuracy: 0.7817 - 809ms/epoch - 11ms/step
# Epoch 402/500
# 72/72 - 1s - loss: 0.4840 - accuracy: 0.7872 - 790ms/epoch - 11ms/step
# Epoch 403/500
# 72/72 - 1s - loss: 0.4801 - accuracy: 0.7937 - 795ms/epoch - 11ms/step
# Epoch 404/500
# 72/72 - 1s - loss: 0.4775 - accuracy: 0.7983 - 808ms/epoch - 11ms/step
# Epoch 405/500
# 72/72 - 1s - loss: 0.4760 - accuracy: 0.7921 - 802ms/epoch - 11ms/step
# Epoch 406/500
# 72/72 - 1s - loss: 0.4705 - accuracy: 0.7932 - 794ms/epoch - 11ms/step
# Epoch 407/500
# 72/72 - 1s - loss: 0.4786 - accuracy: 0.7954 - 793ms/epoch - 11ms/step
# Epoch 408/500
# 72/72 - 1s - loss: 0.4826 - accuracy: 0.7905 - 805ms/epoch - 11ms/step
# Epoch 409/500
# 72/72 - 1s - loss: 0.4718 - accuracy: 0.7924 - 861ms/epoch - 12ms/step
# Epoch 410/500
# 72/72 - 1s - loss: 0.4747 - accuracy: 0.7926 - 1s/epoch - 15ms/step
# Epoch 411/500
# 72/72 - 1s - loss: 0.4787 - accuracy: 0.7916 - 1s/epoch - 15ms/step
# Epoch 412/500
# 72/72 - 1s - loss: 0.4738 - accuracy: 0.7932 - 793ms/epoch - 11ms/step
# Epoch 413/500
# 72/72 - 1s - loss: 0.4691 - accuracy: 0.7993 - 801ms/epoch - 11ms/step
# Epoch 414/500
# 72/72 - 1s - loss: 0.4709 - accuracy: 0.7968 - 795ms/epoch - 11ms/step
# Epoch 415/500
# 72/72 - 1s - loss: 0.4688 - accuracy: 0.7979 - 799ms/epoch - 11ms/step
# Epoch 416/500
# 72/72 - 1s - loss: 0.4572 - accuracy: 0.7972 - 801ms/epoch - 11ms/step
# Epoch 417/500
# 72/72 - 1s - loss: 0.4639 - accuracy: 0.8013 - 800ms/epoch - 11ms/step
# Epoch 418/500
# 72/72 - 1s - loss: 0.4684 - accuracy: 0.7993 - 792ms/epoch - 11ms/step
# Epoch 419/500
# 72/72 - 1s - loss: 0.4736 - accuracy: 0.7916 - 802ms/epoch - 11ms/step
# Epoch 420/500
# 72/72 - 1s - loss: 0.4763 - accuracy: 0.7971 - 791ms/epoch - 11ms/step
# Epoch 421/500
# 72/72 - 1s - loss: 0.4745 - accuracy: 0.7960 - 797ms/epoch - 11ms/step
# Epoch 422/500
# 72/72 - 1s - loss: 0.4679 - accuracy: 0.7974 - 786ms/epoch - 11ms/step
# Epoch 423/500
# 72/72 - 1s - loss: 0.4646 - accuracy: 0.7972 - 784ms/epoch - 11ms/step
# Epoch 424/500
# 72/72 - 1s - loss: 0.4667 - accuracy: 0.7984 - 970ms/epoch - 13ms/step
# Epoch 425/500
# 72/72 - 1s - loss: 0.4564 - accuracy: 0.8050 - 998ms/epoch - 14ms/step
# Epoch 426/500
# 72/72 - 1s - loss: 0.4746 - accuracy: 0.7955 - 909ms/epoch - 13ms/step
# Epoch 427/500
# 72/72 - 1s - loss: 0.4684 - accuracy: 0.7942 - 786ms/epoch - 11ms/step
# Epoch 428/500
# 72/72 - 1s - loss: 0.4653 - accuracy: 0.8023 - 799ms/epoch - 11ms/step
# Epoch 429/500
# 72/72 - 1s - loss: 0.4665 - accuracy: 0.8003 - 795ms/epoch - 11ms/step
# Epoch 430/500
# 72/72 - 1s - loss: 0.4610 - accuracy: 0.8043 - 787ms/epoch - 11ms/step
# Epoch 431/500
# 72/72 - 1s - loss: 0.4613 - accuracy: 0.7985 - 796ms/epoch - 11ms/step
# Epoch 432/500
# 72/72 - 1s - loss: 0.4630 - accuracy: 0.7943 - 804ms/epoch - 11ms/step
# Epoch 433/500
# 72/72 - 1s - loss: 0.4629 - accuracy: 0.8022 - 796ms/epoch - 11ms/step
# Epoch 434/500
# 72/72 - 1s - loss: 0.4682 - accuracy: 0.8024 - 808ms/epoch - 11ms/step
# Epoch 435/500
# 72/72 - 1s - loss: 0.4461 - accuracy: 0.8128 - 805ms/epoch - 11ms/step
# Epoch 436/500
# 72/72 - 1s - loss: 0.4573 - accuracy: 0.8039 - 801ms/epoch - 11ms/step
# Epoch 437/500
# 72/72 - 1s - loss: 0.4443 - accuracy: 0.8075 - 802ms/epoch - 11ms/step
# Epoch 438/500
# 72/72 - 1s - loss: 0.4488 - accuracy: 0.8070 - 842ms/epoch - 12ms/step
# Epoch 439/500
# 72/72 - 1s - loss: 0.4403 - accuracy: 0.8104 - 1s/epoch - 14ms/step
# Epoch 440/500
# 72/72 - 1s - loss: 0.4649 - accuracy: 0.8036 - 1s/epoch - 14ms/step
# Epoch 441/500
# 72/72 - 1s - loss: 0.4514 - accuracy: 0.8070 - 796ms/epoch - 11ms/step
# Epoch 442/500
# 72/72 - 1s - loss: 0.4447 - accuracy: 0.8070 - 794ms/epoch - 11ms/step
# Epoch 443/500
# 72/72 - 1s - loss: 0.4381 - accuracy: 0.8113 - 792ms/epoch - 11ms/step
# Epoch 444/500
# 72/72 - 1s - loss: 0.4368 - accuracy: 0.8125 - 794ms/epoch - 11ms/step
# Epoch 445/500
# 72/72 - 1s - loss: 0.4379 - accuracy: 0.8142 - 804ms/epoch - 11ms/step
# Epoch 446/500
# 72/72 - 1s - loss: 0.4448 - accuracy: 0.8099 - 799ms/epoch - 11ms/step
# Epoch 447/500
# 72/72 - 1s - loss: 0.4510 - accuracy: 0.8041 - 811ms/epoch - 11ms/step
# Epoch 448/500
# 72/72 - 1s - loss: 0.4447 - accuracy: 0.8145 - 788ms/epoch - 11ms/step
# Epoch 449/500
# 72/72 - 1s - loss: 0.4434 - accuracy: 0.8145 - 802ms/epoch - 11ms/step
# Epoch 450/500
# 72/72 - 1s - loss: 0.4492 - accuracy: 0.8103 - 802ms/epoch - 11ms/step
# Epoch 451/500
# 72/72 - 1s - loss: 0.4355 - accuracy: 0.8109 - 1s/epoch - 14ms/step
# Epoch 452/500
# 72/72 - 1s - loss: 0.4334 - accuracy: 0.8123 - 1s/epoch - 14ms/step
# Epoch 453/500
# 72/72 - 1s - loss: 0.4461 - accuracy: 0.8074 - 1s/epoch - 20ms/step
# Epoch 454/500
# 72/72 - 1s - loss: 0.4388 - accuracy: 0.8091 - 956ms/epoch - 13ms/step
# Epoch 455/500
# 72/72 - 1s - loss: 0.4379 - accuracy: 0.8120 - 799ms/epoch - 11ms/step
# Epoch 456/500
# 72/72 - 1s - loss: 0.4331 - accuracy: 0.8193 - 798ms/epoch - 11ms/step
# Epoch 457/500
# 72/72 - 1s - loss: 0.4442 - accuracy: 0.8112 - 794ms/epoch - 11ms/step
# Epoch 458/500
# 72/72 - 1s - loss: 0.4777 - accuracy: 0.7952 - 790ms/epoch - 11ms/step
# Epoch 459/500
# 72/72 - 1s - loss: 0.4415 - accuracy: 0.8137 - 802ms/epoch - 11ms/step
# Epoch 460/500
# 72/72 - 1s - loss: 0.4405 - accuracy: 0.8136 - 793ms/epoch - 11ms/step
# Epoch 461/500
# 72/72 - 1s - loss: 0.4327 - accuracy: 0.8133 - 791ms/epoch - 11ms/step
# Epoch 462/500
# 72/72 - 1s - loss: 0.4310 - accuracy: 0.8130 - 794ms/epoch - 11ms/step
# Epoch 463/500
# 72/72 - 1s - loss: 0.4330 - accuracy: 0.8130 - 798ms/epoch - 11ms/step
# Epoch 464/500
# 72/72 - 1s - loss: 0.4380 - accuracy: 0.8168 - 794ms/epoch - 11ms/step
# Epoch 465/500
# 72/72 - 1s - loss: 0.4407 - accuracy: 0.8111 - 792ms/epoch - 11ms/step
# Epoch 466/500
# 72/72 - 1s - loss: 0.4312 - accuracy: 0.8175 - 800ms/epoch - 11ms/step
# Epoch 467/500
# 72/72 - 1s - loss: 0.4209 - accuracy: 0.8223 - 966ms/epoch - 13ms/step
# Epoch 468/500
# 72/72 - 1s - loss: 0.4239 - accuracy: 0.8212 - 1s/epoch - 14ms/step
# Epoch 469/500
# 72/72 - 1s - loss: 0.4248 - accuracy: 0.8201 - 885ms/epoch - 12ms/step
# Epoch 470/500
# 72/72 - 1s - loss: 0.4192 - accuracy: 0.8220 - 798ms/epoch - 11ms/step
# Epoch 471/500
# 72/72 - 1s - loss: 0.4251 - accuracy: 0.8218 - 795ms/epoch - 11ms/step
# Epoch 472/500
# 72/72 - 1s - loss: 0.4271 - accuracy: 0.8148 - 782ms/epoch - 11ms/step
# Epoch 473/500
# 72/72 - 1s - loss: 0.4241 - accuracy: 0.8225 - 786ms/epoch - 11ms/step
# Epoch 474/500
# 72/72 - 1s - loss: 0.4232 - accuracy: 0.8208 - 797ms/epoch - 11ms/step
# Epoch 475/500
# 72/72 - 1s - loss: 0.4311 - accuracy: 0.8196 - 800ms/epoch - 11ms/step
# Epoch 476/500
# 72/72 - 1s - loss: 0.4210 - accuracy: 0.8213 - 792ms/epoch - 11ms/step
# Epoch 477/500
# 72/72 - 1s - loss: 0.4264 - accuracy: 0.8218 - 794ms/epoch - 11ms/step
# Epoch 478/500
# 72/72 - 1s - loss: 0.4108 - accuracy: 0.8247 - 791ms/epoch - 11ms/step
# Epoch 479/500
# 72/72 - 1s - loss: 0.4259 - accuracy: 0.8195 - 796ms/epoch - 11ms/step
# Epoch 480/500
# 72/72 - 1s - loss: 0.4189 - accuracy: 0.8228 - 795ms/epoch - 11ms/step
# Epoch 481/500
# 72/72 - 1s - loss: 0.4305 - accuracy: 0.8183 - 852ms/epoch - 12ms/step
# Epoch 482/500
# 72/72 - 1s - loss: 0.4214 - accuracy: 0.8297 - 1s/epoch - 15ms/step
# Epoch 483/500
# 72/72 - 1s - loss: 0.4091 - accuracy: 0.8298 - 1s/epoch - 15ms/step
# Epoch 484/500
# 72/72 - 1s - loss: 0.4116 - accuracy: 0.8266 - 789ms/epoch - 11ms/step
# Epoch 485/500
# 72/72 - 1s - loss: 0.4283 - accuracy: 0.8216 - 802ms/epoch - 11ms/step
# Epoch 486/500
# 72/72 - 1s - loss: 0.4230 - accuracy: 0.8259 - 790ms/epoch - 11ms/step
# Epoch 487/500
# 72/72 - 1s - loss: 0.4118 - accuracy: 0.8234 - 795ms/epoch - 11ms/step
# Epoch 488/500
# 72/72 - 1s - loss: 0.4155 - accuracy: 0.8268 - 790ms/epoch - 11ms/step
# Epoch 489/500
# 72/72 - 1s - loss: 0.4118 - accuracy: 0.8249 - 794ms/epoch - 11ms/step
# Epoch 490/500
# 72/72 - 1s - loss: 0.4131 - accuracy: 0.8289 - 794ms/epoch - 11ms/step
# Epoch 491/500
# 72/72 - 1s - loss: 0.4054 - accuracy: 0.8259 - 799ms/epoch - 11ms/step
# Epoch 492/500
# 72/72 - 1s - loss: 0.4170 - accuracy: 0.8230 - 802ms/epoch - 11ms/step
# Epoch 493/500
# 72/72 - 1s - loss: 0.4048 - accuracy: 0.8279 - 787ms/epoch - 11ms/step
# Epoch 494/500
# 72/72 - 1s - loss: 0.4077 - accuracy: 0.8263 - 793ms/epoch - 11ms/step
# Epoch 495/500
# 72/72 - 1s - loss: 0.4149 - accuracy: 0.8259 - 790ms/epoch - 11ms/step
# Epoch 496/500
# 72/72 - 1s - loss: 0.4015 - accuracy: 0.8280 - 930ms/epoch - 13ms/step
# Epoch 497/500
# 72/72 - 1s - loss: 0.4085 - accuracy: 0.8265 - 993ms/epoch - 14ms/step
# Epoch 498/500
# 72/72 - 1s - loss: 0.4047 - accuracy: 0.8283 - 937ms/epoch - 13ms/step
# Epoch 499/500
# 72/72 - 1s - loss: 0.4053 - accuracy: 0.8268 - 800ms/epoch - 11ms/step
# Epoch 500/500
# 72/72 - 1s - loss: 0.4063 - accuracy: 0.8298 - 792ms/epoch - 11ms/step
# 72/72 [==============================] - 1s 5ms/step
# 72/72 [==============================] - 0s 3ms/step
# 72/72 [==============================] - 0s 3ms/step
# accuracy_score: 0.5665
# cohen_kappa_score: 0.4582
# log_loss: 1.3328
# zero_one_loss: 0.4335
# hemming_loss: 0.4335
# matthews_corrcoef: 0.4731
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.38474130630493164
# 72/72 [==============================] - 1s 5ms/step - loss: 1.3328 - accuracy: 0.5665
# 72/72 [==============================] - 0s 4ms/step
# Test runtime: 1.2636408805847168
# 72/72 [==============================] - 0s 3ms/step
# 72/72 [==============================] - 0s 4ms/step - loss: 1.3328 - accuracy: 0.5665
# 72/72 [==============================] - 0s 4ms/step - loss: 1.3328 - accuracy: 0.5665
# 72/72 [==============================] - 0s 3ms/step
# 72/72 [==============================] - 0s 5ms/step - loss: 1.3328 - accuracy: 0.5665
# 72/72 [==============================] - 0s 3ms/step
