# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

import math

# %%
data_path6 = '/content/Epileptic Seizure Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  if Labels[i]==2 or Labels[i]==3 or Labels[i]==4 or Labels[i]==5:
    Labels[i]=0
  else:
    Labels[i]=1

# %%
Labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 0    9200
# 1    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=45)

X_sm, y_sm = sm.fit_resample(Features, Labels)

print(f'''Shape of X before SMOTE: {Features.shape}
Shape of X after SMOTE: {X_sm.shape}''')
# Out:
# Shape of X before SMOTE: (11500, 178)
# Shape of X after SMOTE: (18400, 178)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (14720, 178)
# Train labels shape: (14720,)
# Test data shape: (3680, 178)
# Test labels shape: (3680,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (14720, 178)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (14720, 178, 1)

# %%
#classes
classes = [0, 1]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %% [markdown]
# ## Transformer

# %%
# OPTIMIZER
LEARNING_RATE_2 = 1e-3
WEIGHT_DECAY_2 = 1e-4
LAYER_NORM_EPS_2 = 1e-6
PROJECTION_DIM_2 = 512 # no se puede modificar
NUM_HEADS_2 = 8
NUM_LAYERS_2 = 1
MLP_UNITS_2 = [
    PROJECTION_DIM_2 * 2,
    PROJECTION_DIM_2
]
def mlp(x, dropout_rate, hidden_units):
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
def transformer_2(encoded_patches):

    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS_2, key_dim=PROJECTION_DIM_2, dropout=0.1
    )(x1, x1)

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS_2, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x4, x2])
    return encoded_patches

def Transform_sh_2(inputs):
      # Iterate over the number of layers and stack up blocks of
      # Transformer.
    for i in range(NUM_LAYERS_2):
          # Add a Transformer block.
        encoded_patches = transformer_2(inputs)

    return encoded_patches

# %% [markdown]
# ## CapsNet

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=2
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,2,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 2, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %% [markdown]
# ## Transformer_Caps_Net

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  CVT1=Transform_sh_2(Pool_1)
  representation = tf.keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(CVT1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(representation)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7facad4616c0>)
# Epoch 1/500
# 115/115 - 36s - loss: 0.3666 - accuracy: 0.8261 - 36s/epoch - 310ms/step
# Epoch 2/500
# 115/115 - 3s - loss: 0.1578 - accuracy: 0.9432 - 3s/epoch - 30ms/step
# Epoch 3/500
# 115/115 - 4s - loss: 0.1385 - accuracy: 0.9489 - 4s/epoch - 31ms/step
# Epoch 4/500
# 115/115 - 4s - loss: 0.1270 - accuracy: 0.9541 - 4s/epoch - 31ms/step
# Epoch 5/500
# 115/115 - 4s - loss: 0.1185 - accuracy: 0.9562 - 4s/epoch - 31ms/step
# Epoch 6/500
# 115/115 - 4s - loss: 0.1051 - accuracy: 0.9613 - 4s/epoch - 31ms/step
# Epoch 7/500
# 115/115 - 4s - loss: 0.1009 - accuracy: 0.9620 - 4s/epoch - 32ms/step
# Epoch 8/500
# 115/115 - 4s - loss: 0.0944 - accuracy: 0.9647 - 4s/epoch - 31ms/step
# Epoch 9/500
# 115/115 - 4s - loss: 0.0989 - accuracy: 0.9635 - 4s/epoch - 31ms/step
# Epoch 10/500
# 115/115 - 4s - loss: 0.0934 - accuracy: 0.9660 - 4s/epoch - 32ms/step
# Epoch 11/500
# 115/115 - 4s - loss: 0.0876 - accuracy: 0.9683 - 4s/epoch - 32ms/step
# Epoch 12/500
# 115/115 - 4s - loss: 0.0834 - accuracy: 0.9691 - 4s/epoch - 32ms/step
# Epoch 13/500
# 115/115 - 4s - loss: 0.0730 - accuracy: 0.9741 - 4s/epoch - 32ms/step
# Epoch 14/500
# 115/115 - 4s - loss: 0.0658 - accuracy: 0.9757 - 4s/epoch - 33ms/step
# Epoch 15/500
# 115/115 - 4s - loss: 0.0609 - accuracy: 0.9789 - 4s/epoch - 32ms/step
# Epoch 16/500
# 115/115 - 4s - loss: 0.0721 - accuracy: 0.9753 - 4s/epoch - 33ms/step
# Epoch 17/500
# 115/115 - 4s - loss: 0.0546 - accuracy: 0.9805 - 4s/epoch - 33ms/step
# Epoch 18/500
# 115/115 - 4s - loss: 0.0542 - accuracy: 0.9804 - 4s/epoch - 32ms/step
# Epoch 19/500
# 115/115 - 4s - loss: 0.0462 - accuracy: 0.9836 - 4s/epoch - 34ms/step
# Epoch 20/500
# 115/115 - 4s - loss: 0.0410 - accuracy: 0.9853 - 4s/epoch - 35ms/step
# Epoch 21/500
# 115/115 - 4s - loss: 0.0463 - accuracy: 0.9840 - 4s/epoch - 32ms/step
# Epoch 22/500
# 115/115 - 4s - loss: 0.0481 - accuracy: 0.9838 - 4s/epoch - 32ms/step
# Epoch 23/500
# 115/115 - 4s - loss: 0.0525 - accuracy: 0.9819 - 4s/epoch - 32ms/step
# Epoch 24/500
# 115/115 - 4s - loss: 0.0402 - accuracy: 0.9855 - 4s/epoch - 32ms/step
# Epoch 25/500
# 115/115 - 4s - loss: 0.0426 - accuracy: 0.9851 - 4s/epoch - 32ms/step
# Epoch 26/500
# 115/115 - 4s - loss: 0.0303 - accuracy: 0.9893 - 4s/epoch - 32ms/step
# Epoch 27/500
# 115/115 - 4s - loss: 0.0314 - accuracy: 0.9882 - 4s/epoch - 32ms/step
# Epoch 28/500
# 115/115 - 4s - loss: 0.0401 - accuracy: 0.9862 - 4s/epoch - 31ms/step
# Epoch 29/500
# 115/115 - 4s - loss: 0.0379 - accuracy: 0.9871 - 4s/epoch - 32ms/step
# Epoch 30/500
# 115/115 - 4s - loss: 0.0273 - accuracy: 0.9891 - 4s/epoch - 32ms/step
# Epoch 31/500
# 115/115 - 4s - loss: 0.0379 - accuracy: 0.9870 - 4s/epoch - 32ms/step
# Epoch 32/500
# 115/115 - 4s - loss: 0.0329 - accuracy: 0.9887 - 4s/epoch - 32ms/step
# Epoch 33/500
# 115/115 - 4s - loss: 0.0279 - accuracy: 0.9899 - 4s/epoch - 32ms/step
# Epoch 34/500
# 115/115 - 4s - loss: 0.0245 - accuracy: 0.9910 - 4s/epoch - 32ms/step
# Epoch 35/500
# 115/115 - 4s - loss: 0.0267 - accuracy: 0.9908 - 4s/epoch - 32ms/step
# Epoch 36/500
# 115/115 - 4s - loss: 0.0193 - accuracy: 0.9930 - 4s/epoch - 32ms/step
# Epoch 37/500
# 115/115 - 4s - loss: 0.0187 - accuracy: 0.9933 - 4s/epoch - 32ms/step
# Epoch 38/500
# 115/115 - 4s - loss: 0.0228 - accuracy: 0.9927 - 4s/epoch - 32ms/step
# Epoch 39/500
# 115/115 - 4s - loss: 0.0254 - accuracy: 0.9921 - 4s/epoch - 32ms/step
# Epoch 40/500
# 115/115 - 4s - loss: 0.0189 - accuracy: 0.9933 - 4s/epoch - 32ms/step
# Epoch 41/500
# 115/115 - 4s - loss: 0.0145 - accuracy: 0.9947 - 4s/epoch - 32ms/step
# Epoch 42/500
# 115/115 - 4s - loss: 0.0178 - accuracy: 0.9929 - 4s/epoch - 32ms/step
# Epoch 43/500
# 115/115 - 4s - loss: 0.0171 - accuracy: 0.9937 - 4s/epoch - 32ms/step
# Epoch 44/500
# 115/115 - 4s - loss: 0.0177 - accuracy: 0.9941 - 4s/epoch - 32ms/step
# Epoch 45/500
# 115/115 - 4s - loss: 0.0193 - accuracy: 0.9933 - 4s/epoch - 32ms/step
# Epoch 46/500
# 115/115 - 4s - loss: 0.0264 - accuracy: 0.9914 - 4s/epoch - 32ms/step
# Epoch 47/500
# 115/115 - 4s - loss: 0.0179 - accuracy: 0.9944 - 4s/epoch - 32ms/step
# Epoch 48/500
# 115/115 - 4s - loss: 0.0167 - accuracy: 0.9936 - 4s/epoch - 32ms/step
# Epoch 49/500
# 115/115 - 4s - loss: 0.0473 - accuracy: 0.9836 - 4s/epoch - 32ms/step
# Epoch 50/500
# 115/115 - 4s - loss: 0.0226 - accuracy: 0.9928 - 4s/epoch - 32ms/step
# Epoch 51/500
# 115/115 - 4s - loss: 0.0229 - accuracy: 0.9930 - 4s/epoch - 32ms/step
# Epoch 52/500
# 115/115 - 4s - loss: 0.0172 - accuracy: 0.9946 - 4s/epoch - 32ms/step
# Epoch 53/500
# 115/115 - 4s - loss: 0.0131 - accuracy: 0.9954 - 4s/epoch - 32ms/step
# Epoch 54/500
# 115/115 - 4s - loss: 0.0147 - accuracy: 0.9958 - 4s/epoch - 32ms/step
# Epoch 55/500
# 115/115 - 4s - loss: 0.0224 - accuracy: 0.9917 - 4s/epoch - 32ms/step
# Epoch 56/500
# 115/115 - 4s - loss: 0.0161 - accuracy: 0.9942 - 4s/epoch - 32ms/step
# Epoch 57/500
# 115/115 - 4s - loss: 0.0121 - accuracy: 0.9956 - 4s/epoch - 32ms/step
# Epoch 58/500
# 115/115 - 4s - loss: 0.0133 - accuracy: 0.9958 - 4s/epoch - 32ms/step
# Epoch 59/500
# 115/115 - 4s - loss: 0.0077 - accuracy: 0.9976 - 4s/epoch - 32ms/step
# Epoch 60/500
# 115/115 - 4s - loss: 0.0125 - accuracy: 0.9960 - 4s/epoch - 32ms/step
# Epoch 61/500
# 115/115 - 4s - loss: 0.0141 - accuracy: 0.9951 - 4s/epoch - 32ms/step
# Epoch 62/500
# 115/115 - 4s - loss: 0.0193 - accuracy: 0.9941 - 4s/epoch - 32ms/step
# Epoch 63/500
# 115/115 - 4s - loss: 0.0133 - accuracy: 0.9960 - 4s/epoch - 32ms/step
# Epoch 64/500
# 115/115 - 4s - loss: 0.0081 - accuracy: 0.9972 - 4s/epoch - 32ms/step
# Epoch 65/500
# 115/115 - 4s - loss: 0.0115 - accuracy: 0.9963 - 4s/epoch - 32ms/step
# Epoch 66/500
# 115/115 - 4s - loss: 0.0106 - accuracy: 0.9962 - 4s/epoch - 32ms/step
# Epoch 67/500
# 115/115 - 4s - loss: 0.0129 - accuracy: 0.9961 - 4s/epoch - 32ms/step
# Epoch 68/500
# 115/115 - 4s - loss: 0.0068 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 69/500
# 115/115 - 4s - loss: 0.0126 - accuracy: 0.9963 - 4s/epoch - 32ms/step
# Epoch 70/500
# 115/115 - 4s - loss: 0.0102 - accuracy: 0.9967 - 4s/epoch - 32ms/step
# Epoch 71/500
# 115/115 - 4s - loss: 0.0130 - accuracy: 0.9955 - 4s/epoch - 32ms/step
# Epoch 72/500
# 115/115 - 4s - loss: 0.0109 - accuracy: 0.9959 - 4s/epoch - 32ms/step
# Epoch 73/500
# 115/115 - 4s - loss: 0.0115 - accuracy: 0.9974 - 4s/epoch - 32ms/step
# Epoch 74/500
# 115/115 - 4s - loss: 0.0097 - accuracy: 0.9970 - 4s/epoch - 32ms/step
# Epoch 75/500
# 115/115 - 4s - loss: 0.0145 - accuracy: 0.9957 - 4s/epoch - 32ms/step
# Epoch 76/500
# 115/115 - 4s - loss: 0.0256 - accuracy: 0.9923 - 4s/epoch - 32ms/step
# Epoch 77/500
# 115/115 - 4s - loss: 0.0131 - accuracy: 0.9960 - 4s/epoch - 32ms/step
# Epoch 78/500
# 115/115 - 4s - loss: 0.0090 - accuracy: 0.9974 - 4s/epoch - 32ms/step
# Epoch 79/500
# 115/115 - 4s - loss: 0.0104 - accuracy: 0.9967 - 4s/epoch - 32ms/step
# Epoch 80/500
# 115/115 - 4s - loss: 0.0100 - accuracy: 0.9969 - 4s/epoch - 32ms/step
# Epoch 81/500
# 115/115 - 4s - loss: 0.0071 - accuracy: 0.9977 - 4s/epoch - 32ms/step
# Epoch 82/500
# 115/115 - 4s - loss: 0.0056 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 83/500
# 115/115 - 4s - loss: 0.0257 - accuracy: 0.9924 - 4s/epoch - 32ms/step
# Epoch 84/500
# 115/115 - 4s - loss: 0.0118 - accuracy: 0.9964 - 4s/epoch - 32ms/step
# Epoch 85/500
# 115/115 - 4s - loss: 0.0075 - accuracy: 0.9977 - 4s/epoch - 32ms/step
# Epoch 86/500
# 115/115 - 4s - loss: 0.0273 - accuracy: 0.9908 - 4s/epoch - 32ms/step
# Epoch 87/500
# 115/115 - 4s - loss: 0.0110 - accuracy: 0.9964 - 4s/epoch - 32ms/step
# Epoch 88/500
# 115/115 - 4s - loss: 0.0164 - accuracy: 0.9947 - 4s/epoch - 32ms/step
# Epoch 89/500
# 115/115 - 4s - loss: 0.0070 - accuracy: 0.9972 - 4s/epoch - 32ms/step
# Epoch 90/500
# 115/115 - 4s - loss: 0.0072 - accuracy: 0.9978 - 4s/epoch - 32ms/step
# Epoch 91/500
# 115/115 - 4s - loss: 0.0044 - accuracy: 0.9986 - 4s/epoch - 32ms/step
# Epoch 92/500
# 115/115 - 4s - loss: 0.0076 - accuracy: 0.9973 - 4s/epoch - 32ms/step
# Epoch 93/500
# 115/115 - 4s - loss: 0.0078 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 94/500
# 115/115 - 4s - loss: 0.0034 - accuracy: 0.9989 - 4s/epoch - 32ms/step
# Epoch 95/500
# 115/115 - 4s - loss: 0.0075 - accuracy: 0.9978 - 4s/epoch - 32ms/step
# Epoch 96/500
# 115/115 - 4s - loss: 0.0094 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 97/500
# 115/115 - 4s - loss: 0.0182 - accuracy: 0.9944 - 4s/epoch - 32ms/step
# Epoch 98/500
# 115/115 - 4s - loss: 0.0096 - accuracy: 0.9969 - 4s/epoch - 32ms/step
# Epoch 99/500
# 115/115 - 4s - loss: 0.0052 - accuracy: 0.9986 - 4s/epoch - 32ms/step
# Epoch 100/500
# 115/115 - 4s - loss: 0.0054 - accuracy: 0.9982 - 4s/epoch - 32ms/step
# Epoch 101/500
# 115/115 - 4s - loss: 0.0081 - accuracy: 0.9969 - 4s/epoch - 32ms/step
# Epoch 102/500
# 115/115 - 4s - loss: 0.0080 - accuracy: 0.9971 - 4s/epoch - 32ms/step
# Epoch 103/500
# 115/115 - 4s - loss: 0.0058 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 104/500
# 115/115 - 4s - loss: 0.0102 - accuracy: 0.9973 - 4s/epoch - 32ms/step
# Epoch 105/500
# 115/115 - 4s - loss: 0.0111 - accuracy: 0.9965 - 4s/epoch - 32ms/step
# Epoch 106/500
# 115/115 - 4s - loss: 0.0112 - accuracy: 0.9967 - 4s/epoch - 32ms/step
# Epoch 107/500
# 115/115 - 4s - loss: 0.0065 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 108/500
# 115/115 - 4s - loss: 0.0082 - accuracy: 0.9976 - 4s/epoch - 32ms/step
# Epoch 109/500
# 115/115 - 4s - loss: 0.0108 - accuracy: 0.9973 - 4s/epoch - 32ms/step
# Epoch 110/500
# 115/115 - 4s - loss: 0.0088 - accuracy: 0.9970 - 4s/epoch - 32ms/step
# Epoch 111/500
# 115/115 - 4s - loss: 0.0061 - accuracy: 0.9982 - 4s/epoch - 32ms/step
# Epoch 112/500
# 115/115 - 4s - loss: 0.0057 - accuracy: 0.9984 - 4s/epoch - 32ms/step
# Epoch 113/500
# 115/115 - 4s - loss: 0.0098 - accuracy: 0.9969 - 4s/epoch - 32ms/step
# Epoch 114/500
# 115/115 - 4s - loss: 0.0070 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 115/500
# 115/115 - 4s - loss: 0.0064 - accuracy: 0.9979 - 4s/epoch - 32ms/step
# Epoch 116/500
# 115/115 - 4s - loss: 0.0096 - accuracy: 0.9971 - 4s/epoch - 32ms/step
# Epoch 117/500
# 115/115 - 4s - loss: 0.0095 - accuracy: 0.9969 - 4s/epoch - 32ms/step
# Epoch 118/500
# 115/115 - 4s - loss: 0.0087 - accuracy: 0.9972 - 4s/epoch - 32ms/step
# Epoch 119/500
# 115/115 - 4s - loss: 0.0078 - accuracy: 0.9976 - 4s/epoch - 32ms/step
# Epoch 120/500
# 115/115 - 4s - loss: 0.0051 - accuracy: 0.9980 - 4s/epoch - 32ms/step
# Epoch 121/500
# 115/115 - 4s - loss: 0.0062 - accuracy: 0.9981 - 4s/epoch - 32ms/step
# Epoch 122/500
# 115/115 - 4s - loss: 0.0047 - accuracy: 0.9984 - 4s/epoch - 32ms/step
# Epoch 123/500
# 115/115 - 4s - loss: 0.0150 - accuracy: 0.9949 - 4s/epoch - 32ms/step
# Epoch 124/500
# 115/115 - 4s - loss: 0.0062 - accuracy: 0.9982 - 4s/epoch - 32ms/step
# Epoch 125/500
# 115/115 - 4s - loss: 0.0075 - accuracy: 0.9977 - 4s/epoch - 32ms/step
# Epoch 126/500
# 115/115 - 4s - loss: 0.0041 - accuracy: 0.9986 - 4s/epoch - 32ms/step
# Epoch 127/500
# 115/115 - 4s - loss: 0.0151 - accuracy: 0.9949 - 4s/epoch - 32ms/step
# Epoch 128/500
# 115/115 - 4s - loss: 0.0112 - accuracy: 0.9964 - 4s/epoch - 32ms/step
# Epoch 129/500
# 115/115 - 4s - loss: 0.0043 - accuracy: 0.9982 - 4s/epoch - 32ms/step
# Epoch 130/500
# 115/115 - 4s - loss: 0.0053 - accuracy: 0.9979 - 4s/epoch - 32ms/step
# Epoch 131/500
# 115/115 - 4s - loss: 0.0053 - accuracy: 0.9984 - 4s/epoch - 32ms/step
# Epoch 132/500
# 115/115 - 4s - loss: 0.0056 - accuracy: 0.9987 - 4s/epoch - 32ms/step
# Epoch 133/500
# 115/115 - 4s - loss: 0.0070 - accuracy: 0.9977 - 4s/epoch - 32ms/step
# Epoch 134/500
# 115/115 - 4s - loss: 0.0056 - accuracy: 0.9987 - 4s/epoch - 32ms/step
# Epoch 135/500
# 115/115 - 4s - loss: 0.0029 - accuracy: 0.9995 - 4s/epoch - 32ms/step
# Epoch 136/500
# 115/115 - 4s - loss: 0.0127 - accuracy: 0.9956 - 4s/epoch - 32ms/step
# Epoch 137/500
# 115/115 - 4s - loss: 0.0064 - accuracy: 0.9978 - 4s/epoch - 32ms/step
# Epoch 138/500
# 115/115 - 4s - loss: 0.0083 - accuracy: 0.9974 - 4s/epoch - 32ms/step
# Epoch 139/500
# 115/115 - 4s - loss: 0.0062 - accuracy: 0.9983 - 4s/epoch - 32ms/step
# Epoch 140/500
# 115/115 - 4s - loss: 0.0031 - accuracy: 0.9990 - 4s/epoch - 32ms/step
# Epoch
- accuracy: 0.9997 - 4s/epoch - 32ms/step
# Epoch 483/500
# 115/115 - 4s - loss: 0.0024 - accuracy: 0.9993 - 4s/epoch - 32ms/step
# Epoch 484/500
# 115/115 - 4s - loss: 7.9142e-04 - accuracy: 0.9999 - 4s/epoch - 31ms/step
# Epoch 485/500
# 115/115 - 4s - loss: 0.0036 - accuracy: 0.9986 - 4s/epoch - 32ms/step
# Epoch 486/500
# 115/115 - 4s - loss: 0.0011 - accuracy: 0.9998 - 4s/epoch - 32ms/step
# Epoch 487/500
# 115/115 - 4s - loss: 0.0012 - accuracy: 0.9998 - 4s/epoch - 32ms/step
# Epoch 488/500
# 115/115 - 4s - loss: 5.4793e-04 - accuracy: 1.0000 - 4s/epoch - 32ms/step
# Epoch 489/500
# 115/115 - 4s - loss: 0.0012 - accuracy: 0.9997 - 4s/epoch - 32ms/step
# Epoch 490/500
# 115/115 - 4s - loss: 5.6500e-04 - accuracy: 1.0000 - 4s/epoch - 32ms/step
# Epoch 491/500
# 115/115 - 4s - loss: 0.0043 - accuracy: 0.9989 - 4s/epoch - 32ms/step
# Epoch 492/500
# 115/115 - 4s - loss: 0.0013 - accuracy: 0.9997 - 4s/epoch - 32ms/step
# Epoch 493/500
# 115/115 - 4s - loss: 0.0011 - accuracy: 0.9998 - 4s/epoch - 32ms/step
# Epoch 494/500
# 115/115 - 4s - loss: 0.0028 - accuracy: 0.9992 - 4s/epoch - 31ms/step
# Epoch 495/500
# 115/115 - 4s - loss: 0.0015 - accuracy: 0.9997 - 4s/epoch - 32ms/step
# Epoch 496/500
# 115/115 - 4s - loss: 0.0019 - accuracy: 0.9996 - 4s/epoch - 31ms/step
# Epoch 497/500
# 115/115 - 4s - loss: 5.7971e-04 - accuracy: 1.0000 - 4s/epoch - 32ms/step
# Epoch 498/500
# 115/115 - 4s - loss: 0.0022 - accuracy: 0.9994 - 4s/epoch - 32ms/step
# Epoch 499/500
# 115/115 - 4s - loss: 0.0025 - accuracy: 0.9995 - 4s/epoch - 32ms/step
# Epoch 500/500
# 115/115 - 4s - loss: 6.9446e-04 - accuracy: 0.9999 - 4s/epoch - 32ms/step
# 115/115 [==============================] - 1s 5ms/step
# 115/115 [==============================] - 1s 5ms/step
# 115/115 [==============================] - 1s 5ms/step
# accuracy_score: 0.9989
# cohen_kappa_score: 0.9978
# log_loss: 0.0077
# zero_one_loss: 0.0011
# hemming_loss: 0.0011
# matthews_corrcoef: 0.9978
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.5605423450469971
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 0.9989
# 115/115 [==============================] - 1s 5ms/step
# Test runtime: 1.9501924514770508
# 115/115 [==============================] - 1s 4ms/step
# 115/115 [==============================] - 1s 5ms/step - loss: 0.0077 - accuracy: 0.9989
# 115/115 [==============================] - 1s 5ms/step - loss: 0.0077 - accuracy: 0.9989
# 115/115 [==============================] - 1s 5ms/step
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 0.9989
# 115/115 [==============================] - 1s 6ms/step
