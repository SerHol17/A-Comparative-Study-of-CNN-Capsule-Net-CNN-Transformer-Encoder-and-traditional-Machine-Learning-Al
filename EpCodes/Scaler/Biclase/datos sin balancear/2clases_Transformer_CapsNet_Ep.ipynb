# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
# libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator
import time

#Visualizers
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
import matplotlib.pyplot as plt

#Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import log_loss
from sklearn.metrics import zero_one_loss
from sklearn.metrics import matthews_corrcoef

#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

#Neural Network
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Lambda, Layer, ReLU
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D,Concatenate

import warnings
warnings.filterwarnings('ignore')

# %%
from keras import optimizers

# %%
import tensorflow
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, Input, Reshape, Lambda, Layer, Flatten, BatchNormalization,AveragePooling2D
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist

from keras import initializers

from keras.utils import to_categorical
from keras.layers.core import Activation

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

import math

# %%
data_path6 = '/content/Epileptic Seizure Recognition.csv'
figures_path = './figures'

# %%
if not os.path.exists(figures_path):
    os.makedirs(figures_path)
if not os.path.exists(figures_path+"/6FP"):
    os.makedirs(figures_path+"/6FP")

# %%
Data = pd.read_csv(data_path6)

# %%
Data=Data.drop(["Unnamed"],axis=1)

# %%
Labels = Data['y'].values
Features = Data.drop(['y'],axis=1).values


print('Features shape:', Features.shape)
print('Labels shape:', Labels.shape)
# Out:
# Features shape: (11500, 178)
# Labels shape: (11500,)

# %%
for i in range(len(Labels)):
  if Labels[i]==2 or Labels[i]==3 or Labels[i]==4 or Labels[i]==5:
    Labels[i]=0
  else:
    Labels[i]=1

# %%
Labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
LabelDataFrame=pd.DataFrame(Labels)

# %%
#Write function for class-centric metrics
# Classification report
def CR_viz():
    def Class_report(model,classes):
        visualizer = ClassificationReport(model, classes=classes, support=True)
        train_start_time = time.time()
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        print(f'Train runtime: {time.time()-train_start_time}')
        test_start_time = time.time()
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        print(f'Test runtime: {time.time()-test_start_time}')
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        Class_report(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CR.pdf")

#Class Prediction Error
def CPE_viz():
    def CPE(model,classes):
        visualizer = ClassPredictionError(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CPE(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CPE.pdf")

#Confusion matrix
def CM_viz():
    def CM(model,classes):
        visualizer = ConfusionMatrix(model, classes=classes, percent=True)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        CM(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_CM.pdf")

#ROC-AUC
def ROC_viz():
    def ROC(model,classes):
        visualizer = ROCAUC(model, classes=classes)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        ROC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_ROC.pdf")

#Precision Recall Curve
def PRC_viz():
    def PRC(model,classes):
        visualizer = PrecisionRecallCurve(model,classes=classes, per_class=True, iso_f1_curves=False,
    fill_area=False, micro=False)
        visualizer.fit(X_train, y_train)  # Fit the visualizer and the model
        visualizer.score(X_test, y_test)  # Evaluate the model on the test data
        return visualizer.poof()
    for name, classifier in zip(names, classifiers):
        fig, ax = plt.subplots(nrows=1, ncols=1 )
        PRC(classifier,classes)
        #fig.savefig(figures_path+"/"+str(len(classes))+"FP/"+name+"_PRC.pdf")

# %%
LabelDataFrame[0].value_counts()
# Out:
# 0    9200
# 1    2300
# Name: 0, dtype: int64

# %%
# Write function for aggregate metrics
def classifier_metrics():
    def metrics(model):
        #     model=model_name()
        model.fit(X_train, y_train)  # Fit the visualizer and the model
        y_pred = model.predict(X_test)
       # model.save('modeloEpilepsia.h5')
        try:
            y_prob = model.predict_proba(X_test)
            log_metric = log_loss(y_test,y_prob)
        except:
            y_prob = "Not probablistic"
            log_metric = 0
        else:
            y_pred = model.predict(X_test)

        acc_score=accuracy_score(y_test,y_pred)
        c_k_s=cohen_kappa_score(y_test,y_pred)
        zero_met=zero_one_loss(y_test,y_pred)
        hl=hamming_loss(y_test,y_pred)
        mc=matthews_corrcoef(y_test,y_pred)
        print('accuracy_score: {0:.4f}'.format(acc_score))
        print('cohen_kappa_score: {0:.4f}'.format(c_k_s))
        print('log_loss: {0:.4f}'.format(log_metric))
        print('zero_one_loss: {0:.4f}'.format(zero_met))
        print('hemming_loss: {0:.4f}'.format(hl))
        print('matthews_corrcoef: {0:.4f}'.format(mc))
    for name in classifiers:
        print (str(name))
        metrics(name)
        print()
        print ("---------------------------------------------------------------------------------")

# %%
X_train, X_test, y_train, y_test = train_test_split(Features, Labels, test_size=0.2, stratify=Labels, random_state=42)

print('Train data shape:', X_train.shape)
print('Train labels shape:', y_train.shape)
print('Test data shape:', X_test.shape)
print('Test labels shape:', y_test.shape)
# Out:
# Train data shape: (9200, 178)
# Train labels shape: (9200,)
# Test data shape: (2300, 178)
# Test labels shape: (2300,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (9200, 178)

# %%
X_train=np.expand_dims(X_train, axis=-1)
X_test=np.expand_dims(X_test, axis=-1)

# %%
X_train.shape
# Out:
# (9200, 178, 1)

# %%
#classes
classes = [0, 1]

# %%
# select classifiers

## HIPERPARAMETROS
#classifiers=[
#ExtraTreesClassifier(n_estimators=220, max_depth=None, min_samples_split=3, random_state=18), #Definitivo
#svm.SVC(C=3000000, gamma=0.1), #Definitivo
#RandomForestClassifier(n_estimators=600,criterion='entropy',random_state=18), #Definitivo
#GradientBoostingClassifier(n_estimators=2048, learning_rate=0.03, max_depth=10, random_state=10) #Definitivo
#]

#names=['ET', 'SVM', 'RF','GB']

# %%
#deploy visualization A
#visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz(),PRC_viz()]

# %%
#Deploy aggregate metrics
#classifier_metrics()

# %% [markdown]
# ## Transformer

# %%
# OPTIMIZER
LEARNING_RATE_2 = 1e-3
WEIGHT_DECAY_2 = 1e-4
LAYER_NORM_EPS_2 = 1e-6
PROJECTION_DIM_2 = 512 # no se puede modificar
NUM_HEADS_2 = 8
NUM_LAYERS_2 = 1
MLP_UNITS_2 = [
    PROJECTION_DIM_2 * 2,
    PROJECTION_DIM_2
]
def mlp(x, dropout_rate, hidden_units):
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
def transformer_2(encoded_patches):

    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS_2, key_dim=PROJECTION_DIM_2, dropout=0.1
    )(x1, x1)

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS_2, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x4, x2])
    return encoded_patches

def Transform_sh_2(inputs):
      # Iterate over the number of layers and stack up blocks of
      # Transformer.
    for i in range(NUM_LAYERS_2):
          # Add a Transformer block.
        encoded_patches = transformer_2(inputs)

    return encoded_patches

# %% [markdown]
# ## CapsNet

# %%
from keras.layers import GlobalAveragePooling2D,ReLU
num_clases=2
vec=16
class DigitCapsuleLayer(Layer):
    # creating a layer class in keras
    def __init__(self, **kwargs):
        super(DigitCapsuleLayer, self).__init__(**kwargs)
        self.kernel_initializer = initializers.get('glorot_uniform')

    def build(self, input_shape):
        # initialize weight matrix for each capsule in lower layer
        self.W = self.add_weight(shape = [1,2,num_clases, vec, 512], initializer = self.kernel_initializer, name = 'weights')
        self.built = True

    def call(self, inputs):

        u = tf.reshape(inputs, (-1, 2, 512)) # u.shape: (None, 1152, 8)
        u = tf.expand_dims(u, axis=-2) # u.shape: (None, 1152, 1, 8)
        u = tf.expand_dims(u, axis=-1) # u.shape: (None, 1152, 1, 8, 1)
        u_hat = tf.matmul(self.W, u) # u_hat.shape: (None, 1152, 10, 16, 1)
        u_hat = tf.squeeze(u_hat, [4]) # u_hat.shape: (None, 1152, 10, 16)
        b = tf.zeros(shape = [K.shape(inputs)[0],2, num_clases, 1])

# routing algorithm with updating coupling coefficient c, using scalar product b/w input capsule and output capsule
        for i in range(3-1):
            c = tf.nn.softmax(b, axis=-2) # c.shape: (None, 1152, 10, 1)
            s = tf.reduce_sum(tf.multiply(c, u_hat), axis=1, keepdims=True) # s.shape: (None, 1, 10, 16)
            v = squash(s) # v.shape: (None, 1, 10, 16)
            agreement = tf.squeeze(tf.matmul(tf.expand_dims(u_hat, axis=-1), tf.expand_dims(v, axis=-1), transpose_a=True), [4]) # agreement.shape: (None, 1152, 10, 1)
            # Before matmul following intermediate shapes are present, they are not assigned to a variable but just for understanding the code.
            # u_hat.shape (Intermediate shape) : (None, 1152, 10, 16, 1)
            # v.shape (Intermediate shape): (None, 1, 10, 16, 1)
            # Since the first parameter of matmul is to be transposed its shape becomes:(None, 1152, 10, 1, 16)
            # Now matmul is performed in the last two dimensions, and others are broadcasted
            # Before squeezing we have an intermediate shape of (None, 1152, 10, 1, 1)
            b += agreement

        return v

    def compute_output_shape(self, input_shape):
        return tuple([None, num_clases, vec])

epsilon = 1e-7

def output_layer(inputs):
    return K.sqrt(K.sum(K.square(inputs), -1) + K.epsilon())

def squash(inputs):
    # take norm of input vectors
    squared_norm = tf.keras.backend.sum(tf.keras.backend.square(inputs), axis = -1, keepdims = True)

    # use the formula for non-linear function to return squashed output
    return ((squared_norm/(1+squared_norm))/(K.sqrt(squared_norm+K.epsilon())))*inputs

def safe_norm(v, axis=-1, epsilon=1e-7):
    v_ = tf.reduce_sum(tf.square(v), axis = axis, keepdims=True)
    return tf.sqrt(v_ + epsilon)

# %% [markdown]
# ## Transformer_Caps_Net

# %%
class KerasBatchClassifier(KerasClassifier, BaseEstimator):
    def __init__(self, model, **kwargs):
        super().__init__(model)
        self.fit_kwargs = kwargs
        self._estimator_type = 'classifier'

    def fit(self, x, y, *args, **kwargs):
        y = np.array(y)
        if len(y.shape) == 2 and y.shape[1] > 1:
          self.classes_ = np.arange(y.shape[1])
        elif (len(y.shape) == 2 and y.shape[1] == 1) or len(y.shape) == 1:
          self.classes_ = np.unique(y)
          y = np.searchsorted(self.classes_, y)
        else:
          raise ValueError('Invalid shape for y: ' + str(y.shape))
        self.n_classes_ = len(self.classes_)
        return super(KerasClassifier, self).fit(x, y, **self.fit_kwargs)


# RED NEURONAL
def FullyConnected():

  inputs = Input(shape=(X_train.shape[1],1), name="input_1")


  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(inputs)
  Layer_1=tf.keras.layers.Conv1D(32,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)


  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(64,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(128,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(256,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)

  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  Pool_1=tf.keras.layers.Dropout(rate=0.5)(Pool_1)

  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Pool_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Layer_1=tf.keras.layers.Conv1D(512,3,activation="selu",padding="same")(Layer_1)
  Pool_1=tf.keras.layers.MaxPool1D(2)(Layer_1)
  CVT1=Transform_sh_2(Pool_1)
  representation = tf.keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS_2)(CVT1)
  # squash the reshaped output to make length of vector b/w 0 and 1
  squashed_output = tf.keras.layers.Lambda(squash)(representation)
  digit_caps = DigitCapsuleLayer()(squashed_output)
  Acont= safe_norm(digit_caps)
  mast = tf.reshape(Acont, (-1,Acont.shape[2],Acont.shape[3]))
  outputs = tf.keras.layers.Lambda(output_layer)(mast)
  model = Model(inputs = inputs, outputs = outputs)
  optimizer=Adam(learning_rate=0.001)
  model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  #model.compile(optimizer=optimizer,loss=[loss_fn,'mse'],loss_weights = [1. ,0.0005],metrics=['accuracy'])
  return model

# %%
classifiers=[KerasBatchClassifier(FullyConnected, epochs=500, batch_size=128, verbose=2)]
names = ['FNN']

# %%
classifier_metrics()
visualization =[CR_viz(),CPE_viz(),CM_viz(),ROC_viz()]
# Out:
# KerasBatchClassifier(build_fn=<function FullyConnected at 0x7f5b69643d90>)
# Epoch 1/500
# 72/72 - 34s - loss: 0.4722 - accuracy: 0.8076 - 34s/epoch - 472ms/step
# Epoch 2/500
# 72/72 - 2s - loss: 0.1531 - accuracy: 0.9452 - 2s/epoch - 31ms/step
# Epoch 3/500
# 72/72 - 2s - loss: 0.1713 - accuracy: 0.9385 - 2s/epoch - 32ms/step
# Epoch 4/500
# 72/72 - 2s - loss: 0.1082 - accuracy: 0.9668 - 2s/epoch - 32ms/step
# Epoch 5/500
# 72/72 - 2s - loss: 0.0896 - accuracy: 0.9712 - 2s/epoch - 31ms/step
# Epoch 6/500
# 72/72 - 2s - loss: 0.0825 - accuracy: 0.9702 - 2s/epoch - 31ms/step
# Epoch 7/500
# 72/72 - 2s - loss: 0.0777 - accuracy: 0.9742 - 2s/epoch - 31ms/step
# Epoch 8/500
# 72/72 - 2s - loss: 0.0827 - accuracy: 0.9710 - 2s/epoch - 31ms/step
# Epoch 9/500
# 72/72 - 2s - loss: 0.0739 - accuracy: 0.9735 - 2s/epoch - 33ms/step
# Epoch 10/500
# 72/72 - 2s - loss: 0.0683 - accuracy: 0.9779 - 2s/epoch - 31ms/step
# Epoch 11/500
# 72/72 - 2s - loss: 0.0689 - accuracy: 0.9765 - 2s/epoch - 31ms/step
# Epoch 12/500
# 72/72 - 2s - loss: 0.0663 - accuracy: 0.9786 - 2s/epoch - 31ms/step
# Epoch 13/500
# 72/72 - 2s - loss: 0.0659 - accuracy: 0.9796 - 2s/epoch - 31ms/step
# Epoch 14/500
# 72/72 - 2s - loss: 0.0656 - accuracy: 0.9775 - 2s/epoch - 33ms/step
# Epoch 15/500
# 72/72 - 2s - loss: 0.0611 - accuracy: 0.9792 - 2s/epoch - 32ms/step
# Epoch 16/500
# 72/72 - 2s - loss: 0.0586 - accuracy: 0.9814 - 2s/epoch - 32ms/step
# Epoch 17/500
# 72/72 - 2s - loss: 0.0664 - accuracy: 0.9783 - 2s/epoch - 31ms/step
# Epoch 18/500
# 72/72 - 2s - loss: 0.0583 - accuracy: 0.9816 - 2s/epoch - 31ms/step
# Epoch 19/500
# 72/72 - 2s - loss: 0.0512 - accuracy: 0.9836 - 2s/epoch - 32ms/step
# Epoch 20/500
# 72/72 - 2s - loss: 0.0507 - accuracy: 0.9832 - 2s/epoch - 33ms/step
# Epoch 21/500
# 72/72 - 2s - loss: 0.0677 - accuracy: 0.9784 - 2s/epoch - 32ms/step
# Epoch 22/500
# 72/72 - 2s - loss: 0.0486 - accuracy: 0.9840 - 2s/epoch - 32ms/step
# Epoch 23/500
# 72/72 - 2s - loss: 0.0515 - accuracy: 0.9826 - 2s/epoch - 32ms/step
# Epoch 24/500
# 72/72 - 2s - loss: 0.0548 - accuracy: 0.9810 - 2s/epoch - 32ms/step
# Epoch 25/500
# 72/72 - 2s - loss: 0.0479 - accuracy: 0.9842 - 2s/epoch - 34ms/step
# Epoch 26/500
# 72/72 - 2s - loss: 0.0474 - accuracy: 0.9848 - 2s/epoch - 32ms/step
# Epoch 27/500
# 72/72 - 2s - loss: 0.0517 - accuracy: 0.9829 - 2s/epoch - 32ms/step
# Epoch 28/500
# 72/72 - 2s - loss: 0.0455 - accuracy: 0.9853 - 2s/epoch - 32ms/step
# Epoch 29/500
# 72/72 - 2s - loss: 0.0439 - accuracy: 0.9840 - 2s/epoch - 33ms/step
# Epoch 30/500
# 72/72 - 3s - loss: 0.0597 - accuracy: 0.9805 - 3s/epoch - 36ms/step
# Epoch 31/500
# 72/72 - 2s - loss: 0.0424 - accuracy: 0.9858 - 2s/epoch - 34ms/step
# Epoch 32/500
# 72/72 - 3s - loss: 0.0422 - accuracy: 0.9861 - 3s/epoch - 39ms/step
# Epoch 33/500
# 72/72 - 3s - loss: 0.0448 - accuracy: 0.9863 - 3s/epoch - 36ms/step
# Epoch 34/500
# 72/72 - 2s - loss: 0.0380 - accuracy: 0.9886 - 2s/epoch - 33ms/step
# Epoch 35/500
# 72/72 - 2s - loss: 0.0322 - accuracy: 0.9902 - 2s/epoch - 34ms/step
# Epoch 36/500
# 72/72 - 2s - loss: 0.0321 - accuracy: 0.9888 - 2s/epoch - 33ms/step
# Epoch 37/500
# 72/72 - 2s - loss: 0.0373 - accuracy: 0.9886 - 2s/epoch - 32ms/step
# Epoch 38/500
# 72/72 - 2s - loss: 0.0353 - accuracy: 0.9873 - 2s/epoch - 32ms/step
# Epoch 39/500
# 72/72 - 2s - loss: 0.0303 - accuracy: 0.9898 - 2s/epoch - 32ms/step
# Epoch 40/500
# 72/72 - 2s - loss: 0.0324 - accuracy: 0.9887 - 2s/epoch - 33ms/step
# Epoch 41/500
# 72/72 - 2s - loss: 0.0372 - accuracy: 0.9878 - 2s/epoch - 33ms/step
# Epoch 42/500
# 72/72 - 2s - loss: 0.0404 - accuracy: 0.9864 - 2s/epoch - 32ms/step
# Epoch 43/500
# 72/72 - 2s - loss: 0.0325 - accuracy: 0.9893 - 2s/epoch - 32ms/step
# Epoch 44/500
# 72/72 - 2s - loss: 0.0320 - accuracy: 0.9899 - 2s/epoch - 32ms/step
# Epoch 45/500
# 72/72 - 2s - loss: 0.0304 - accuracy: 0.9912 - 2s/epoch - 32ms/step
# Epoch 46/500
# 72/72 - 2s - loss: 0.0224 - accuracy: 0.9935 - 2s/epoch - 34ms/step
# Epoch 47/500
# 72/72 - 2s - loss: 0.0210 - accuracy: 0.9939 - 2s/epoch - 32ms/step
# Epoch 48/500
# 72/72 - 2s - loss: 0.0236 - accuracy: 0.9920 - 2s/epoch - 32ms/step
# Epoch 49/500
# 72/72 - 2s - loss: 0.0282 - accuracy: 0.9900 - 2s/epoch - 32ms/step
# Epoch 50/500
# 72/72 - 2s - loss: 0.0205 - accuracy: 0.9937 - 2s/epoch - 32ms/step
# Epoch 51/500
# 72/72 - 2s - loss: 0.0217 - accuracy: 0.9921 - 2s/epoch - 33ms/step
# Epoch 52/500
# 72/72 - 2s - loss: 0.0225 - accuracy: 0.9924 - 2s/epoch - 32ms/step
# Epoch 53/500
# 72/72 - 2s - loss: 0.0224 - accuracy: 0.9936 - 2s/epoch - 32ms/step
# Epoch 54/500
# 72/72 - 2s - loss: 0.0190 - accuracy: 0.9942 - 2s/epoch - 32ms/step
# Epoch 55/500
# 72/72 - 2s - loss: 0.0219 - accuracy: 0.9933 - 2s/epoch - 32ms/step
# Epoch 56/500
# 72/72 - 2s - loss: 0.0177 - accuracy: 0.9949 - 2s/epoch - 33ms/step
# Epoch 57/500
# 72/72 - 2s - loss: 0.0176 - accuracy: 0.9942 - 2s/epoch - 33ms/step
# Epoch 58/500
# 72/72 - 2s - loss: 0.0177 - accuracy: 0.9941 - 2s/epoch - 32ms/step
# Epoch 59/500
# 72/72 - 2s - loss: 0.0141 - accuracy: 0.9957 - 2s/epoch - 32ms/step
# Epoch 60/500
# 72/72 - 2s - loss: 0.0209 - accuracy: 0.9933 - 2s/epoch - 32ms/step
# Epoch 61/500
# 72/72 - 2s - loss: 0.0137 - accuracy: 0.9952 - 2s/epoch - 32ms/step
# Epoch 62/500
# 72/72 - 2s - loss: 0.0144 - accuracy: 0.9942 - 2s/epoch - 33ms/step
# Epoch 63/500
# 72/72 - 2s - loss: 0.0196 - accuracy: 0.9932 - 2s/epoch - 32ms/step
# Epoch 64/500
# 72/72 - 2s - loss: 0.0129 - accuracy: 0.9954 - 2s/epoch - 32ms/step
# Epoch 65/500
# 72/72 - 2s - loss: 0.0118 - accuracy: 0.9965 - 2s/epoch - 32ms/step
# Epoch 66/500
# 72/72 - 2s - loss: 0.0117 - accuracy: 0.9960 - 2s/epoch - 32ms/step
# Epoch 67/500
# 72/72 - 2s - loss: 0.0288 - accuracy: 0.9912 - 2s/epoch - 34ms/step
# Epoch 68/500
# 72/72 - 2s - loss: 0.0166 - accuracy: 0.9945 - 2s/epoch - 32ms/step
# Epoch 69/500
# 72/72 - 2s - loss: 0.0239 - accuracy: 0.9916 - 2s/epoch - 32ms/step
# Epoch 70/500
# 72/72 - 2s - loss: 0.0147 - accuracy: 0.9948 - 2s/epoch - 32ms/step
# Epoch 71/500
# 72/72 - 2s - loss: 0.0164 - accuracy: 0.9942 - 2s/epoch - 32ms/step
# Epoch 72/500
# 72/72 - 2s - loss: 0.0104 - accuracy: 0.9968 - 2s/epoch - 33ms/step
# Epoch 73/500
# 72/72 - 2s - loss: 0.0122 - accuracy: 0.9958 - 2s/epoch - 33ms/step
# Epoch 74/500
# 72/72 - 2s - loss: 0.0156 - accuracy: 0.9951 - 2s/epoch - 32ms/step
# Epoch 75/500
# 72/72 - 2s - loss: 0.0143 - accuracy: 0.9959 - 2s/epoch - 32ms/step
# Epoch 76/500
# 72/72 - 2s - loss: 0.0151 - accuracy: 0.9954 - 2s/epoch - 32ms/step
# Epoch 77/500
# 72/72 - 2s - loss: 0.0133 - accuracy: 0.9963 - 2s/epoch - 33ms/step
# Epoch 78/500
# 72/72 - 2s - loss: 0.0086 - accuracy: 0.9974 - 2s/epoch - 33ms/step
# Epoch 79/500
# 72/72 - 2s - loss: 0.0108 - accuracy: 0.9966 - 2s/epoch - 32ms/step
# Epoch 80/500
# 72/72 - 2s - loss: 0.0069 - accuracy: 0.9978 - 2s/epoch - 32ms/step
# Epoch 81/500
# 72/72 - 2s - loss: 0.0101 - accuracy: 0.9961 - 2s/epoch - 32ms/step
# Epoch 82/500
# 72/72 - 2s - loss: 0.0139 - accuracy: 0.9952 - 2s/epoch - 32ms/step
# Epoch 83/500
# 72/72 - 2s - loss: 0.0068 - accuracy: 0.9977 - 2s/epoch - 33ms/step
# Epoch 84/500
# 72/72 - 2s - loss: 0.0083 - accuracy: 0.9976 - 2s/epoch - 32ms/step
# Epoch 85/500
# 72/72 - 2s - loss: 0.0152 - accuracy: 0.9949 - 2s/epoch - 32ms/step
# Epoch 86/500
# 72/72 - 2s - loss: 0.0377 - accuracy: 0.9888 - 2s/epoch - 32ms/step
# Epoch 87/500
# 72/72 - 2s - loss: 0.0236 - accuracy: 0.9924 - 2s/epoch - 32ms/step
# Epoch 88/500
# 72/72 - 2s - loss: 0.0125 - accuracy: 0.9967 - 2s/epoch - 34ms/step
# Epoch 89/500
# 72/72 - 2s - loss: 0.0160 - accuracy: 0.9957 - 2s/epoch - 32ms/step
# Epoch 90/500
# 72/72 - 2s - loss: 0.0161 - accuracy: 0.9947 - 2s/epoch - 32ms/step
# Epoch 91/500
# 72/72 - 2s - loss: 0.0165 - accuracy: 0.9952 - 2s/epoch - 32ms/step
# Epoch 92/500
# 72/72 - 2s - loss: 0.0141 - accuracy: 0.9951 - 2s/epoch - 32ms/step
# Epoch 93/500
# 72/72 - 2s - loss: 0.0069 - accuracy: 0.9975 - 2s/epoch - 33ms/step
# Epoch 94/500
# 72/72 - 2s - loss: 0.0116 - accuracy: 0.9960 - 2s/epoch - 33ms/step
# Epoch 95/500
# 72/72 - 2s - loss: 0.0088 - accuracy: 0.9968 - 2s/epoch - 32ms/step
# Epoch 96/500
# 72/72 - 2s - loss: 0.0134 - accuracy: 0.9957 - 2s/epoch - 32ms/step
# Epoch 97/500
# 72/72 - 2s - loss: 0.0110 - accuracy: 0.9968 - 2s/epoch - 32ms/step
# Epoch 98/500
# 72/72 - 2s - loss: 0.0128 - accuracy: 0.9964 - 2s/epoch - 32ms/step
# Epoch 99/500
# 72/72 - 2s - loss: 0.0092 - accuracy: 0.9965 - 2s/epoch - 33ms/step
# Epoch 100/500
# 72/72 - 2s - loss: 0.0076 - accuracy: 0.9972 - 2s/epoch - 32ms/step
# Epoch 101/500
# 72/72 - 2s - loss: 0.0070 - accuracy: 0.9977 - 2s/epoch - 32ms/step
# Epoch 102/500
# 72/72 - 2s - loss: 0.0128 - accuracy: 0.9961 - 2s/epoch - 32ms/step
# Epoch 103/500
# 72/72 - 2s - loss: 0.0124 - accuracy: 0.9961 - 2s/epoch - 32ms/step
# Epoch 104/500
# 72/72 - 2s - loss: 0.0075 - accuracy: 0.9972 - 2s/epoch - 34ms/step
# Epoch 105/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 106/500
# 72/72 - 2s - loss: 0.0039 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 107/500
# 72/72 - 2s - loss: 0.0046 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 108/500
# 72/72 - 2s - loss: 0.0034 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 109/500
# 72/72 - 2s - loss: 0.0106 - accuracy: 0.9967 - 2s/epoch - 33ms/step
# Epoch 110/500
# 72/72 - 2s - loss: 0.0059 - accuracy: 0.9985 - 2s/epoch - 33ms/step
# Epoch 111/500
# 72/72 - 2s - loss: 0.0055 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 112/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 113/500
# 72/72 - 2s - loss: 0.0255 - accuracy: 0.9920 - 2s/epoch - 32ms/step
# Epoch 114/500
# 72/72 - 2s - loss: 0.0086 - accuracy: 0.9974 - 2s/epoch - 32ms/step
# Epoch 115/500
# 72/72 - 2s - loss: 0.0108 - accuracy: 0.9972 - 2s/epoch - 33ms/step
# Epoch 116/500
# 72/72 - 2s - loss: 0.0095 - accuracy: 0.9966 - 2s/epoch - 32ms/step
# Epoch 117/500
# 72/72 - 2s - loss: 0.0122 - accuracy: 0.9965 - 2s/epoch - 32ms/step
# Epoch 118/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9976 - 2s/epoch - 32ms/step
# Epoch 119/500
# 72/72 - 2s - loss: 0.0076 - accuracy: 0.9974 - 2s/epoch - 32ms/step
# Epoch 120/500
# 72/72 - 2s - loss: 0.0179 - accuracy: 0.9947 - 2s/epoch - 34ms/step
# Epoch 121/500
# 72/72 - 2s - loss: 0.0123 - accuracy: 0.9959 - 2s/epoch - 32ms/step
# Epoch 122/500
# 72/72 - 2s - loss: 0.0100 - accuracy: 0.9970 - 2s/epoch - 32ms/step
# Epoch 123/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 124/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 125/500
# 72/72 - 2s - loss: 0.0071 - accuracy: 0.9983 - 2s/epoch - 34ms/step
# Epoch 126/500
# 72/72 - 2s - loss: 0.0059 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 127/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 128/500
# 72/72 - 2s - loss: 0.0031 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 129/500
# 72/72 - 2s - loss: 0.0185 - accuracy: 0.9948 - 2s/epoch - 33ms/step
# Epoch 130/500
# 72/72 - 2s - loss: 0.0127 - accuracy: 0.9963 - 2s/epoch - 35ms/step
# Epoch 131/500
# 72/72 - 2s - loss: 0.0080 - accuracy: 0.9974 - 2s/epoch - 33ms/step
# Epoch 132/500
# 72/72 - 2s - loss: 0.0182 - accuracy: 0.9938 - 2s/epoch - 32ms/step
# Epoch 133/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 134/500
# 72/72 - 2s - loss: 0.0118 - accuracy: 0.9972 - 2s/epoch - 32ms/step
# Epoch 135/500
# 72/72 - 2s - loss: 0.0084 - accuracy: 0.9977 - 2s/epoch - 32ms/step
# Epoch 136/500
# 72/72 - 2s - loss: 0.0065 - accuracy: 0.9982 - 2s/epoch - 34ms/step
# Epoch 137/500
# 72/72 - 2s - loss: 0.0114 - accuracy: 0.9965 - 2s/epoch - 32ms/step
# Epoch 138/500
# 72/72 - 2s - loss: 0.0056 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 139/500
# 72/72 - 2s - loss: 0.0067 - accuracy: 0.9976 - 2s/epoch - 32ms/step
# Epoch 140/500
# 72/72 - 2s - loss: 0.0041 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 141/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9975 - 2s/epoch - 33ms/step
# Epoch 142/500
# 72/72 - 2s - loss: 0.0063 - accuracy: 0.9982 - 2s/epoch - 32ms/step
# Epoch 143/500
# 72/72 - 2s - loss: 0.0068 - accuracy: 0.9977 - 2s/epoch - 32ms/step
# Epoch 144/500
# 72/72 - 2s - loss: 0.0050 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 145/500
# 72/72 - 2s - loss: 0.0042 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 146/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9992 - 2s/epoch - 33ms/step
# Epoch 147/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9992 - 2s/epoch - 33ms/step
# Epoch 148/500
# 72/72 - 2s - loss: 0.0045 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 149/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9978 - 2s/epoch - 32ms/step
# Epoch 150/500
# 72/72 - 2s - loss: 0.0066 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 151/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 152/500
# 72/72 - 2s - loss: 0.0053 - accuracy: 0.9986 - 2s/epoch - 34ms/step
# Epoch 153/500
# 72/72 - 2s - loss: 0.0057 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 154/500
# 72/72 - 2s - loss: 0.0068 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 155/500
# 72/72 - 2s - loss: 0.0075 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 156/500
# 72/72 - 2s - loss: 0.0097 - accuracy: 0.9970 - 2s/epoch - 32ms/step
# Epoch 157/500
# 72/72 - 2s - loss: 0.0062 - accuracy: 0.9984 - 2s/epoch - 34ms/step
# Epoch 158/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 159/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 160/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 161/500
# 72/72 - 2s - loss: 0.0054 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 162/500
# 72/72 - 2s - loss: 0.0053 - accuracy: 0.9988 - 2s/epoch - 33ms/step
# Epoch 163/500
# 72/72 - 2s - loss: 0.0041 - accuracy: 0.9988 - 2s/epoch - 33ms/step
# Epoch 164/500
# 72/72 - 2s - loss: 0.0071 - accuracy: 0.9978 - 2s/epoch - 32ms/step
# Epoch 165/500
# 72/72 - 2s - loss: 0.0045 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 166/500
# 72/72 - 2s - loss: 0.0070 - accuracy: 0.9976 - 2s/epoch - 32ms/step
# Epoch 167/500
# 72/72 - 2s - loss: 0.0107 - accuracy: 0.9963 - 2s/epoch - 33ms/step
# Epoch 168/500
# 72/72 - 2s - loss: 0.0106 - accuracy: 0.9962 - 2s/epoch - 33ms/step
# Epoch 169/500
# 72/72 - 2s - loss: 0.0043 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 170/500
# 72/72 - 2s - loss: 0.0047 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 171/500
# 72/72 - 2s - loss: 0.0149 - accuracy: 0.9951 - 2s/epoch - 32ms/step
# Epoch 172/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 173/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9989 - 2s/epoch - 34ms/step
# Epoch 174/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 175/500
# 72/72 - 2s - loss: 0.0055 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 176/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9982 - 2s/epoch - 32ms/step
# Epoch 177/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 178/500
# 72/72 - 2s - loss: 0.0047 - accuracy: 0.9983 - 2s/epoch - 33ms/step
# Epoch 179/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 180/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 181/500
# 72/72 - 2s - loss: 0.0046 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 182/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 183/500
# 72/72 - 2s - loss: 0.0039 - accuracy: 0.9989 - 2s/epoch - 33ms/step
# Epoch 184/500
# 72/72 - 2s - loss: 0.0126 - accuracy: 0.9957 - 2s/epoch - 33ms/step
# Epoch 185/500
# 72/72 - 2s - loss: 0.0090 - accuracy: 0.9974 - 2s/epoch - 32ms/step
# Epoch 186/500
# 72/72 - 2s - loss: 0.0095 - accuracy: 0.9968 - 2s/epoch - 32ms/step
# Epoch 187/500
# 72/72 - 2s - loss: 0.0080 - accuracy: 0.9976 - 2s/epoch - 32ms/step
# Epoch 188/500
# 72/72 - 2s - loss: 0.0069 - accuracy: 0.9974 - 2s/epoch - 32ms/step
# Epoch 189/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9990 - 2s/epoch - 34ms/step
# Epoch 190/500
# 72/72 - 2s - loss: 0.0072 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 191/500
# 72/72 - 2s - loss: 0.0100 - accuracy: 0.9973 - 2s/epoch - 32ms/step
# Epoch 192/500
# 72/72 - 2s - loss: 0.0117 - accuracy: 0.9960 - 2s/epoch - 32ms/step
# Epoch 193/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 194/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9989 - 2s/epoch - 33ms/step
# Epoch 195/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 196/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 197/500
# 72/72 - 2s - loss: 0.0047 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 198/500
# 72/72 - 2s - loss: 0.0069 - accuracy: 0.9980 - 2s/epoch - 33ms/step
# Epoch 199/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9980 - 2s/epoch - 34ms/step
# Epoch 200/500
# 72/72 - 2s - loss: 0.0042 - accuracy: 0.9989 - 2s/epoch - 33ms/step
# Epoch 201/500
# 72/72 - 2s - loss: 0.0218 - accuracy: 0.9930 - 2s/epoch - 32ms/step
# Epoch 202/500
# 72/72 - 2s - loss: 0.0119 - accuracy: 0.9960 - 2s/epoch - 32ms/step
# Epoch 203/500
# 72/72 - 2s - loss: 0.0056 - accuracy: 0.9990 - 2s/epoch - 31ms/step
# Epoch 204/500
# 72/72 - 2s - loss: 0.0068 - accuracy: 0.9978 - 2s/epoch - 32ms/step
# Epoch 205/500
# 72/72 - 2s - loss: 0.0077 - accuracy: 0.9979 - 2s/epoch - 33ms/step
# Epoch 206/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 207/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 208/500
# 72/72 - 2s - loss: 0.0031 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 209/500
# 72/72 - 2s - loss: 0.0038 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 210/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9992 - 2s/epoch - 34ms/step
# Epoch 211/500
# 72/72 - 2s - loss: 0.0038 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 212/500
# 72/72 - 2s - loss: 0.0062 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 213/500
# 72/72 - 2s - loss: 0.0036 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 214/500
# 72/72 - 2s - loss: 0.0061 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 215/500
# 72/72 - 2s - loss: 0.0052 - accuracy: 0.9985 - 2s/epoch - 33ms/step
# Epoch 216/500
# 72/72 - 2s - loss: 0.0036 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 217/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 218/500
# 72/72 - 2s - loss: 0.0023 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 219/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 220/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9990 - 2s/epoch - 33ms/step
# Epoch 221/500
# 72/72 - 2s - loss: 0.0073 - accuracy: 0.9980 - 2s/epoch - 33ms/step
# Epoch 222/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 223/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 224/500
# 72/72 - 2s - loss: 7.6788e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 225/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 226/500
# 72/72 - 3s - loss: 0.0032 - accuracy: 0.9992 - 3s/epoch - 35ms/step
# Epoch 227/500
# 72/72 - 2s - loss: 0.0075 - accuracy: 0.9982 - 2s/epoch - 33ms/step
# Epoch 228/500
# 72/72 - 2s - loss: 0.0019 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 229/500
# 72/72 - 2s - loss: 0.0061 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 230/500
# 72/72 - 2s - loss: 0.0080 - accuracy: 0.9979 - 2s/epoch - 32ms/step
# Epoch 231/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9990 - 2s/epoch - 33ms/step
# Epoch 232/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 233/500
# 72/72 - 2s - loss: 0.0166 - accuracy: 0.9949 - 2s/epoch - 32ms/step
# Epoch 234/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 235/500
# 72/72 - 2s - loss: 0.0058 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 236/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 237/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9979 - 2s/epoch - 33ms/step
# Epoch 238/500
# 72/72 - 2s - loss: 0.0048 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 239/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 240/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 241/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 242/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9997 - 2s/epoch - 34ms/step
# Epoch 243/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 244/500
# 72/72 - 2s - loss: 0.0025 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 245/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 246/500
# 72/72 - 2s - loss: 0.0036 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 247/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9993 - 2s/epoch - 33ms/step
# Epoch 248/500
# 72/72 - 2s - loss: 0.0048 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 249/500
# 72/72 - 2s - loss: 0.0062 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 250/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 251/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 252/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9996 - 2s/epoch - 33ms/step
# Epoch 253/500
# 72/72 - 2s - loss: 0.0039 - accuracy: 0.9992 - 2s/epoch - 33ms/step
# Epoch 254/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 255/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 256/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 257/500
# 72/72 - 2s - loss: 0.0026 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 258/500
# 72/72 - 2s - loss: 0.0057 - accuracy: 0.9984 - 2s/epoch - 33ms/step
# Epoch 259/500
# 72/72 - 2s - loss: 0.0041 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 260/500
# 72/72 - 2s - loss: 0.0069 - accuracy: 0.9982 - 2s/epoch - 32ms/step
# Epoch 261/500
# 72/72 - 2s - loss: 0.0054 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 262/500
# 72/72 - 2s - loss: 0.0034 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 263/500
# 72/72 - 2s - loss: 0.0042 - accuracy: 0.9990 - 2s/epoch - 34ms/step
# Epoch 264/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 265/500
# 72/72 - 2s - loss: 8.1465e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 266/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 267/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 268/500
# 72/72 - 2s - loss: 0.0093 - accuracy: 0.9973 - 2s/epoch - 33ms/step
# Epoch 269/500
# 72/72 - 2s - loss: 0.0073 - accuracy: 0.9980 - 2s/epoch - 33ms/step
# Epoch 270/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 271/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 272/500
# 72/72 - 2s - loss: 0.0054 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 273/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 274/500
# 72/72 - 2s - loss: 0.0061 - accuracy: 0.9988 - 2s/epoch - 33ms/step
# Epoch 275/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 276/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 277/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 278/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 279/500
# 72/72 - 2s - loss: 0.0106 - accuracy: 0.9967 - 2s/epoch - 34ms/step
# Epoch 280/500
# 72/72 - 2s - loss: 0.0046 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 281/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 282/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 283/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 284/500
# 72/72 - 2s - loss: 0.0040 - accuracy: 0.9987 - 2s/epoch - 33ms/step
# Epoch 285/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 286/500
# 72/72 - 2s - loss: 0.0038 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 287/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 288/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 289/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 290/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 291/500
# 72/72 - 2s - loss: 0.0054 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 292/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 293/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 294/500
# 72/72 - 2s - loss: 0.0056 - accuracy: 0.9986 - 2s/epoch - 33ms/step
# Epoch 295/500
# 72/72 - 2s - loss: 8.1845e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 296/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 297/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 298/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 299/500
# 72/72 - 2s - loss: 0.0033 - accuracy: 0.9991 - 2s/epoch - 33ms/step
# Epoch 300/500
# 72/72 - 2s - loss: 0.0051 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 301/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 302/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 303/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 304/500
# 72/72 - 2s - loss: 0.0023 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 305/500
# 72/72 - 2s - loss: 6.3739e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 306/500
# 72/72 - 2s - loss: 5.7755e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 307/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 308/500
# 72/72 - 2s - loss: 0.0026 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 309/500
# 72/72 - 2s - loss: 0.0068 - accuracy: 0.9984 - 2s/epoch - 33ms/step
# Epoch 310/500
# 72/72 - 2s - loss: 0.0054 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 311/500
# 72/72 - 2s - loss: 0.0076 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 312/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 313/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 314/500
# 72/72 - 2s - loss: 0.0098 - accuracy: 0.9979 - 2s/epoch - 33ms/step
# Epoch 315/500
# 72/72 - 2s - loss: 0.0090 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 316/500
# 72/72 - 2s - loss: 0.0041 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 317/500
# 72/72 - 2s - loss: 0.0026 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 318/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 319/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 320/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 321/500
# 72/72 - 2s - loss: 0.0067 - accuracy: 0.9977 - 2s/epoch - 32ms/step
# Epoch 322/500
# 72/72 - 2s - loss: 0.0026 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 323/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 324/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 325/500
# 72/72 - 2s - loss: 0.0035 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 326/500
# 72/72 - 2s - loss: 0.0023 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 327/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 328/500
# 72/72 - 2s - loss: 7.9571e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 329/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9982 - 2s/epoch - 33ms/step
# Epoch 330/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 331/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 332/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 333/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 334/500
# 72/72 - 2s - loss: 0.0032 - accuracy: 0.9995 - 2s/epoch - 33ms/step
# Epoch 335/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 336/500
# 72/72 - 2s - loss: 0.0038 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 337/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 338/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 339/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 340/500
# 72/72 - 2s - loss: 0.0026 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 341/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 342/500
# 72/72 - 2s - loss: 0.0062 - accuracy: 0.9982 - 2s/epoch - 32ms/step
# Epoch 343/500
# 72/72 - 2s - loss: 0.0046 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 344/500
# 72/72 - 2s - loss: 0.0057 - accuracy: 0.9986 - 2s/epoch - 33ms/step
# Epoch 345/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 346/500
# 72/72 - 2s - loss: 6.0943e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 347/500
# 72/72 - 2s - loss: 0.0032 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 348/500
# 72/72 - 2s - loss: 0.0059 - accuracy: 0.9979 - 2s/epoch - 32ms/step
# Epoch 349/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9993 - 2s/epoch - 33ms/step
# Epoch 350/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 351/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 352/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 353/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 354/500
# 72/72 - 2s - loss: 0.0023 - accuracy: 0.9991 - 2s/epoch - 33ms/step
# Epoch 355/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 356/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 357/500
# 72/72 - 2s - loss: 0.0056 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 358/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 359/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 360/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 361/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 362/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 363/500
# 72/72 - 2s - loss: 0.0048 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 364/500
# 72/72 - 2s - loss: 0.0032 - accuracy: 0.9996 - 2s/epoch - 33ms/step
# Epoch 365/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 366/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 367/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 368/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 369/500
# 72/72 - 2s - loss: 0.0101 - accuracy: 0.9978 - 2s/epoch - 33ms/step
# Epoch 370/500
# 72/72 - 2s - loss: 0.0076 - accuracy: 0.9977 - 2s/epoch - 32ms/step
# Epoch 371/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 372/500
# 72/72 - 2s - loss: 9.0628e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 373/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 374/500
# 72/72 - 2s - loss: 6.9829e-04 - accuracy: 0.9999 - 2s/epoch - 33ms/step
# Epoch 375/500
# 72/72 - 2s - loss: 6.6757e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 376/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 377/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 378/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 379/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 380/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 381/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 382/500
# 72/72 - 2s - loss: 0.0037 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 383/500
# 72/72 - 2s - loss: 0.0019 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 384/500
# 72/72 - 2s - loss: 7.5008e-04 - accuracy: 1.0000 - 2s/epoch - 33ms/step
# Epoch 385/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 386/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 387/500
# 72/72 - 2s - loss: 0.0030 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 388/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 389/500
# 72/72 - 2s - loss: 0.0125 - accuracy: 0.9964 - 2s/epoch - 33ms/step
# Epoch 390/500
# 72/72 - 2s - loss: 0.0074 - accuracy: 0.9980 - 2s/epoch - 32ms/step
# Epoch 391/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 392/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 393/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 394/500
# 72/72 - 2s - loss: 7.7147e-04 - accuracy: 1.0000 - 2s/epoch - 33ms/step
# Epoch 395/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 396/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 397/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 398/500
# 72/72 - 2s - loss: 6.9626e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 399/500
# 72/72 - 2s - loss: 7.7371e-04 - accuracy: 0.9999 - 2s/epoch - 33ms/step
# Epoch 400/500
# 72/72 - 2s - loss: 7.7173e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 401/500
# 72/72 - 2s - loss: 5.4072e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 402/500
# 72/72 - 2s - loss: 0.0021 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 403/500
# 72/72 - 2s - loss: 0.0052 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 404/500
# 72/72 - 2s - loss: 0.0076 - accuracy: 0.9976 - 2s/epoch - 33ms/step
# Epoch 405/500
# 72/72 - 2s - loss: 0.0034 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 406/500
# 72/72 - 2s - loss: 8.8544e-04 - accuracy: 0.9999 - 2s/epoch - 31ms/step
# Epoch 407/500
# 72/72 - 2s - loss: 0.0025 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 408/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 409/500
# 72/72 - 2s - loss: 0.0032 - accuracy: 0.9991 - 2s/epoch - 33ms/step
# Epoch 410/500
# 72/72 - 2s - loss: 0.0049 - accuracy: 0.9989 - 2s/epoch - 32ms/step
# Epoch 411/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 412/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 413/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 414/500
# 72/72 - 2s - loss: 9.9543e-04 - accuracy: 0.9999 - 2s/epoch - 33ms/step
# Epoch 415/500
# 72/72 - 2s - loss: 6.6891e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 416/500
# 72/72 - 2s - loss: 7.4972e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 417/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 418/500
# 72/72 - 2s - loss: 0.0080 - accuracy: 0.9979 - 2s/epoch - 32ms/step
# Epoch 419/500
# 72/72 - 2s - loss: 0.0044 - accuracy: 0.9993 - 2s/epoch - 33ms/step
# Epoch 420/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 31ms/step
# Epoch 421/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 422/500
# 72/72 - 2s - loss: 0.0091 - accuracy: 0.9973 - 2s/epoch - 32ms/step
# Epoch 423/500
# 72/72 - 2s - loss: 0.0060 - accuracy: 0.9985 - 2s/epoch - 32ms/step
# Epoch 424/500
# 72/72 - 2s - loss: 9.6176e-04 - accuracy: 1.0000 - 2s/epoch - 34ms/step
# Epoch 425/500
# 72/72 - 2s - loss: 0.0019 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 426/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 427/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 428/500
# 72/72 - 2s - loss: 0.0059 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 429/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9995 - 2s/epoch - 33ms/step
# Epoch 430/500
# 72/72 - 2s - loss: 9.0167e-04 - accuracy: 0.9999 - 2s/epoch - 31ms/step
# Epoch 431/500
# 72/72 - 2s - loss: 6.4924e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 432/500
# 72/72 - 2s - loss: 5.5254e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 433/500
# 72/72 - 2s - loss: 6.0534e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 434/500
# 72/72 - 2s - loss: 6.2850e-04 - accuracy: 1.0000 - 2s/epoch - 33ms/step
# Epoch 435/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 436/500
# 72/72 - 2s - loss: 0.0039 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 437/500
# 72/72 - 2s - loss: 0.0060 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 438/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 31ms/step
# Epoch 439/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 440/500
# 72/72 - 2s - loss: 9.1060e-04 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 441/500
# 72/72 - 2s - loss: 5.7350e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 442/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 443/500
# 72/72 - 2s - loss: 0.0023 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 444/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 445/500
# 72/72 - 2s - loss: 0.0016 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 446/500
# 72/72 - 2s - loss: 7.5923e-04 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 447/500
# 72/72 - 2s - loss: 0.0035 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 448/500
# 72/72 - 2s - loss: 0.0064 - accuracy: 0.9984 - 2s/epoch - 32ms/step
# Epoch 449/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 450/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 451/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 452/500
# 72/72 - 2s - loss: 0.0010 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 453/500
# 72/72 - 2s - loss: 5.7119e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 454/500
# 72/72 - 2s - loss: 6.8433e-04 - accuracy: 0.9999 - 2s/epoch - 33ms/step
# Epoch 455/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9996 - 2s/epoch - 31ms/step
# Epoch 456/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 457/500
# 72/72 - 2s - loss: 0.0048 - accuracy: 0.9987 - 2s/epoch - 32ms/step
# Epoch 458/500
# 72/72 - 2s - loss: 8.8893e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 459/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9996 - 2s/epoch - 33ms/step
# Epoch 460/500
# 72/72 - 2s - loss: 0.0022 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 461/500
# 72/72 - 2s - loss: 0.0059 - accuracy: 0.9986 - 2s/epoch - 31ms/step
# Epoch 462/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 463/500
# 72/72 - 2s - loss: 0.0032 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 464/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 465/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 466/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 467/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 468/500
# 72/72 - 2s - loss: 0.0024 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 469/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9998 - 2s/epoch - 33ms/step
# Epoch 470/500
# 72/72 - 2s - loss: 6.4346e-04 - accuracy: 1.0000 - 2s/epoch - 31ms/step
# Epoch 471/500
# 72/72 - 2s - loss: 0.0041 - accuracy: 0.9991 - 2s/epoch - 31ms/step
# Epoch 472/500
# 72/72 - 2s - loss: 0.0018 - accuracy: 0.9995 - 2s/epoch - 32ms/step
# Epoch 473/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9996 - 2s/epoch - 32ms/step
# Epoch 474/500
# 72/72 - 2s - loss: 7.6835e-04 - accuracy: 0.9999 - 2s/epoch - 33ms/step
# Epoch 475/500
# 72/72 - 2s - loss: 7.6309e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 476/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 477/500
# 72/72 - 2s - loss: 0.0051 - accuracy: 0.9983 - 2s/epoch - 32ms/step
# Epoch 478/500
# 72/72 - 2s - loss: 0.0031 - accuracy: 0.9992 - 2s/epoch - 32ms/step
# Epoch 479/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 480/500
# 72/72 - 2s - loss: 0.0012 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 481/500
# 72/72 - 2s - loss: 0.0014 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 482/500
# 72/72 - 2s - loss: 0.0066 - accuracy: 0.9986 - 2s/epoch - 32ms/step
# Epoch 483/500
# 72/72 - 2s - loss: 0.0017 - accuracy: 0.9997 - 2s/epoch - 32ms/step
# Epoch 484/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9997 - 2s/epoch - 33ms/step
# Epoch 485/500
# 72/72 - 2s - loss: 0.0053 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 486/500
# 72/72 - 2s - loss: 0.0013 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 487/500
# 72/72 - 2s - loss: 6.1439e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 488/500
# 72/72 - 2s - loss: 8.5689e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# Epoch 489/500
# 72/72 - 2s - loss: 7.0265e-04 - accuracy: 1.0000 - 2s/epoch - 33ms/step
# Epoch 490/500
# 72/72 - 2s - loss: 4.8642e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 491/500
# 72/72 - 2s - loss: 4.8060e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 492/500
# 72/72 - 2s - loss: 0.0015 - accuracy: 0.9993 - 2s/epoch - 32ms/step
# Epoch 493/500
# 72/72 - 2s - loss: 5.5306e-04 - accuracy: 1.0000 - 2s/epoch - 32ms/step
# Epoch 494/500
# 72/72 - 2s - loss: 0.0028 - accuracy: 0.9990 - 2s/epoch - 33ms/step
# Epoch 495/500
# 72/72 - 2s - loss: 0.0011 - accuracy: 0.9998 - 2s/epoch - 32ms/step
# Epoch 496/500
# 72/72 - 2s - loss: 0.0027 - accuracy: 0.9991 - 2s/epoch - 32ms/step
# Epoch 497/500
# 72/72 - 2s - loss: 0.0029 - accuracy: 0.9988 - 2s/epoch - 32ms/step
# Epoch 498/500
# 72/72 - 2s - loss: 0.0039 - accuracy: 0.9990 - 2s/epoch - 32ms/step
# Epoch 499/500
# 72/72 - 2s - loss: 0.0020 - accuracy: 0.9991 - 2s/epoch - 33ms/step
# Epoch 500/500
# 72/72 - 2s - loss: 8.9825e-04 - accuracy: 0.9999 - 2s/epoch - 32ms/step
# 72/72 [==============================] - 1s 9ms/step
# 72/72 [==============================] - 0s 6ms/step
# 72/72 [==============================] - 0s 6ms/step
# accuracy_score: 0.9965
# cohen_kappa_score: 0.9891
# log_loss: 0.0160
# zero_one_loss: 0.0035
# hemming_loss: 0.0035
# matthews_corrcoef: 0.9891
#
# ---------------------------------------------------------------------------------
# Train runtime: 0.5303812026977539
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0160 - accuracy: 0.9965
# 72/72 [==============================] - 1s 7ms/step
# Test runtime: 1.9876608848571777
# 72/72 [==============================] - 0s 6ms/step
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0160 - accuracy: 0.9965
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0160 - accuracy: 0.9965
# 72/72 [==============================] - 0s 6ms/step
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0160 - accuracy: 0.9965
# 72/72 [==============================] - 0s 6ms/step
